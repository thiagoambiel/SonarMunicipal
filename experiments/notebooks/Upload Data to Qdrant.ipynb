# %%
import time
import numpy as np
from tqdm.auto import tqdm 

from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams, PointStruct

# %%
with open("../data/dataset.npy", "rb") as f:
    dataset = np.load(f, allow_pickle=True)

len(dataset)
# Out:
# 220065

# %%
# URL do seu node Qdrant
# - Para Qdrant local: "http://localhost:6333"
# - Para Qdrant Cloud: "https://SEU-CLUSTER.qdrant.io"
QDRANT_URL = "https://34cff7bc-5334-4dc1-b9b8-3a6432c5fc70.sa-east-1-0.aws.cloud.qdrant.io"

# Para Qdrant Cloud, coloque o API key aqui; para local, deixe None
QDRANT_API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIn0.lZERRhcG91oelSwFVxtIClB23eaHKckK8cpsJTSfJvw"

# Nome da collection que vamos criar
COLLECTION_NAME = "projetos-de-lei"

BATCH_SIZE = 250            # tamanho do batch para upsert
UPSERT_TIMEOUT = 60.0       # timeout por request
MAX_RETRIES = 3             # quantas vezes tentar o mesmo batch
RETRY_SLEEP = 5             # segundos entre tentativas

# %%
# Cria cliente Qdrant
client = QdrantClient(
    url=QDRANT_URL,
    api_key=QDRANT_API_KEY,
    timeout=UPSERT_TIMEOUT
)

# Descobre a dimensionalidade do vetor a partir da primeira amostra
vector_dim = int(dataset[0]["embedding"].shape[0])
print(f"Dimensão das embeddings: {vector_dim}")
# Out:
# Dimensão das embeddings: 768

# %%
if client.collection_exists(COLLECTION_NAME):
    client.delete_collection(collection_name=COLLECTION_NAME)

client.create_collection(
    collection_name=COLLECTION_NAME,
    vectors_config=VectorParams(
        size=vector_dim,
        distance=Distance.COSINE,  # similaridade de cosseno
    ),
)

print(f"Collection '{COLLECTION_NAME}' criada.")
# Out:
# Collection 'projetos-de-lei' criada.

# %%
total = len(dataset)
global_id = 0  # contador global de IDs

for start in tqdm(range(0, total, BATCH_SIZE), desc="Enviando pontos para o Qdrant"):
    end = min(start + BATCH_SIZE, total)
    batch = dataset[start:end]

    points = []

    for local_idx, item in enumerate(batch, start=start):
        vector = item["embedding"].astype(np.float32).tolist()

         # ID global único dentro desta carga
        point_id = int(global_id)
        global_id += 1

        payload = {
            "id": point_id,
            "sapl_base": item.get("sapl_base"),
            "sapl_url": item.get("sapl_url"),
            "municipio": item.get("municipio"),
            "uf": item.get("uf"),
            "tipo_id": item.get("tipo_id"),
            "tipo_label": item.get("tipo_label"),
            "materia_id": item.get("materia_id"),
            "numero": item.get("numero"),
            "ano": item.get("ano"),
            "ementa": item.get("ementa"),
            "data_apresentacao": item.get("data_apresentacao"),
            "em_tramitacao": item.get("em_tramitacao"),
            "situacao": item.get("situacao"),
            "link_publico": item.get("link_publico"),
            "acao": item.get("acao"),
        }

        points.append(
            PointStruct(
                id=point_id,
                vector=vector,
                payload=payload,
            )
        )

    # ======= UPSERT COM RETRY =======
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            client.upsert(
                collection_name=COLLECTION_NAME,
                points=points,
                wait=True,
            )
            break  # deu certo -> sai do loop de retries
        except Exception as e:
            print(f"\nErro no batch {start}-{end} (tentativa {attempt}/{MAX_RETRIES}): {e}")
            if attempt == MAX_RETRIES:
                print("Número máximo de tentativas atingido. Seguindo para o próximo batch.")
            else:
                print(f"Aguardando {RETRY_SLEEP}s antes de tentar novamente...")
                time.sleep(RETRY_SLEEP)

print("Upload concluído.")
# Out:
# Enviando pontos para o Qdrant:   0%|          | 0/881 [00:00<?, ?it/s]
# Upload concluído.

# %%
import os
from huggingface_hub import InferenceClient

hf_client = InferenceClient(
    provider="hf-inference",
    api_key="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",
)

embeddings = hf_client.feature_extraction(
    "query: Como diminuir a taxa de homicídios no município?",
    model="embaas/sentence-transformers-multilingual-e5-base",
    normalize=True,               # vetores normalizados (bom para cosseno)
    truncate=True,                # corta se passar do limite de tokens
    truncation_direction="Right", # padrão mais comum
)

embeddings.shape
# Out:
# (768,)

# %%
# Supondo que `embeddings` seja um np.ndarray (dimensão igual à da collection)
query_embedding = embeddings.astype(np.float32).tolist()

results = client.query_points(
    collection_name=COLLECTION_NAME,
    query=query_embedding,  # vetor da query
    limit=100,
    with_payload=True,      # pra já trazer os campos do documento
)

for point in results.points:
    print(
        point.id,
        point.score,
        point.payload.get("municipio"),
        "-",
        point.payload.get("acao"),
    )
# Out:
# 148841 0.8847642 Parauapebas - Instituir a campanha “Morte Zero no Trânsito” no município.
# 213973 0.8805548 Natal - Criar o programa “Descarte Consciente” no município.
# 171593 0.87999094 Pedra Preta - Instituir o mês Setembro Amarelo como mês de ações preventivas ao suicídio no município.
# 48686 0.879871 Guarujá do Sul - Criar o programa “Juro Zero” no município.
# 97511 0.8790353 Primavera do Leste - Criar o programa “Pichação Zero” no município.
# 12479 0.87892556 Caruaru - Implementar programa de prevenção às drogas, denominado “Esporte Sim, Drogas Não”, no município.
# 12951 0.8788948 Campina Grande - Criar programa municipal de prevenção ao suicídio no município.
# 14725 0.87882113 Campina Grande - Implementar política municipal contra pichações no município.
# 158341 0.87814754 Francisco Beltrão - Criar programa de combate à pichação no município.
# 174584 0.87814754 Barueri - Criar programa de combate à pichação no município.
# 196688 0.8778729 Sarandi - Criar o projeto “Diga Não às Drogas” no município.
# 195491 0.8778614 Barueri - Implantar programa de desarmamento no município.
# 144850 0.8777949 Anápolis - Instituir a campanha pública “Tomada Premiada” no município.
# 21848 0.8777608 Guanhães - Proibir queimadas no município.
# 163533 0.8777608 Barueri - Proibir queimadas no município.
# 185612 0.8777608 Votorantim - Proibir queimadas no município.
# 21732 0.8777608 Itabirito - Proibir queimadas no município.
# 166767 0.8777608 Formosa - Proibir queimadas no município.
# 182622 0.8777607 Parauapebas - Proibir queimadas no município.
# 179651 0.8775494 Diamantino - Criar o programa “Homem de Honra” no município.
# 32983 0.87741005 Campinas - Criar programa municipal de enfrentamento ao feminicídio no município.
# 157034 0.8772757 Itaporanga - Criar o programa “Infância Sem Violência” no município.
# 70154 0.87720615 Pelotas - Instituir o Diamante Amarelo de Prevenção ao suicídio no município.
# 145243 0.87720615 Santa Rita do Sapucaí - Instituir o Diamante Amarelo de Prevenção ao suicídio no município.
# 161096 0.87709284 Montes Claros - Instituir o mês “Junho Violento” para conscientização e prevenção da violência contra pessoas idosas no município.
# 10487 0.8770144 Campina Grande - Instituir campanha permanente de prevenção e combate à automutilação e ao suicídio “Pare! Não faça mal a você!” no município.
# 29797 0.8768616 Armação dos Búzios - Criar programa de combate às pichações no município.
# 164197 0.8768616 Olinda - Criar programa de combate às pichações no município.
# 11019 0.8767557 Caruaru - Criar o programa “Mulheres Sem Violência” no município.
# 9560 0.876674 Campina Grande - Instituir a campanha “Pequeno silvestre não é Pet” no município.
# 196125 0.8766446 Montes Claros - Incluir a temática “Contra a Violência contra Mulheres e Meninas” no currículo das escolas do município.
# 198567 0.8766446 Montes Claros - Incluir a temática “Contra a Violência contra Mulheres e Meninas” no currículo das escolas do município.
# 197334 0.87664425 Montes Claros - Incluir a temática “Contra a Violência contra Mulheres e Meninas” no currículo das escolas do município.
# 46329 0.8764689 Esteio - Instituir campanha de prevenção ao suicídio no município.
# 199476 0.876413 Barueri - Proibir a venda de armas de brinquedos no município.
# 102951 0.87637085 Araxá - Instituir o mês “Junho Violento” no município para promover ações de combate à violência contra o idoso.
# 212763 0.8763679 Natal - Criar programa de combate a pichações no município.
# 56639 0.8763679 Tijucas do Sul - Criar programa de combate a pichações no município.
# 46380 0.8763673 Esteio - Criar programa de combate a pichações no município.
# 12887 0.8762961 Caruaru - Instituir o Dia “Sem Carro” no município.
# 168502 0.876232 Natércia - Implementar seguro de vida no município.
# 100115 0.87620205 Porto Murtinho - Instituir o Dia de Combate ao Feminicídio e a Semana Municipal de Combate ao Feminicídio no município.
# 134060 0.87616956 Barueri - Implementar programa de desarmamento no município.
# 16310 0.8755614 Campina Grande - Proibir a comercialização de armas de brinquedos no município.
# 153972 0.87556124 Natal - Instituir a campanha “Amar é dela, o silêncio mata” no município.
# 122266 0.875553 Parauapebas - Criar política municipal de prevenção ao suicídio no município.
# 118846 0.8753984 Tapurah - Reconhecer o risco da atividade de caçadores, atiradores esportivos e colecionadores de cac’s no município.
# 70888 0.8753049 Tijucas - Instituir campanha de prevenção ao avc no município.
# 203921 0.8752736 Natal - Criar programa de cooperação e o código “Sinal Vermelho” no município para combater e prevenir a violência doméstica e familiar.
# 174593 0.8750925 Barueri - Instituir a campanha municipal de prevenção ao suicídio “Setembro Amarelo” no município.
# 45878 0.8750752 Estância Velha - Instituir campanha de conscientização, prevenção e enfrentamento à violência contra a pessoa idosa “Junho Violento” no município.
# 210239 0.87505937 Erechim - Instituir o “Hino Nativista Brasileiro” no município.
# 130135 0.8749871 Olinda - Criar fundo municipal para políticas penais no município.
# 1106 0.8749871 Marabá - Criar fundo municipal para políticas penais no município.
# 183625 0.8749105 Araxá - Criar programa antidrogas no município.
# 200695 0.8748293 Barueri - Instituir o “Hino à Negritude” no município.
# 36293 0.87474763 Franca - Criar o programa municipal “Remédio em Casa” no município.
# 90 0.8747454 Marabá - Criar o programa “Adote Uma Casinha em Ponto de Mototáxi” no município.
# 162647 0.87462246 Piedade - Instituir campanha municipal de prevenção ao suicídio “Setembro Amarelo” no município.
# 173239 0.8745934 Natal - Proibir que condenados por crimes de racismo assumam cargos públicos no município.
# 6843 0.87453806 Campina Grande - Instituir a campanha “Pe na Sombra” no município.
# 150897 0.8745311 Sarandi - Criar política municipal antipichação no município.
# 173212 0.8745184 Natal - Instituir a Campanha “Cordão Dourado” no município.
# 12221 0.8744802 Caruaru - Criar programa de jornada extra de prevencão à violência no município.
# 197511 0.8744788 Natal - Instituir a Campanha Junho Violento – Violentos contra a Violência no município.
# 210445 0.8744006 Pato Branco - Criar programa municipal antivandalismo no município.
# 213562 0.87433404 Montes Claros - Criar o projeto “Segurança Participativa” no município.
# 205807 0.87424517 Natal - Instituir a “Hora do Esporte” no município.
# 139995 0.8740853 Barueri - Criar o programa “Esse Zero” no município.
# 15960 0.8740295 Campina Grande - Implantar o programa “Remédio para Todos” no município.
# 10419 0.8739995 Campina Grande - Instituir a campanha “A abuso sexual no ônibus é crime” no município.
# 201818 0.8739975 Montes Claros - Proibir jogar lixo no chão no município.
# 171582 0.87391484 Pedra Preta - Instituir o mês “Maio Amarelo” para ações preventivas de conscientização para a redução de acidentes de trânsito no município.
# 213473 0.8738866 Natal - Criar o programa “Tempo de Acordar” no município.
# 111544 0.87387586 Ipameri - Instituir o mês “Junho Violento” como mês de conscientização, prevenção e combate à violência contra pessoas idosas no município.
# 87089 0.87378484 Tijucas - Instituir o mês “Setembro Amarelo – Campanha de Prevenção ao suicídio” no município.
# 163010 0.87373674 Formosa - Instituir o Dia Municipal de Combate ao Feminicídio no município.
# 12482 0.8736537 Caruaru - Instituir a campanha “Coração Pet - Doação de Sangue Animal” no município.
# 37483 0.8736447 Paraguaçu Paulista - Criar o programa “Doe Sangue, Salve Uma Vida” no município.
# 63776 0.8736241 Santana do Itararé - Criar o programa “Hora Cidadã” no município.
# 35014 0.8736186 Franca - Instituir o “Setembro Amarelo – Dia de Prevenção ao suicídio” no município.
# 196962 0.87355524 Pato Branco - Instituir o Setembro Amarelo como mês de prevenção e combate ao suicídio no município.
# 211781 0.87352765 Erechim - Criar taxa de bombeiros no município.
# 66924 0.87349415 Jaguari - Instituir a campanha municipal “Setembro Amarelo” para prevenir o suicídio e valorização da vida no município.
# 34658 0.87349284 Campinas - Implantar medidas de combate ao mosquito Aedes Aegypti no município.
# 46658 0.8734304 Nova Prata - Regulamentar a taxa de lixo no município.
# 168764 0.8733598 Votorantim - Criar o projeto “Recorte Legal” no município.
# 21789 0.87335706 Guanhães - Instituir o “Benficar Social” no município.
# 128310 0.8732262 Natal - Criar o programa “Desconecta” no município.
# 165267 0.87321776 Pedra Preta - Proibir práticas de violência, assédio e discriminação contra mulheres no município.
# 42550 0.87319547 Canoinhas - Corrigir o valor da taxa de lixo no município.
# 22562 0.873156 Itabirito - Criar o projeto “Pena na Faixa, Pé no Freio” no município.
# 94971 0.8730452 Xangri-lá - Criar o programa “Deidentifique Nossas Ruas” no município.
# 189643 0.87288046 Natal - Instituir o Dia de Prevenção ao Feminicídio no município.
# 7339 0.87285286 Campina Grande - Criar o programa “Remédio em Casa” no município.
# 57308 0.87285286 São João do Ivaí - Criar o programa “Remédio em Casa” no município.
# 171099 0.87285244 Luziânia - Criar o programa “Remédio em Casa” no município.
# 18522 0.87285244 Goianá - Criar o programa “Remédio em Casa” no município.
# 118231 0.87285244 Tangará da Serra - Criar o programa “Remédio em Casa” no município.
# 134052 0.872847 Barueri - Proibir o câncer do colo do útero no município.
