# %%
# Download the Custom Criminal Indicator Data
# !gdown "1VgzwriksHMj5uiX2pYk7cv8hOavA1fku"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VgzwriksHMj5uiX2pYk7cv8hOavA1fku
# To: /content/criminal_indicator.csv
# 100% 6.86M/6.86M [00:00<00:00, 36.9MB/s]

# %%
# Download the Action Recommendation Dataset
# !gdown "1ECcRj3u6g04z-4ODNSHoJC3jRz6ba0nd"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ECcRj3u6g04z-4ODNSHoJC3jRz6ba0nd
# From (redirected): https://drive.google.com/uc?id=1ECcRj3u6g04z-4ODNSHoJC3jRz6ba0nd&confirm=t&uuid=2eb7f999-6fef-4761-93e4-a7d407b0d2c4
# To: /content/dataset.npy
# 100% 487M/487M [00:04<00:00, 115MB/s]

# %%
import numpy as np

with open("/content/dataset.npy", "rb") as f:
  dataset = np.load(f, allow_pickle=True)

len(dataset)
# Out:
# 220065

# %%
cities = list(set([row['municipio'].upper() for row in dataset]))
len(cities)
# Out:
# 322

# %%
import pandas as pd

df = pd.read_csv("/content/criminal_indicator.csv")
df = df[df['municipio_norm'].isin(cities)]
len(df['municipio_norm'].unique())
# Out:
# 322

# %%
df
# Out:
#        municipio_norm  codigo_municipio  uf   ano  semestre  \
# 946         CAMPESTRE         2701357.0  AL  2015         1
# 947         CAMPESTRE         3111002.0  AL  2015         1
# 948         CAMPESTRE         2701357.0  AL  2015         2
# 949         CAMPESTRE         3111002.0  AL  2015         2
# 950         CAMPESTRE         2701357.0  AL  2016         1
# ...               ...               ...  ..   ...       ...
# 136799       RIO SONO         1718758.0  TO  2023         2
# 136800       RIO SONO         1718758.0  TO  2024         1
# 136801       RIO SONO         1718758.0  TO  2024         2
# 136802       RIO SONO         1718758.0  TO  2025         1
# 136803       RIO SONO         1718758.0  TO  2025         2
#
#         vitimas_homicidio_doloso  populacao  taxa_homicidios_100k
# 946                            0     6665.0              0.000000
# 947                            0    20696.0              0.000000
# 948                            1     6665.0             15.003751
# 949                            1    20696.0              4.831852
# 950                            2     6665.0             30.007502
# ...                          ...        ...                   ...
# 136799                         0     4841.0              0.000000
# 136800                         0     4841.0              0.000000
# 136801                         1     4841.0             20.656889
# 136802                         0     4841.0              0.000000
# 136803                         1     4841.0             20.656889
#
# [8466 rows x 8 columns]

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# Carrega o modelo uma única vez (fora da função, para não recarregar toda hora)
model = SentenceTransformer("embaas/sentence-transformers-multilingual-e5-base")

def top_k(text: str,
          embeddings: np.ndarray,
          k: int = 5) -> np.ndarray:
    """
    Retorna os índices das k embeddings mais similares semanticamente ao `texto`.

    Parâmetros
    ----------
    text : str
        Texto de entrada.
    embeddings : np.ndarray
        Matriz de embeddings com shape (N, 768), por exemplo (250000, 768).
        Idealmente pré-computadas com o mesmo modelo.
    k : int
        Número de vizinhos mais próximos a retornar.

    Retorno
    -------
    np.ndarray
        Array 1D com os índices das k embeddings mais similares.
    """

    # 1) Codificar o texto de entrada em um embedding
    # Para modelos E5, é comum prefixar com "query: "
    consulta = f"query: {text}"
    embedding_texto = model.encode(
        consulta,
        normalize_embeddings=True  # já normaliza o vetor (norma L2 = 1)
    )  # shape (768,)

    # 2) Garantir que a matriz de embeddings também está normalizada
    #    (se você já salvou normalizada, pode pular esse passo)
    normas = np.linalg.norm(embeddings, axis=1, keepdims=True)
    # Evitar divisão por zero
    normas[normas == 0] = 1e-12
    embeddings_norm = embeddings / normas

    # 3) Similaridade por produto interno (equivale a cosseno se tudo está normalizado)
    #    resultado: vetor de similaridades shape (N,)
    scores = embeddings_norm @ embedding_texto

    # 4) Pegar os índices das k maiores similaridades
    # argpartition é mais eficiente que sort para top-k
    if k >= len(scores):
        # Se k >= N, só ordena tudo
        return np.argsort(-scores)

    idx_part = np.argpartition(-scores, k)[:k]  # k maiores (desordenados)
    # Ordenar esses k pelo score decrescente
    idx_ordenados = idx_part[np.argsort(-scores[idx_part])]

    return idx_ordenados
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/714 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
dataset[10]
# Out:
# {'sapl_base': 'https://sapl.maraba.pa.leg.br',
#  'sapl_url': 'https://sapl.maraba.pa.leg.br',
#  'municipio': 'Marabá',
#  'uf': 'PA',
#  'tipo_id': 9,
#  'tipo_label': 'ANT Anteprojeto de Lei ',
#  'materia_id': 27379,
#  'numero': 12,
#  'ano': 2025,
#  'ementa': 'ANTEPROJETO DE LEI Nº 01 DE 10 DE ABRIL 2025\r\nINSTITUI  E REGULAMENTA A IMPLANTAÇÃO DA CASA DE PARTO  NO MUNICÍPIO DE MARABÁ, E DÁ OUTRAS PROVIDÊNCIAS.',
#  'data_apresentacao': '2025-04-10',
#  'em_tramitacao': True,
#  'situacao': None,
#  'link_publico': 'https://sapl.maraba.pa.leg.br/materia/27379/acompanhar-materia/',
#  'acao': 'Instituir e regulamentar a implantação da Casa de Parto no município.',
#  'embedding': array([ 0.006138 ,  0.01941  , -0.005856 ,  0.047    ,  0.02234  ,
#         -0.00502  , -0.0306   , -0.0444   ,  0.002518 ,  0.02133  ,
#         -0.0491   ,  0.007385 ,  0.1006   ,  0.0452   , -0.06537  ,
#         -0.03192  ,  0.001022 , -0.003258 ,  0.03323  ,  0.0008044,
#          0.0185   , -0.0629   ,  0.0708   , -0.0175   ,  0.05655  ,
#          0.005352 ,  0.01149  ,  0.04544  , -0.02832  ,  0.02228  ,
#          0.0259   , -0.03207  ,  0.01473  ,  0.03467  ,  0.0627   ,
#          0.04022  , -0.03323  , -0.02672  ,  0.012276 ,  0.02917  ,
#          0.02242  ,  0.04453  ,  0.02252  , -0.0488   ,  0.02827  ,
#          0.0005164,  0.0541   ,  0.03506  , -0.02274  , -0.02025  ,
#          0.03555  ,  0.01892  , -0.001797 ,  0.04465  , -0.05026  ,
#         -0.06046  ,  0.02507  ,  0.05255  , -0.02661  ,  0.007515 ,
#         -0.010345 ,  0.0851   , -0.02086  ,  0.000747 ,  0.01627  ,
#         -0.013725 , -0.004913 , -0.01474  , -0.01604  , -0.03992  ,
#         -0.008385 , -0.04645  ,  0.04608  ,  0.04446  , -0.0328   ,
#         -0.00667  , -0.0686   ,  0.03488  ,  0.0131   , -0.03397  ,
#          0.03323  ,  0.001706 ,  0.03464  ,  0.01436  ,  0.01426  ,
#         -0.01794  , -0.014305 ,  0.05014  ,  0.03653  ,  0.04587  ,
#          0.03     , -0.04517  , -0.03262  ,  0.01894  , -0.007645 ,
#          0.01654  ,  0.006763 ,  0.03632  ,  0.03375  , -0.08026  ,
#         -0.012665 , -0.0546   , -0.03973  , -0.0539   , -0.07465  ,
#         -0.01137  , -0.000543 , -0.014175 ,  0.02621  ,  0.006542 ,
#         -0.02171  ,  0.02412  ,  0.03378  , -0.03845  ,  0.03027  ,
#          0.01697  , -0.0002434, -0.03345  , -0.012726 , -0.0754   ,
#          0.0277   , -0.03314  , -0.03674  ,  0.001383 ,  0.02554  ,
#          0.01464  ,  0.01134  , -0.0542   ,  0.04126  , -0.053    ,
#         -0.02493  , -0.05536  ,  0.03062  , -0.02174  , -0.00778  ,
#          0.09955  ,  0.0249   ,  0.05048  ,  0.01121  , -0.008934 ,
#          0.04117  , -0.04852  ,  0.00685  , -0.014206 ,  0.01791  ,
#         -0.06177  ,  0.01996  , -0.014984 , -0.02794  ,  0.01671  ,
#          0.0364   , -0.01312  , -0.04105  , -0.0382   ,  0.00746  ,
#         -0.00938  , -0.04288  , -0.03845  , -0.00701  ,  0.01834  ,
#          0.00868  ,  0.03625  ,  0.0324   , -0.01926  ,  0.04022  ,
#         -0.01533  , -0.02669  , -0.009544 , -0.0213   , -0.0413   ,
#         -0.02498  , -0.04285  , -0.05142  ,  0.009735 ,  0.02347  ,
#         -0.02141  , -0.01706  , -0.06088  , -0.01892  , -0.06366  ,
#         -0.04993  , -0.0235   , -0.0251   ,  0.02968  , -0.0156   ,
#         -0.02269  , -0.02936  , -0.01555  ,  0.02118  , -0.011894 ,
#         -0.011696 ,  0.06555  ,  0.03174  ,  0.03696  ,  0.00938  ,
#          0.02147  ,  0.02165  ,  0.02873  , -0.01974  , -0.04608  ,
#          0.01384  , -0.02696  ,  0.03102  ,  0.04288  ,  0.02051  ,
#         -0.0703   ,  0.01973  ,  0.0542   ,  0.0254   ,  0.0334   ,
#         -0.008095 ,  0.02386  , -0.0412   , -0.00309  , -0.0218   ,
#         -0.0235   ,  0.001928 ,  0.008385 , -0.04498  ,  0.04266  ,
#          0.02888  , -0.04272  ,  0.06116  ,  0.02097  , -0.0296   ,
#         -0.0002763,  0.01243  ,  0.00848  ,  0.04132  ,  0.03072  ,
#          0.05374  ,  0.02925  , -0.015    ,  0.03528  , -0.03937  ,
#         -0.0226   ,  0.007835 ,  0.02461  , -0.02551  , -0.10815  ,
#         -0.02896  ,  0.02162  ,  0.02153  , -0.03824  , -0.01053  ,
#         -0.04678  , -0.04376  ,  0.0546   , -0.04724  ,  0.0329   ,
#          0.003067 , -0.012276 ,  0.0323   , -0.02531  ,  0.02226  ,
#          0.01235  , -0.03976  ,  0.02411  ,  0.02266  ,  0.0397   ,
#          0.0333   , -0.03577  , -0.03021  , -0.03836  ,  0.01842  ,
#         -0.006912 ,  0.10394  , -0.007236 , -0.0207   , -0.01689  ,
#         -0.004723 , -0.007385 , -0.0175   ,  0.06067  ,  0.03516  ,
#         -0.006893 , -0.02815  ,  0.03525  ,  0.003881 , -0.007423 ,
#          0.00045  ,  0.067    , -0.0221   , -0.011154 , -0.03436  ,
#          0.006664 , -0.02605  , -0.002316 , -0.0745   ,  0.03653  ,
#          0.0613   ,  0.04288  , -0.01483  ,  0.03397  ,  0.0581   ,
#         -0.0008264,  0.04596  ,  0.02481  , -0.01257  , -0.03467  ,
#          0.0008974, -0.07715  ,  0.04     , -0.05093  , -0.00464  ,
#          0.02815  ,  0.0944   ,  0.0478   , -0.05685  ,  0.0254   ,
#         -0.057    ,  0.00279  , -0.0432   ,  0.02896  ,  0.03888  ,
#         -0.03333  ,  0.001217 ,  0.0753   ,  0.02258  ,  0.0666   ,
#         -0.008316 ,  0.02664  , -0.04196  , -0.04416  ,  0.0417   ,
#         -0.02463  ,  0.00874  , -0.00217  ,  0.03018  ,  0.0013075,
#         -0.03833  ,  0.009705 , -0.0429   ,  0.0636   , -0.0937   ,
#          0.03647  , -0.03717  , -0.0889   ,  0.0717   ,  0.02902  ,
#         -0.01846  ,  0.07385  ,  0.02393  , -0.00996  ,  0.053    ,
#         -0.02885  , -0.0173   , -0.00254  , -0.02313  ,  0.05182  ,
#          0.04544  , -0.05423  ,  0.02753  , -0.04132  , -0.0355   ,
#          0.02061  ,  0.02917  , -0.00798  , -0.03738  , -0.01391  ,
#         -0.02899  ,  0.014145 ,  0.015205 , -0.02524  ,  0.01552  ,
#          0.01762  , -0.04263  , -0.03412  ,  0.04422  , -0.01064  ,
#          0.06433  ,  0.04352  ,  0.0002904,  0.0117   ,  0.03848  ,
#         -0.02419  ,  0.04214  , -0.01624  ,  0.012596 ,  0.03323  ,
#          0.05948  ,  0.0532   ,  0.01177  ,  0.02086  , -0.02708  ,
#          0.02379  , -0.01561  , -0.063    ,  0.07874  , -0.04956  ,
#          0.036    , -0.04468  , -0.03503  ,  0.02672  ,  0.052    ,
#         -0.06104  ,  0.01076  , -0.00631  ,  0.03522  , -0.04593  ,
#          0.0378   ,  0.01808  , -0.01642  ,  0.01558  ,  0.03069  ,
#          0.00958  ,  0.01116  ,  0.04147  ,  0.001041 , -0.015495 ,
#          0.05585  , -0.01242  ,  0.03522  , -0.008995 ,  0.00424  ,
#         -0.03452  , -0.01008  ,  0.04663  ,  0.02756  ,  0.01008  ,
#         -0.02245  ,  0.02312  ,  0.04572  ,  0.04834  ,  0.0486   ,
#         -0.0806   , -0.010704 , -0.0425   ,  0.01307  , -0.01828  ,
#         -0.01749  , -0.01065  ,  0.01321  , -0.003283 ,  0.02884  ,
#         -0.04343  ,  0.02109  ,  0.01881  , -0.03586  ,  0.01918  ,
#         -0.02089  ,  0.00749  ,  0.003038 , -0.000544 , -0.03915  ,
#         -0.02798  , -0.05005  ,  0.00173  , -0.04285  , -0.0319   ,
#          0.04233  ,  0.0273   ,  0.0159   , -0.02339  ,  0.03366  ,
#         -0.02501  ,  0.01397  , -0.00899  ,  0.03528  , -0.1294   ,
#          0.0602   ,  0.0338   , -0.014786 , -0.0007687, -0.0392   ,
#         -0.08875  ,  0.0213   , -0.001197 ,  0.02396  , -0.04642  ,
#         -0.005306 , -0.005413 ,  0.013084 , -0.010475 ,  0.02287  ,
#          0.04523  ,  0.01229  ,  0.05148  ,  0.0706   , -0.00766  ,
#          0.0337   , -0.0295   , -0.04437  ,  0.01569  ,  0.02219  ,
#          0.0383   , -0.0807   ,  0.0386   ,  0.01453  , -0.04578  ,
#         -0.02524  ,  0.0383   ,  0.01624  ,  0.004307 ,  0.01181  ,
#          0.01872  , -0.003138 , -0.000573 ,  0.02475  ,  0.005287 ,
#          0.0006876, -0.03778  , -0.05194  ,  0.03357  , -0.04636  ,
#          0.01006  , -0.02917  , -0.00274  ,  0.04242  , -0.00866  ,
#          0.07074  , -0.04538  , -0.00807  , -0.0209   ,  0.00466  ,
#         -0.019    , -0.03125  ,  0.02213  ,  0.01569  , -0.01938  ,
#         -0.00715  , -0.00954  , -0.01813  , -0.007515 ,  0.01714  ,
#         -0.05273  , -0.01304  , -0.07526  ,  0.00872  , -0.01859  ,
#          0.01217  , -0.0552   ,  0.02882  , -0.0422   , -0.03464  ,
#          0.02483  , -0.02847  , -0.00789  ,  0.02097  ,  0.012184 ,
#         -0.002623 , -0.002563 ,  0.03195  ,  0.004818 ,  0.03632  ,
#         -0.02698  ,  0.02036  , -0.02711  , -0.01198  , -0.007248 ,
#         -0.012505 , -0.03415  , -0.00653  ,  0.03032  , -0.02344  ,
#          0.0278   , -0.03293  ,  0.01482  ,  0.01211  , -0.01389  ,
#          0.01607  , -0.0346   ,  0.006237 ,  0.034    , -0.02649  ,
#          0.02112  ,  0.02856  ,  0.02013  , -0.03717  ,  0.05453  ,
#         -0.0511   ,  0.0357   ,  0.04202  , -0.01831  ,  0.00889  ,
#          0.01974  , -0.01304  , -0.0435   ,  0.05402  , -0.1013   ,
#         -0.03354  ,  0.01683  ,  0.01178  ,  0.0406   , -0.00966  ,
#          0.005653 ,  0.0222   ,  0.01234  , -0.2122   ,  0.013916 ,
#         -0.02902  , -0.04312  ,  0.0698   ,  0.02328  ,  0.02347  ,
#         -0.01351  ,  0.03528  , -0.00716  ,  0.0339   , -0.0682   ,
#          0.01625  , -0.02946  , -0.002653 ,  0.03864  ,  0.003622 ,
#         -0.03275  ,  0.0337   , -0.01437  , -0.01126  ,  0.0814   ,
#         -0.05273  , -0.02802  , -0.03087  , -0.02325  , -0.01432  ,
#          0.01915  ,  0.03702  ,  0.03647  , -0.004623 , -0.0422   ,
#          0.0184   ,  0.03967  , -0.04315  , -0.0269   , -0.05145  ,
#          0.02089  , -0.07     ,  0.03934  ,  0.01619  , -0.02486  ,
#         -0.05756  ,  0.03476  , -0.00179  ,  0.05954  ,  0.02972  ,
#          0.00488  , -0.02232  , -0.03253  ,  0.02168  ,  0.00879  ,
#         -0.11383  , -0.005966 ,  0.005253 ,  0.02261  ,  0.02216  ,
#          0.053    ,  0.02182  , -0.00503  ,  0.06137  ,  0.02898  ,
#         -0.04977  ,  0.02898  , -0.00783  , -0.00283  ,  0.02048  ,
#         -0.04077  ,  0.003035 , -0.0189   ,  0.03488  , -0.01376  ,
#         -0.01886  ,  0.0179   ,  0.0519   , -0.04373  ,  0.01584  ,
#          0.01709  , -0.07     ,  0.02391  , -0.02583  , -0.07135  ,
#         -0.04285  ,  0.01587  , -0.01926  , -0.00868  , -0.02771  ,
#          0.009445 ,  0.0323   ,  0.0111   , -0.04877  , -0.02164  ,
#         -0.008    , -0.0165   ,  0.0412   , -0.0512   , -0.03793  ,
#          0.03287  ,  0.01209  , -0.01732  ,  0.02669  , -0.01093  ,
#         -0.01276  ,  0.0539   ,  0.0376   , -0.03668  , -0.05954  ,
#          0.01936  , -0.05515  , -0.03035  ,  0.0388   ,  0.02798  ,
#          0.02977  , -0.0023   , -0.0182   , -0.02452  ,  0.0249   ,
#         -0.04132  , -0.010994 , -0.05106  , -0.04926  , -0.0392   ,
#          0.02121  , -0.00833  ,  0.01498  , -0.01245  , -0.002457 ,
#          0.0534   ,  0.01492  ,  0.02917  , -0.01689  , -0.01004  ,
#          0.072    ,  0.01131  , -0.03012  ,  0.00887  ,  0.04068  ,
#         -0.00903  ,  0.03818  ,  0.02603  ,  0.09515  , -0.05923  ,
#         -0.01095  ,  0.02255  , -0.03534  ,  0.01888  ,  0.0286   ,
#         -0.0429   ,  0.0226   , -0.003777 , -0.02336  , -0.0786   ,
#          0.0079   , -0.02032  , -0.03284  ,  0.03326  ,  0.0309   ,
#          0.01236  , -0.00649  ,  0.04465  , -0.0136   , -0.04327  ,
#          0.0497   ,  0.02461  ,  0.01648  , -0.01897  , -0.00869  ,
#         -0.039    , -0.007088 ,  0.03665  , -0.0444   , -0.00981  ,
#          0.004868 , -0.01116  ,  0.01107  , -0.002481 ,  0.05164  ,
#         -0.05768  , -0.04785  ,  0.02078  ], dtype=float16)}

# %%
embeddings = [row['embedding'] for row in dataset]
embeddings = np.concat([embeddings])

embeddings.shape
# Out:
# (220065, 768)

# %%
text = "Como diminuir a criminalidade no município?"
k = 1000

indexes_top_k = top_k(text, embeddings, k)

# %%
results = dataset[indexes_top_k]
results = [(row['municipio'], row['data_apresentacao'], row['acao']) for row in results]

pd.DataFrame(
    results,
    columns=['nome', 'data', 'acao']
)
# Out:
#                      nome        data  \
# 0                 Caruaru  2023-06-15
# 1          Guarujá do Sul  2021-09-30
# 2          Campina Grande  2025-09-11
# 3                   Natal  2018-06-06
# 4                 Caruaru  2025-03-11
# ..                    ...         ...
# 995                 Natal  2018-02-20
# 996                 Araxá  2025-10-14
# 997  São Sebastião do Caí  2025-09-30
# 998            Montenegro  2024-07-10
# 999           Constantina  2025-08-29
#
#                                                   acao
# 0    Implementar programa de prevenção às drogas, d...
# 1           Criar o programa “Juro Zero” no município.
# 2    Criar o programa municipal “Dignidade em Foco”...
# 3    Criar o programa “Descarte Consciente” no muni...
# 4    Criar o programa “Mulheres Sem Violência” no m...
# ..                                                 ...
# 995  Instalar faixas de travessia de pedestres em f...
# 996  Criar o programa “Doe uma Praça, Praça Esporti...
# 997  Criar programa municipal de prevenção ao green...
# 998  Criar programa municipal de prevenção ao green...
# 999  Criar programa municipal de prevenção ao green...
#
# [1000 rows x 3 columns]

# %%
uf2score = {}

for idx, row in df.iterrows():
  key = (row['municipio_norm'], row['ano'], row['semestre'])
  uf2score[key] = row['taxa_homicidios_100k']

uf2score
# Out:
# {('CAMPESTRE', 2015, 1): 4.831851565519907,
#  ('CAMPESTRE', 2015, 2): 4.831851565519907,
#  ('CAMPESTRE', 2016, 1): 0.0,
#  ('CAMPESTRE', 2016, 2): 0.0,
#  ('CAMPESTRE', 2017, 1): 0.0,
#  ('CAMPESTRE', 2017, 2): 9.663703131039814,
#  ('CAMPESTRE', 2018, 1): 0.0,
#  ('CAMPESTRE', 2018, 2): 0.0,
#  ('CAMPESTRE', 2019, 1): 9.663703131039814,
#  ('CAMPESTRE', 2019, 2): 0.0,
#  ('CAMPESTRE', 2020, 1): 4.831851565519907,
#  ('CAMPESTRE', 2020, 2): 0.0,
#  ('CAMPESTRE', 2021, 1): 0.0,
#  ('CAMPESTRE', 2021, 2): 4.831851565519907,
#  ('CAMPESTRE', 2022, 1): 0.0,
#  ('CAMPESTRE', 2022, 2): 0.0,
#  ('CAMPESTRE', 2023, 1): 0.0,
#  ('CAMPESTRE', 2023, 2): 4.831851565519907,
#  ('CAMPESTRE', 2024, 1): 4.831851565519907,
#  ('CAMPESTRE', 2024, 2): 0.0,
#  ('CAMPESTRE', 2025, 1): 0.0,
#  ('CAMPESTRE', 2025, 2): 0.0,
#  ('CANARANA', 2015, 1): 0.0,
#  ('CANARANA', 2015, 2): 0.0,
#  ('CANARANA', 2016, 1): 11.601825353855672,
#  ('CANARANA', 2016, 2): 0.0,
#  ('CANARANA', 2017, 1): 7.734550235903781,
#  ('CANARANA', 2017, 2): 27.07092582566324,
#  ('CANARANA', 2018, 1): 15.469100471807565,
#  ('CANARANA', 2018, 2): 23.203650707711347,
#  ('CANARANA', 2019, 1): 3.8672751179518903,
#  ('CANARANA', 2019, 2): 3.8672751179518903,
#  ('CANARANA', 2020, 1): 15.469100471807565,
#  ('CANARANA', 2020, 2): 3.8672751179518903,
#  ('CANARANA', 2021, 1): 7.734550235903781,
#  ('CANARANA', 2021, 2): 23.203650707711347,
#  ('CANARANA', 2022, 1): 11.601825353855672,
#  ('CANARANA', 2022, 2): 3.8672751179518903,
#  ('CANARANA', 2023, 1): 11.601825353855672,
#  ('CANARANA', 2023, 2): 0.0,
#  ('CANARANA', 2024, 1): 15.469100471807565,
#  ('CANARANA', 2024, 2): 19.336375589759456,
#  ('CANARANA', 2025, 1): 7.734550235903781,
#  ('CANARANA', 2025, 2): 3.8672751179518903,
#  ('IGRAPIÚNA', 2015, 1): 30.41593795148658,
#  ('IGRAPIÚNA', 2015, 2): 7.603984487871645,
#  ('IGRAPIÚNA', 2016, 1): 7.603984487871645,
#  ('IGRAPIÚNA', 2016, 2): 68.43586039084481,
#  ('IGRAPIÚNA', 2017, 1): 30.41593795148658,
#  ('IGRAPIÚNA', 2017, 2): 22.81195346361493,
#  ('IGRAPIÚNA', 2018, 1): 45.62390692722987,
#  ('IGRAPIÚNA', 2018, 2): 45.62390692722987,
#  ('IGRAPIÚNA', 2019, 1): 0.0,
#  ('IGRAPIÚNA', 2019, 2): 60.83187590297316,
#  ('IGRAPIÚNA', 2020, 1): 22.81195346361493,
#  ('IGRAPIÚNA', 2020, 2): 76.03984487871645,
#  ('IGRAPIÚNA', 2021, 1): 15.20796897574329,
#  ('IGRAPIÚNA', 2021, 2): 22.81195346361493,
#  ('IGRAPIÚNA', 2022, 1): 15.20796897574329,
#  ('IGRAPIÚNA', 2022, 2): 15.20796897574329,
#  ('IGRAPIÚNA', 2023, 1): 30.41593795148658,
#  ('IGRAPIÚNA', 2023, 2): 15.20796897574329,
#  ('IGRAPIÚNA', 2024, 1): 0.0,
#  ('IGRAPIÚNA', 2024, 2): 0.0,
#  ('IGRAPIÚNA', 2025, 1): 38.01992243935823,
#  ('IGRAPIÚNA', 2025, 2): 15.20796897574329,
#  ('ILHÉUS', 2015, 1): 17.3524620904679,
#  ('ILHÉUS', 2015, 2): 26.308571556515847,
#  ('ILHÉUS', 2016, 1): 26.868328398143845,
#  ('ILHÉUS', 2016, 2): 24.06954419000386,
#  ('ILHÉUS', 2017, 1): 26.868328398143845,
#  ('ILHÉUS', 2017, 2): 25.18905787325986,
#  ('ILHÉUS', 2018, 1): 25.748814714887853,
#  ('ILHÉUS', 2018, 2): 17.3524620904679,
#  ('ILHÉUS', 2019, 1): 22.39027366511987,
#  ('ILHÉUS', 2019, 2): 20.151246298607887,
#  ('ILHÉUS', 2020, 1): 24.629301031631854,
#  ('ILHÉUS', 2020, 2): 22.95003050674787,
#  ('ILHÉUS', 2021, 1): 28.547598923027834,
#  ('ILHÉUS', 2021, 2): 22.39027366511987,
#  ('ILHÉUS', 2022, 1): 22.95003050674787,
#  ('ILHÉUS', 2022, 2): 20.71100314023588,
#  ('ILHÉUS', 2023, 1): 25.18905787325986,
#  ('ILHÉUS', 2023, 2): 21.27075998186388,
#  ('ILHÉUS', 2024, 1): 23.509787348375863,
#  ('ILHÉUS', 2024, 2): 12.874407357443928,
#  ('ILHÉUS', 2025, 1): 8.95610946604795,
#  ('ILHÉUS', 2025, 2): 13.434164199071922,
#  ('ITABERABA', 2015, 1): 15.367356660980745,
#  ('ITABERABA', 2015, 2): 23.05103499147112,
#  ('ITABERABA', 2016, 1): 38.41839165245186,
#  ('ITABERABA', 2016, 2): 26.124506323667266,
#  ('ITABERABA', 2017, 1): 13.83062099488267,
#  ('ITABERABA', 2017, 2): 23.05103499147112,
#  ('ITABERABA', 2018, 1): 36.881655986353785,
#  ('ITABERABA', 2018, 2): 33.808184654157635,
#  ('ITABERABA', 2019, 1): 10.757149662686524,
#  ('ITABERABA', 2019, 2): 18.44082799317689,
#  ('ITABERABA', 2020, 1): 21.514299325373045,
#  ('ITABERABA', 2020, 2): 12.293885328784596,
#  ('ITABERABA', 2021, 1): 12.293885328784596,
#  ('ITABERABA', 2021, 2): 19.977563659274967,
#  ('ITABERABA', 2022, 1): 16.904092327078818,
#  ('ITABERABA', 2022, 2): 10.757149662686524,
#  ('ITABERABA', 2023, 1): 10.757149662686524,
#  ('ITABERABA', 2023, 2): 7.683678330490372,
#  ('ITABERABA', 2024, 1): 9.220413996588446,
#  ('ITABERABA', 2024, 2): 7.683678330490372,
#  ('ITABERABA', 2025, 1): 6.146942664392298,
#  ('ITABERABA', 2025, 2): 12.293885328784596,
#  ('ITABUNA', 2015, 1): 25.17299740771686,
#  ('ITABUNA', 2015, 2): 26.779784476294537,
#  ('ITABUNA', 2016, 1): 38.56288964586413,
#  ('ITABUNA', 2016, 2): 27.85097585534632,
#  ('ITABUNA', 2017, 1): 36.95610257728646,
#  ('ITABUNA', 2017, 2): 23.030614649613295,
#  ('ITABUNA', 2018, 1): 31.06454999250166,
#  ('ITABUNA', 2018, 2): 39.09848533539002,
#  ('ITABUNA', 2019, 1): 37.49169826681235,
#  ('ITABUNA', 2019, 2): 26.779784476294537,
#  ('ITABUNA', 2020, 1): 26.24418878676865,
#  ('ITABUNA', 2020, 2): 13.925487927673158,
#  ('ITABUNA', 2021, 1): 14.46108361719905,
#  ('ITABUNA', 2021, 2): 12.318700859095484,
#  ('ITABUNA', 2022, 1): 8.03393534288836,
#  ('ITABUNA', 2022, 2): 11.783105169569597,
#  ('ITABUNA', 2023, 1): 15.53227499625083,
#  ('ITABUNA', 2023, 2): 6.962743963836579,
#  ('ITABUNA', 2024, 1): 8.56953103241425,
#  ('ITABUNA', 2024, 2): 4.8203612057330165,
#  ('ITABUNA', 2025, 1): 7.498339653362469,
#  ('ITABUNA', 2025, 2): 3.213574137155344,
#  ('ITAGIBÁ', 2015, 1): 13.063357282821686,
#  ('ITAGIBÁ', 2015, 2): 0.0,
#  ('ITAGIBÁ', 2016, 1): 19.595035924232526,
#  ('ITAGIBÁ', 2016, 2): 6.531678641410843,
#  ('ITAGIBÁ', 2017, 1): 13.063357282821686,
#  ('ITAGIBÁ', 2017, 2): 6.531678641410843,
#  ('ITAGIBÁ', 2018, 1): 0.0,
#  ('ITAGIBÁ', 2018, 2): 0.0,
#  ('ITAGIBÁ', 2019, 1): 13.063357282821686,
#  ('ITAGIBÁ', 2019, 2): 19.595035924232526,
#  ('ITAGIBÁ', 2020, 1): 6.531678641410843,
#  ('ITAGIBÁ', 2020, 2): 6.531678641410843,
#  ('ITAGIBÁ', 2021, 1): 0.0,
#  ('ITAGIBÁ', 2021, 2): 6.531678641410843,
#  ('ITAGIBÁ', 2022, 1): 19.595035924232526,
#  ('ITAGIBÁ', 2022, 2): 19.595035924232526,
#  ('ITAGIBÁ', 2023, 1): 13.063357282821686,
#  ('ITAGIBÁ', 2023, 2): 13.063357282821686,
#  ('ITAGIBÁ', 2024, 1): 6.531678641410843,
#  ('ITAGIBÁ', 2024, 2): 19.595035924232526,
#  ('ITAGIBÁ', 2025, 1): 13.063357282821686,
#  ('ITAGIBÁ', 2025, 2): 32.65839320705422,
#  ('ITANHÉM', 2015, 1): 33.68326503115702,
#  ('ITANHÉM', 2015, 2): 11.227755010385671,
#  ('ITANHÉM', 2016, 1): 28.06938752596418,
#  ('ITANHÉM', 2016, 2): 11.227755010385671,
#  ('ITANHÉM', 2017, 1): 22.455510020771342,
#  ('ITANHÉM', 2017, 2): 28.06938752596418,
#  ('ITANHÉM', 2018, 1): 11.227755010385671,
#  ('ITANHÉM', 2018, 2): 39.29714253634986,
#  ('ITANHÉM', 2019, 1): 22.455510020771342,
#  ('ITANHÉM', 2019, 2): 28.06938752596418,
#  ('ITANHÉM', 2020, 1): 16.84163251557851,
#  ('ITANHÉM', 2020, 2): 22.455510020771342,
#  ('ITANHÉM', 2021, 1): 22.455510020771342,
#  ('ITANHÉM', 2021, 2): 16.84163251557851,
#  ('ITANHÉM', 2022, 1): 11.227755010385671,
#  ('ITANHÉM', 2022, 2): 28.06938752596418,
#  ('ITANHÉM', 2023, 1): 39.29714253634986,
#  ('ITANHÉM', 2023, 2): 11.227755010385671,
#  ('ITANHÉM', 2024, 1): 5.6138775051928365,
#  ('ITANHÉM', 2024, 2): 5.6138775051928365,
#  ('ITANHÉM', 2025, 1): 11.227755010385671,
#  ('ITANHÉM', 2025, 2): 5.6138775051928365,
#  ('ITAPETINGA', 2015, 1): 25.79783601681412,
#  ('ITAPETINGA', 2015, 2): 13.657677891254536,
#  ('ITAPETINGA', 2016, 1): 6.070079062779793,
#  ('ITAPETINGA', 2016, 2): 9.105118594169689,
#  ('ITAPETINGA', 2017, 1): 19.727756954034326,
#  ('ITAPETINGA', 2017, 2): 21.24527671972928,
#  ('ITAPETINGA', 2018, 1): 13.657677891254536,
#  ('ITAPETINGA', 2018, 2): 7.587598828474741,
#  ('ITAPETINGA', 2019, 1): 12.140158125559584,
#  ('ITAPETINGA', 2019, 2): 12.140158125559584,
#  ('ITAPETINGA', 2020, 1): 16.692717422644428,
#  ('ITAPETINGA', 2020, 2): 13.657677891254536,
#  ('ITAPETINGA', 2021, 1): 3.0350395313898964,
#  ('ITAPETINGA', 2021, 2): 9.105118594169689,
#  ('ITAPETINGA', 2022, 1): 12.140158125559584,
#  ('ITAPETINGA', 2022, 2): 7.587598828474741,
#  ('ITAPETINGA', 2023, 1): 18.210237188339377,
#  ('ITAPETINGA', 2023, 2): 1.5175197656949482,
#  ('ITAPETINGA', 2024, 1): 10.622638359864638,
#  ('ITAPETINGA', 2024, 2): 10.622638359864638,
#  ('ITAPETINGA', 2025, 1): 4.552559297084844,
#  ('ITAPETINGA', 2025, 2): 4.552559297084844,
#  ('JEQUIÉ', 2015, 1): 27.075869103914663,
#  ('JEQUIÉ', 2015, 2): 25.81652635489538,
#  ('JEQUIÉ', 2016, 1): 31.48356872548217,
#  ('JEQUIÉ', 2016, 2): 28.9648832274436,
#  ('JEQUIÉ', 2017, 1): 25.81652635489538,
#  ('JEQUIÉ', 2017, 2): 23.92751223136645,
#  ('JEQUIÉ', 2018, 1): 22.668169482347164,
#  ('JEQUIÉ', 2018, 2): 5.667042370586791,
#  ('JEQUIÉ', 2019, 1): 6.296713745096434,
#  ('JEQUIÉ', 2019, 2): 11.334084741173582,
#  ('JEQUIÉ', 2020, 1): 15.112112988231445,
#  ('JEQUIÉ', 2020, 2): 8.185727868625364,
#  ('JEQUIÉ', 2021, 1): 22.03849810783752,
#  ('JEQUIÉ', 2021, 2): 18.260469860779654,
#  ('JEQUIÉ', 2022, 1): 24.55718360587609,
#  ('JEQUIÉ', 2022, 2): 39.669296594107536,
#  ('JEQUIÉ', 2023, 1): 22.668169482347164,
#  ('JEQUIÉ', 2023, 2): 12.593427490192868,
#  ('JEQUIÉ', 2024, 1): 24.55718360587609,
#  ('JEQUIÉ', 2024, 2): 28.9648832274436,
#  ('JEQUIÉ', 2025, 1): 25.81652635489538,
#  ('JEQUIÉ', 2025, 2): 17.630798486270017,
#  ('JUAZEIRO', 2015, 1): 29.0134176544544,
#  ('JUAZEIRO', 2015, 2): 25.229058829960348,
#  ('JUAZEIRO', 2016, 1): 23.96760588846233,
#  ('JUAZEIRO', 2016, 2): 16.398888239474225,
#  ('JUAZEIRO', 2017, 1): 26.91099608529104,
#  ('JUAZEIRO', 2017, 2): 20.18324706396828,
#  ('JUAZEIRO', 2018, 1): 22.28566863313164,
#  ('JUAZEIRO', 2018, 2): 12.614529414980174,
#  ('JUAZEIRO', 2019, 1): 23.96760588846233,
#  ('JUAZEIRO', 2019, 2): 17.660341180972246,
#  ('JUAZEIRO', 2020, 1): 19.762762750135604,
#  ('JUAZEIRO', 2020, 2): 25.229058829960348,
#  ('JUAZEIRO', 2021, 1): 28.592933340621727,
#  ('JUAZEIRO', 2021, 2): 28.592933340621727,
#  ('JUAZEIRO', 2022, 1): 28.592933340621727,
#  ('JUAZEIRO', 2022, 2): 34.05922942044647,
#  ('JUAZEIRO', 2023, 1): 35.74116667577716,
#  ('JUAZEIRO', 2023, 2): 29.433901968287078,
#  ('JUAZEIRO', 2024, 1): 26.91099608529104,
#  ('JUAZEIRO', 2024, 2): 34.479713734279144,
#  ('JUAZEIRO', 2025, 1): 23.126637260796983,
#  ('JUAZEIRO', 2025, 2): 10.512107845816812,
#  ('MANOEL VITORINO', 2015, 1): 0.0,
#  ('MANOEL VITORINO', 2015, 2): 7.215007215007215,
#  ('MANOEL VITORINO', 2016, 1): 14.43001443001443,
#  ('MANOEL VITORINO', 2016, 2): 0.0,
#  ('MANOEL VITORINO', 2017, 1): 0.0,
#  ('MANOEL VITORINO', 2017, 2): 7.215007215007215,
#  ('MANOEL VITORINO', 2018, 1): 0.0,
#  ('MANOEL VITORINO', 2018, 2): 7.215007215007215,
#  ('MANOEL VITORINO', 2019, 1): 7.215007215007215,
#  ('MANOEL VITORINO', 2019, 2): 14.43001443001443,
#  ('MANOEL VITORINO', 2020, 1): 7.215007215007215,
#  ('MANOEL VITORINO', 2020, 2): 21.645021645021647,
#  ('MANOEL VITORINO', 2021, 1): 7.215007215007215,
#  ('MANOEL VITORINO', 2021, 2): 7.215007215007215,
#  ('MANOEL VITORINO', 2022, 1): 7.215007215007215,
#  ('MANOEL VITORINO', 2022, 2): 7.215007215007215,
#  ('MANOEL VITORINO', 2023, 1): 14.43001443001443,
#  ('MANOEL VITORINO', 2023, 2): 7.215007215007215,
#  ('MANOEL VITORINO', 2024, 1): 0.0,
#  ('MANOEL VITORINO', 2024, 2): 0.0,
#  ('MANOEL VITORINO', 2025, 1): 7.215007215007215,
#  ('MANOEL VITORINO', 2025, 2): 0.0,
#  ('MARACÁS', 2015, 1): 3.620564808110065,
#  ('MARACÁS', 2015, 2): 14.48225923244026,
#  ('MARACÁS', 2016, 1): 7.24112961622013,
#  ('MARACÁS', 2016, 2): 3.620564808110065,
#  ('MARACÁS', 2017, 1): 18.102824040550324,
#  ('MARACÁS', 2017, 2): 10.861694424330196,
#  ('MARACÁS', 2018, 1): 3.620564808110065,
#  ('MARACÁS', 2018, 2): 3.620564808110065,
#  ('MARACÁS', 2019, 1): 10.861694424330196,
#  ('MARACÁS', 2019, 2): 14.48225923244026,
#  ('MARACÁS', 2020, 1): 7.24112961622013,
#  ('MARACÁS', 2020, 2): 3.620564808110065,
#  ('MARACÁS', 2021, 1): 3.620564808110065,
#  ('MARACÁS', 2021, 2): 3.620564808110065,
#  ('MARACÁS', 2022, 1): 3.620564808110065,
#  ('MARACÁS', 2022, 2): 14.48225923244026,
#  ('MARACÁS', 2023, 1): 3.620564808110065,
#  ('MARACÁS', 2023, 2): 3.620564808110065,
#  ('MARACÁS', 2024, 1): 7.24112961622013,
#  ('MARACÁS', 2024, 2): 3.620564808110065,
#  ('MARACÁS', 2025, 1): 14.48225923244026,
#  ('MARACÁS', 2025, 2): 10.861694424330196,
#  ('MATA DE SÃO JOÃO', 2015, 1): 49.33515011981394,
#  ('MATA DE SÃO JOÃO', 2015, 2): 49.33515011981394,
#  ('MATA DE SÃO JOÃO', 2016, 1): 63.430907296903634,
#  ('MATA DE SÃO JOÃO', 2016, 2): 51.68444298266223,
#  ('MATA DE SÃO JOÃO', 2017, 1): 46.98585725696565,
#  ('MATA DE SÃO JOÃO', 2017, 2): 37.58868580557253,
#  ('MATA DE SÃO JOÃO', 2018, 1): 63.430907296903634,
#  ('MATA DE SÃO JOÃO', 2018, 2): 39.9379786684208,
#  ('MATA DE SÃO JOÃO', 2019, 1): 49.33515011981394,
#  ('MATA DE SÃO JOÃO', 2019, 2): 35.239392942724244,
#  ('MATA DE SÃO JOÃO', 2020, 1): 30.54080721702768,
#  ('MATA DE SÃO JOÃO', 2020, 2): 46.98585725696565,
#  ('MATA DE SÃO JOÃO', 2021, 1): 30.54080721702768,
#  ('MATA DE SÃO JOÃO', 2021, 2): 37.58868580557253,
#  ('MATA DE SÃO JOÃO', 2022, 1): 56.38302870835879,
#  ('MATA DE SÃO JOÃO', 2022, 2): 42.28727153126909,
#  ('MATA DE SÃO JOÃO', 2023, 1): 72.82807874829676,
#  ('MATA DE SÃO JOÃO', 2023, 2): 49.33515011981394,
#  ('MATA DE SÃO JOÃO', 2024, 1): 28.191514354179397,
#  ('MATA DE SÃO JOÃO', 2024, 2): 14.095757177089697,
#  ('MATA DE SÃO JOÃO', 2025, 1): 18.794342902786266,
#  ('MATA DE SÃO JOÃO', 2025, 2): 14.095757177089697,
#  ('MIRANTE', 2015, 1): 0.0,
#  ('MIRANTE', 2015, 2): 9.816432708353783,
#  ('MIRANTE', 2016, 1): 0.0,
#  ('MIRANTE', 2016, 2): 0.0,
#  ('MIRANTE', 2017, 1): 9.816432708353783,
#  ('MIRANTE', 2017, 2): 0.0,
#  ('MIRANTE', 2018, 1): 0.0,
#  ('MIRANTE', 2018, 2): 0.0,
#  ('MIRANTE', 2019, 1): 0.0,
#  ('MIRANTE', 2019, 2): 19.63286541670757,
#  ('MIRANTE', 2020, 1): 0.0,
#  ('MIRANTE', 2020, 2): 0.0,
#  ('MIRANTE', 2021, 1): 0.0,
#  ('MIRANTE', 2021, 2): 0.0,
#  ('MIRANTE', 2022, 1): 0.0,
#  ('MIRANTE', 2022, 2): 0.0,
#  ('MIRANTE', 2023, 1): 0.0,
#  ('MIRANTE', 2023, 2): 0.0,
#  ('MIRANTE', 2024, 1): 0.0,
#  ('MIRANTE', 2024, 2): 0.0,
#  ('MIRANTE', 2025, 1): 0.0,
#  ('MIRANTE', 2025, 2): 0.0,
#  ('MURITIBA', 2015, 1): 24.3842965130456,
#  ('MURITIBA', 2015, 2): 6.966941860870171,
#  ('MURITIBA', 2016, 1): 17.417354652175426,
#  ('MURITIBA', 2016, 2): 24.3842965130456,
#  ('MURITIBA', 2017, 1): 31.35123837391577,
#  ('MURITIBA', 2017, 2): 27.867767443480684,
#  ('MURITIBA', 2018, 1): 17.417354652175426,
#  ('MURITIBA', 2018, 2): 10.450412791305256,
#  ('MURITIBA', 2019, 1): 10.450412791305256,
#  ('MURITIBA', 2019, 2): 10.450412791305256,
#  ('MURITIBA', 2020, 1): 3.483470930435085,
#  ('MURITIBA', 2020, 2): 13.933883721740342,
#  ('MURITIBA', 2021, 1): 13.933883721740342,
#  ('MURITIBA', 2021, 2): 10.450412791305256,
#  ('MURITIBA', 2022, 1): 6.966941860870171,
#  ('MURITIBA', 2022, 2): 13.933883721740342,
#  ('MURITIBA', 2023, 1): 10.450412791305256,
#  ('MURITIBA', 2023, 2): 0.0,
#  ('MURITIBA', 2024, 1): 20.900825582610512,
#  ('MURITIBA', 2024, 2): 6.966941860870171,
#  ('MURITIBA', 2025, 1): 0.0,
#  ('MURITIBA', 2025, 2): 6.966941860870171,
#  ('PARIPIRANGA', 2015, 1): 0.0,
#  ('PARIPIRANGA', 2015, 2): 3.758833258156669,
#  ('PARIPIRANGA', 2016, 1): 7.517666516313337,
#  ('PARIPIRANGA', 2016, 2): 3.758833258156669,
#  ('PARIPIRANGA', 2017, 1): 11.276499774470004,
#  ('PARIPIRANGA', 2017, 2): 7.517666516313337,
#  ('PARIPIRANGA', 2018, 1): 0.0,
#  ('PARIPIRANGA', 2018, 2): 3.758833258156669,
#  ('PARIPIRANGA', 2019, 1): 3.758833258156669,
#  ('PARIPIRANGA', 2019, 2): 11.276499774470004,
#  ('PARIPIRANGA', 2020, 1): 3.758833258156669,
#  ('PARIPIRANGA', 2020, 2): 0.0,
#  ('PARIPIRANGA', 2021, 1): 0.0,
#  ('PARIPIRANGA', 2021, 2): 0.0,
#  ('PARIPIRANGA', 2022, 1): 15.035333032626674,
#  ('PARIPIRANGA', 2022, 2): 7.517666516313337,
#  ('PARIPIRANGA', 2023, 1): 3.758833258156669,
#  ('PARIPIRANGA', 2023, 2): 0.0,
#  ('PARIPIRANGA', 2024, 1): 3.758833258156669,
#  ('PARIPIRANGA', 2024, 2): 7.517666516313337,
#  ('PARIPIRANGA', 2025, 1): 3.758833258156669,
#  ('PARIPIRANGA', 2025, 2): 11.276499774470004,
#  ('PAULO AFONSO', 2015, 1): 30.123150527155133,
#  ('PAULO AFONSO', 2015, 2): 20.377425356604945,
#  ('PAULO AFONSO', 2016, 1): 18.60547532559582,
#  ('PAULO AFONSO', 2016, 2): 25.69327544963232,
#  ('PAULO AFONSO', 2017, 1): 15.061575263577566,
#  ('PAULO AFONSO', 2017, 2): 15.061575263577566,
#  ('PAULO AFONSO', 2018, 1): 12.40365021706388,
#  ('PAULO AFONSO', 2018, 2): 11.517675201559316,
#  ('PAULO AFONSO', 2019, 1): 13.28962523256844,
#  ('PAULO AFONSO', 2019, 2): 14.175600248073003,
#  ('PAULO AFONSO', 2020, 1): 15.947550279082131,
#  ('PAULO AFONSO', 2020, 2): 12.40365021706388,
#  ('PAULO AFONSO', 2021, 1): 10.631700186054752,
#  ('PAULO AFONSO', 2021, 2): 15.061575263577566,
#  ('PAULO AFONSO', 2022, 1): 14.175600248073003,
#  ('PAULO AFONSO', 2022, 2): 20.377425356604945,
#  ('PAULO AFONSO', 2023, 1): 19.49145034110038,
#  ('PAULO AFONSO', 2023, 2): 13.28962523256844,
#  ('PAULO AFONSO', 2024, 1): 20.377425356604945,
#  ('PAULO AFONSO', 2024, 2): 14.175600248073003,
#  ('PAULO AFONSO', 2025, 1): 17.719500310091256,
#  ('PAULO AFONSO', 2025, 2): 4.429875077522814,
#  ('PILÃO ARCADO', 2015, 1): 2.8282942557343667,
#  ('PILÃO ARCADO', 2015, 2): 5.656588511468733,
#  ('PILÃO ARCADO', 2016, 1): 8.4848827672031,
#  ('PILÃO ARCADO', 2016, 2): 5.656588511468733,
#  ('PILÃO ARCADO', 2017, 1): 5.656588511468733,
#  ('PILÃO ARCADO', 2017, 2): 5.656588511468733,
#  ('PILÃO ARCADO', 2018, 1): 8.4848827672031,
#  ('PILÃO ARCADO', 2018, 2): 2.8282942557343667,
#  ('PILÃO ARCADO', 2019, 1): 2.8282942557343667,
#  ('PILÃO ARCADO', 2019, 2): 5.656588511468733,
#  ('PILÃO ARCADO', 2020, 1): 0.0,
#  ('PILÃO ARCADO', 2020, 2): 8.4848827672031,
#  ('PILÃO ARCADO', 2021, 1): 2.8282942557343667,
#  ('PILÃO ARCADO', 2021, 2): 5.656588511468733,
#  ('PILÃO ARCADO', 2022, 1): 8.4848827672031,
#  ('PILÃO ARCADO', 2022, 2): 16.9697655344062,
#  ('PILÃO ARCADO', 2023, 1): 11.313177022937468,
#  ('PILÃO ARCADO', 2023, 2): 2.8282942557343667,
#  ('PILÃO ARCADO', 2024, 1): 5.656588511468733,
#  ('PILÃO ARCADO', 2024, 2): 8.4848827672031,
#  ('PILÃO ARCADO', 2025, 1): 2.8282942557343667,
#  ('PILÃO ARCADO', 2025, 2): 5.656588511468733,
#  ('SÍTIO DO QUINTO', 2015, 1): 20.307317403371016,
#  ('SÍTIO DO QUINTO', 2015, 2): 0.0,
#  ('SÍTIO DO QUINTO', 2016, 1): 20.307317403371016,
#  ('SÍTIO DO QUINTO', 2016, 2): 40.61463480674203,
#  ('SÍTIO DO QUINTO', 2017, 1): 0.0,
#  ('SÍTIO DO QUINTO', 2017, 2): 13.538211602247342,
#  ('SÍTIO DO QUINTO', 2018, 1): 13.538211602247342,
#  ('SÍTIO DO QUINTO', 2018, 2): 6.769105801123671,
#  ('SÍTIO DO QUINTO', 2019, 1): 6.769105801123671,
#  ('SÍTIO DO QUINTO', 2019, 2): 0.0,
#  ('SÍTIO DO QUINTO', 2020, 1): 13.538211602247342,
#  ('SÍTIO DO QUINTO', 2020, 2): 20.307317403371016,
#  ('SÍTIO DO QUINTO', 2021, 1): 13.538211602247342,
#  ('SÍTIO DO QUINTO', 2021, 2): 6.769105801123671,
#  ('SÍTIO DO QUINTO', 2022, 1): 0.0,
#  ('SÍTIO DO QUINTO', 2022, 2): 13.538211602247342,
#  ('SÍTIO DO QUINTO', 2023, 1): 0.0,
#  ('SÍTIO DO QUINTO', 2023, 2): 20.307317403371016,
#  ('SÍTIO DO QUINTO', 2024, 1): 6.769105801123671,
#  ('SÍTIO DO QUINTO', 2024, 2): 6.769105801123671,
#  ('SÍTIO DO QUINTO', 2025, 1): 6.769105801123671,
#  ('SÍTIO DO QUINTO', 2025, 2): 0.0,
#  ('ITAIÇABA', 2015, 1): 13.26963906581741,
#  ('ITAIÇABA', 2015, 2): 13.26963906581741,
#  ('ITAIÇABA', 2016, 1): 13.26963906581741,
#  ('ITAIÇABA', 2016, 2): 13.26963906581741,
#  ('ITAIÇABA', 2017, 1): 0.0,
#  ('ITAIÇABA', 2017, 2): 0.0,
#  ('ITAIÇABA', 2018, 1): 13.26963906581741,
#  ('ITAIÇABA', 2018, 2): 0.0,
#  ('ITAIÇABA', 2019, 1): 0.0,
#  ('ITAIÇABA', 2019, 2): 0.0,
#  ('ITAIÇABA', 2020, 1): 0.0,
#  ('ITAIÇABA', 2020, 2): 26.53927813163482,
#  ('ITAIÇABA', 2021, 1): 0.0,
#  ('ITAIÇABA', 2021, 2): 0.0,
#  ('ITAIÇABA', 2022, 1): 26.53927813163482,
#  ('ITAIÇABA', 2022, 2): 13.26963906581741,
#  ('ITAIÇABA', 2023, 1): 0.0,
#  ('ITAIÇABA', 2023, 2): 39.80891719745223,
#  ('ITAIÇABA', 2024, 1): 66.34819532908705,
#  ('ITAIÇABA', 2024, 2): 13.26963906581741,
#  ('ITAIÇABA', 2025, 1): 13.26963906581741,
#  ('ITAIÇABA', 2025, 2): 13.26963906581741,
#  ('MUCURICI', 2016, 1): 0.0,
#  ('MUCURICI', 2016, 2): 0.0,
#  ('MUCURICI', 2017, 1): 18.294914013904133,
#  ('MUCURICI', 2017, 2): 0.0,
#  ('MUCURICI', 2018, 1): 0.0,
#  ('MUCURICI', 2018, 2): 0.0,
#  ('MUCURICI', 2019, 1): 0.0,
#  ('MUCURICI', 2019, 2): 18.294914013904133,
#  ('MUCURICI', 2020, 1): 0.0,
#  ('MUCURICI', 2020, 2): 0.0,
#  ('MUCURICI', 2021, 1): 18.294914013904133,
#  ('MUCURICI', 2021, 2): 0.0,
#  ('MUCURICI', 2022, 1): 0.0,
#  ('MUCURICI', 2022, 2): 0.0,
#  ('MUCURICI', 2023, 1): 0.0,
#  ('MUCURICI', 2023, 2): 0.0,
#  ('MUCURICI', 2024, 1): 0.0,
#  ('MUCURICI', 2024, 2): 0.0,
#  ('MUCURICI', 2025, 1): 54.88474204171241,
#  ('MUCURICI', 2025, 2): 18.294914013904133,
#  ('SÃO MATEUS', 2016, 1): 14.545219471200465,
#  ('SÃO MATEUS', 2016, 2): 20.201693710000647,
#  ('SÃO MATEUS', 2017, 1): 35.554980929601136,
#  ('SÃO MATEUS', 2017, 2): 19.39362596160062,
#  ('SÃO MATEUS', 2018, 1): 28.282371194000905,
#  ('SÃO MATEUS', 2018, 2): 15.35328721960049,
#  ('SÃO MATEUS', 2019, 1): 13.73715172280044,
#  ('SÃO MATEUS', 2019, 2): 12.929083974400411,
#  ('SÃO MATEUS', 2020, 1): 13.73715172280044,
#  ('SÃO MATEUS', 2020, 2): 16.161354968000516,
#  ('SÃO MATEUS', 2021, 1): 21.00976145840067,
#  ('SÃO MATEUS', 2021, 2): 14.545219471200465,
#  ('SÃO MATEUS', 2022, 1): 12.929083974400411,
#  ('SÃO MATEUS', 2022, 2): 20.201693710000647,
#  ('SÃO MATEUS', 2023, 1): 11.31294847760036,
#  ('SÃO MATEUS', 2023, 2): 17.777490464800568,
#  ('SÃO MATEUS', 2024, 1): 16.161354968000516,
#  ('SÃO MATEUS', 2024, 2): 13.73715172280044,
#  ('SÃO MATEUS', 2025, 1): 14.545219471200465,
#  ('SÃO MATEUS', 2025, 2): 12.121016226000387,
#  ('ALVORADA DO NORTE', 2015, 1): 0.0,
#  ('ALVORADA DO NORTE', 2015, 2): 0.0,
#  ('ALVORADA DO NORTE', 2016, 1): 0.0,
#  ('ALVORADA DO NORTE', 2016, 2): 71.03954534690979,
#  ('ALVORADA DO NORTE', 2017, 1): 23.679848448969928,
#  ('ALVORADA DO NORTE', 2017, 2): 71.03954534690979,
#  ('ALVORADA DO NORTE', 2018, 1): 59.199621122424816,
#  ('ALVORADA DO NORTE', 2018, 2): 0.0,
#  ('ALVORADA DO NORTE', 2019, 1): 35.519772673454895,
#  ('ALVORADA DO NORTE', 2019, 2): 23.679848448969928,
#  ('ALVORADA DO NORTE', 2020, 1): 11.839924224484964,
#  ('ALVORADA DO NORTE', 2020, 2): 11.839924224484964,
#  ('ALVORADA DO NORTE', 2021, 1): 23.679848448969928,
#  ('ALVORADA DO NORTE', 2021, 2): 0.0,
#  ('ALVORADA DO NORTE', 2022, 1): 11.839924224484964,
#  ('ALVORADA DO NORTE', 2022, 2): 23.679848448969928,
#  ('ALVORADA DO NORTE', 2023, 1): 0.0,
#  ('ALVORADA DO NORTE', 2023, 2): 23.679848448969928,
#  ('ALVORADA DO NORTE', 2024, 1): 11.839924224484964,
#  ('ALVORADA DO NORTE', 2024, 2): 47.359696897939855,
#  ('ALVORADA DO NORTE', 2025, 1): 0.0,
#  ('ALVORADA DO NORTE', 2025, 2): 0.0,
#  ('ANÁPOLIS', 2015, 1): 0.0,
#  ('ANÁPOLIS', 2015, 2): 0.0,
#  ('ANÁPOLIS', 2016, 1): 13.03686172653177,
#  ('ANÁPOLIS', 2016, 2): 23.566634659499734,
#  ('ANÁPOLIS', 2017, 1): 21.05954586593593,
#  ('ANÁPOLIS', 2017, 2): 21.310254745292315,
#  ('ANÁPOLIS', 2018, 1): 17.048203796233853,
#  ('ANÁPOLIS', 2018, 2): 13.538279485244528,
#  ('ANÁPOLIS', 2019, 1): 16.04536827880833,
#  ('ANÁPOLIS', 2019, 2): 11.031190691680727,
#  ('ANÁPOLIS', 2020, 1): 7.521266380691405,
#  ('ANÁPOLIS', 2020, 2): 5.515595345840364,
#  ('ANÁPOLIS', 2021, 1): 8.022684139404165,
#  ('ANÁPOLIS', 2021, 2): 6.017013104553124,
#  ('ANÁPOLIS', 2022, 1): 7.019848621978644,
#  ('ANÁPOLIS', 2022, 2): 4.512759828414843,
#  ('ANÁPOLIS', 2023, 1): 3.760633190345703,
#  ('ANÁPOLIS', 2023, 2): 4.763468707771223,
#  ('ANÁPOLIS', 2024, 1): 3.008506552276562,
#  ('ANÁPOLIS', 2024, 2): 2.2563799142074217,
#  ('ANÁPOLIS', 2025, 1): 5.264886466483984,
#  ('ANÁPOLIS', 2025, 2): 3.760633190345703,
#  ('BONÓPOLIS', 2015, 1): 0.0,
#  ('BONÓPOLIS', 2015, 2): 0.0,
#  ('BONÓPOLIS', 2016, 1): 0.0,
#  ('BONÓPOLIS', 2016, 2): 30.31221582297666,
#  ('BONÓPOLIS', 2017, 1): 0.0,
#  ('BONÓPOLIS', 2017, 2): 0.0,
#  ('BONÓPOLIS', 2018, 1): 0.0,
#  ('BONÓPOLIS', 2018, 2): 30.31221582297666,
#  ('BONÓPOLIS', 2019, 1): 0.0,
#  ('BONÓPOLIS', 2019, 2): 0.0,
#  ('BONÓPOLIS', 2020, 1): 30.31221582297666,
#  ('BONÓPOLIS', 2020, 2): 0.0,
#  ('BONÓPOLIS', 2021, 1): 0.0,
#  ('BONÓPOLIS', 2021, 2): 0.0,
#  ('BONÓPOLIS', 2022, 1): 30.31221582297666,
#  ('BONÓPOLIS', 2022, 2): 60.62443164595332,
#  ('BONÓPOLIS', 2023, 1): 30.31221582297666,
#  ('BONÓPOLIS', 2023, 2): 0.0,
#  ('BONÓPOLIS', 2024, 1): 0.0,
#  ('BONÓPOLIS', 2024, 2): 0.0,
#  ('BONÓPOLIS', 2025, 1): 0.0,
#  ('BONÓPOLIS', 2025, 2): 0.0,
#  ('CAMPINORTE', 2015, 1): 0.0,
#  ('CAMPINORTE', 2015, 2): 0.0,
#  ('CAMPINORTE', 2016, 1): 0.0,
#  ('CAMPINORTE', 2016, 2): 15.987210231814547,
#  ('CAMPINORTE', 2017, 1): 15.987210231814547,
#  ('CAMPINORTE', 2017, 2): 7.993605115907274,
#  ('CAMPINORTE', 2018, 1): 7.993605115907274,
#  ('CAMPINORTE', 2018, 2): 31.974420463629095,
#  ('CAMPINORTE', 2019, 1): 0.0,
#  ('CAMPINORTE', 2019, 2): 7.993605115907274,
#  ('CAMPINORTE', 2020, 1): 15.987210231814547,
#  ('CAMPINORTE', 2020, 2): 15.987210231814547,
#  ('CAMPINORTE', 2021, 1): 7.993605115907274,
#  ('CAMPINORTE', 2021, 2): 0.0,
#  ('CAMPINORTE', 2022, 1): 0.0,
#  ('CAMPINORTE', 2022, 2): 0.0,
#  ('CAMPINORTE', 2023, 1): 15.987210231814547,
#  ('CAMPINORTE', 2023, 2): 15.987210231814547,
#  ('CAMPINORTE', 2024, 1): 15.987210231814547,
#  ('CAMPINORTE', 2024, 2): 7.993605115907274,
#  ('CAMPINORTE', 2025, 1): 7.993605115907274,
#  ('CAMPINORTE', 2025, 2): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2015, 1): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2015, 2): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2016, 1): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2016, 2): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2017, 1): 26.946914578280783,
#  ('CAMPO ALEGRE DE GOIÁS', 2017, 2): 13.473457289140391,
#  ('CAMPO ALEGRE DE GOIÁS', 2018, 1): 13.473457289140391,
#  ('CAMPO ALEGRE DE GOIÁS', 2018, 2): 13.473457289140391,
#  ('CAMPO ALEGRE DE GOIÁS', 2019, 1): 26.946914578280783,
#  ('CAMPO ALEGRE DE GOIÁS', 2019, 2): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2020, 1): 13.473457289140391,
#  ('CAMPO ALEGRE DE GOIÁS', 2020, 2): 13.473457289140391,
#  ('CAMPO ALEGRE DE GOIÁS', 2021, 1): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2021, 2): 13.473457289140391,
#  ('CAMPO ALEGRE DE GOIÁS', 2022, 1): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2022, 2): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2023, 1): 13.473457289140391,
#  ('CAMPO ALEGRE DE GOIÁS', 2023, 2): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2024, 1): 13.473457289140391,
#  ('CAMPO ALEGRE DE GOIÁS', 2024, 2): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2025, 1): 0.0,
#  ('CAMPO ALEGRE DE GOIÁS', 2025, 2): 0.0,
#  ('CAMPOS BELOS', 2015, 1): 0.0,
#  ('CAMPOS BELOS', 2015, 2): 0.0,
#  ('CAMPOS BELOS', 2016, 1): 5.52242102937928,
#  ('CAMPOS BELOS', 2016, 2): 16.56726308813784,
#  ('CAMPOS BELOS', 2017, 1): 16.56726308813784,
#  ('CAMPOS BELOS', 2017, 2): 27.6121051468964,
#  ('CAMPOS BELOS', 2018, 1): 16.56726308813784,
#  ('CAMPOS BELOS', 2018, 2): 5.52242102937928,
#  ('CAMPOS BELOS', 2019, 1): 27.6121051468964,
#  ('CAMPOS BELOS', 2019, 2): 0.0,
#  ('CAMPOS BELOS', 2020, 1): 5.52242102937928,
#  ('CAMPOS BELOS', 2020, 2): 16.56726308813784,
#  ('CAMPOS BELOS', 2021, 1): 11.04484205875856,
#  ('CAMPOS BELOS', 2021, 2): 38.65694720565496,
#  ('CAMPOS BELOS', 2022, 1): 11.04484205875856,
#  ('CAMPOS BELOS', 2022, 2): 0.0,
#  ('CAMPOS BELOS', 2023, 1): 0.0,
#  ('CAMPOS BELOS', 2023, 2): 0.0,
#  ('CAMPOS BELOS', 2024, 1): 0.0,
#  ('CAMPOS BELOS', 2024, 2): 5.52242102937928,
#  ('CAMPOS BELOS', 2025, 1): 0.0,
#  ('CAMPOS BELOS', 2025, 2): 0.0,
#  ('CATALÃO', 2015, 1): 0.0,
#  ('CATALÃO', 2015, 2): 0.0,
#  ('CATALÃO', 2016, 1): 6.11743731811548,
#  ('CATALÃO', 2016, 2): 16.60447272059916,
#  ('CATALÃO', 2017, 1): 13.1087942531046,
#  ('CATALÃO', 2017, 2): 8.7391961687364,
#  ('CATALÃO', 2018, 1): 6.11743731811548,
#  ('CATALÃO', 2018, 2): 5.24351770124184,
#  ('CATALÃO', 2019, 1): 5.24351770124184,
#  ('CATALÃO', 2019, 2): 3.49567846749456,
#  ('CATALÃO', 2020, 1): 6.11743731811548,
#  ('CATALÃO', 2020, 2): 3.49567846749456,
#  ('CATALÃO', 2021, 1): 5.24351770124184,
#  ('CATALÃO', 2021, 2): 7.865276551862759,
#  ('CATALÃO', 2022, 1): 5.24351770124184,
#  ('CATALÃO', 2022, 2): 11.36095501935732,
#  ('CATALÃO', 2023, 1): 2.62175885062092,
#  ('CATALÃO', 2023, 2): 6.11743731811548,
#  ('CATALÃO', 2024, 1): 6.11743731811548,
#  ('CATALÃO', 2024, 2): 3.49567846749456,
#  ('CATALÃO', 2025, 1): 5.24351770124184,
#  ('CATALÃO', 2025, 2): 4.3695980843682,
#  ('CAÇU', 2015, 1): 0.0,
#  ('CAÇU', 2015, 2): 0.0,
#  ('CAÇU', 2016, 1): 7.260055176419341,
#  ('CAÇU', 2016, 2): 14.520110352838682,
#  ('CAÇU', 2017, 1): 0.0,
#  ('CAÇU', 2017, 2): 0.0,
#  ('CAÇU', 2018, 1): 0.0,
#  ('CAÇU', 2018, 2): 14.520110352838682,
#  ('CAÇU', 2019, 1): 0.0,
#  ('CAÇU', 2019, 2): 14.520110352838682,
#  ('CAÇU', 2020, 1): 0.0,
#  ('CAÇU', 2020, 2): 7.260055176419341,
#  ('CAÇU', 2021, 1): 0.0,
#  ('CAÇU', 2021, 2): 14.520110352838682,
#  ('CAÇU', 2022, 1): 0.0,
#  ('CAÇU', 2022, 2): 0.0,
#  ('CAÇU', 2023, 1): 0.0,
#  ('CAÇU', 2023, 2): 7.260055176419341,
#  ('CAÇU', 2024, 1): 21.780165529258024,
#  ('CAÇU', 2024, 2): 29.040220705677363,
#  ('CAÇU', 2025, 1): 7.260055176419341,
#  ('CAÇU', 2025, 2): 0.0,
#  ('CRIXÁS', 2015, 1): 0.0,
#  ('CRIXÁS', 2015, 2): 0.0,
#  ('CRIXÁS', 2016, 1): 11.71989452094931,
#  ('CRIXÁS', 2016, 2): 17.57984178142397,
#  ('CRIXÁS', 2017, 1): 35.15968356284794,
#  ('CRIXÁS', 2017, 2): 11.71989452094931,
#  ('CRIXÁS', 2018, 1): 5.859947260474655,
#  ('CRIXÁS', 2018, 2): 29.29973630237328,
#  ('CRIXÁS', 2019, 1): 23.43978904189862,
#  ('CRIXÁS', 2019, 2): 23.43978904189862,
#  ('CRIXÁS', 2020, 1): 17.57984178142397,
#  ('CRIXÁS', 2020, 2): 11.71989452094931,
#  ('CRIXÁS', 2021, 1): 52.739525344271904,
#  ('CRIXÁS', 2021, 2): 11.71989452094931,
#  ('CRIXÁS', 2022, 1): 11.71989452094931,
#  ('CRIXÁS', 2022, 2): 29.29973630237328,
#  ('CRIXÁS', 2023, 1): 29.29973630237328,
#  ('CRIXÁS', 2023, 2): 5.859947260474655,
#  ('CRIXÁS', 2024, 1): 0.0,
#  ('CRIXÁS', 2024, 2): 11.71989452094931,
#  ('CRIXÁS', 2025, 1): 5.859947260474655,
#  ('CRIXÁS', 2025, 2): 5.859947260474655,
#  ('DAMIANÓPOLIS', 2015, 1): 0.0,
#  ('DAMIANÓPOLIS', 2015, 2): 0.0,
#  ('DAMIANÓPOLIS', 2016, 1): 0.0,
#  ('DAMIANÓPOLIS', 2016, 2): 0.0,
#  ('DAMIANÓPOLIS', 2017, 1): 0.0,
#  ('DAMIANÓPOLIS', 2017, 2): 0.0,
#  ('DAMIANÓPOLIS', 2018, 1): 0.0,
#  ('DAMIANÓPOLIS', 2018, 2): 0.0,
#  ('DAMIANÓPOLIS', 2019, 1): 26.52519893899204,
#  ('DAMIANÓPOLIS', 2019, 2): 26.52519893899204,
#  ('DAMIANÓPOLIS', 2020, 1): 0.0,
#  ('DAMIANÓPOLIS', 2020, 2): 0.0,
#  ('DAMIANÓPOLIS', 2021, 1): 0.0,
#  ('DAMIANÓPOLIS', 2021, 2): 0.0,
#  ('DAMIANÓPOLIS', 2022, 1): 0.0,
#  ('DAMIANÓPOLIS', 2022, 2): 0.0,
#  ('DAMIANÓPOLIS', 2023, 1): 0.0,
#  ('DAMIANÓPOLIS', 2023, 2): 0.0,
#  ('DAMIANÓPOLIS', 2024, 1): 53.05039787798408,
#  ('DAMIANÓPOLIS', 2024, 2): 53.05039787798408,
#  ('DAMIANÓPOLIS', 2025, 1): 0.0,
#  ('DAMIANÓPOLIS', 2025, 2): 0.0,
#  ('FORMOSA', 2015, 1): 0.0,
#  ('FORMOSA', 2015, 2): 0.0,
#  ('FORMOSA', 2016, 1): 14.667690528985943,
#  ('FORMOSA', 2016, 2): 25.02135443179955,
#  ('FORMOSA', 2017, 1): 16.39330117945488,
#  ('FORMOSA', 2017, 2): 28.472575732737425,
#  ('FORMOSA', 2018, 1): 21.570133130861684,
#  ('FORMOSA', 2018, 2): 26.746965082268485,
#  ('FORMOSA', 2019, 1): 7.765247927110206,
#  ('FORMOSA', 2019, 2): 6.902442601875739,
#  ('FORMOSA', 2020, 1): 7.765247927110206,
#  ('FORMOSA', 2020, 2): 14.667690528985943,
#  ('FORMOSA', 2021, 1): 7.765247927110206,
#  ('FORMOSA', 2021, 2): 6.039637276641272,
#  ('FORMOSA', 2022, 1): 8.628053252344673,
#  ('FORMOSA', 2022, 2): 6.039637276641272,
#  ('FORMOSA', 2023, 1): 9.49085857757914,
#  ('FORMOSA', 2023, 2): 6.902442601875739,
#  ('FORMOSA', 2024, 1): 4.314026626172336,
#  ('FORMOSA', 2024, 2): 5.176831951406804,
#  ('FORMOSA', 2025, 1): 3.4512213009378696,
#  ('FORMOSA', 2025, 2): 1.7256106504689348,
#  ('FORMOSO', 2015, 1): 21.45922746781116,
#  ('FORMOSO', 2015, 2): 0.0,
#  ('FORMOSO', 2016, 1): 0.0,
#  ('FORMOSO', 2016, 2): 21.45922746781116,
#  ('FORMOSO', 2017, 1): 0.0,
#  ('FORMOSO', 2017, 2): 21.45922746781116,
#  ('FORMOSO', 2018, 1): 0.0,
#  ('FORMOSO', 2018, 2): 42.91845493562232,
#  ('FORMOSO', 2019, 1): 0.0,
#  ('FORMOSO', 2019, 2): 0.0,
#  ('FORMOSO', 2020, 1): 0.0,
#  ('FORMOSO', 2020, 2): 0.0,
#  ('FORMOSO', 2021, 1): 21.45922746781116,
#  ('FORMOSO', 2021, 2): 0.0,
#  ('FORMOSO', 2022, 1): 21.45922746781116,
#  ('FORMOSO', 2022, 2): 21.45922746781116,
#  ('FORMOSO', 2023, 1): 42.91845493562232,
#  ('FORMOSO', 2023, 2): 42.91845493562232,
#  ('FORMOSO', 2024, 1): 0.0,
#  ('FORMOSO', 2024, 2): 0.0,
#  ('FORMOSO', 2025, 1): 21.45922746781116,
#  ('FORMOSO', 2025, 2): 0.0,
#  ('IPAMERI', 2015, 1): 0.0,
#  ('IPAMERI', 2015, 2): 0.0,
#  ('IPAMERI', 2016, 1): 15.65680288085173,
#  ('IPAMERI', 2016, 2): 3.914200720212933,
#  ('IPAMERI', 2017, 1): 0.0,
#  ('IPAMERI', 2017, 2): 15.65680288085173,
#  ('IPAMERI', 2018, 1): 23.4852043212776,
#  ('IPAMERI', 2018, 2): 7.828401440425865,
#  ('IPAMERI', 2019, 1): 19.57100360106466,
#  ('IPAMERI', 2019, 2): 11.742602160638798,
#  ('IPAMERI', 2020, 1): 11.742602160638798,
#  ('IPAMERI', 2020, 2): 7.828401440425865,
#  ('IPAMERI', 2021, 1): 7.828401440425865,
#  ('IPAMERI', 2021, 2): 3.914200720212933,
#  ('IPAMERI', 2022, 1): 11.742602160638798,
#  ('IPAMERI', 2022, 2): 7.828401440425865,
#  ('IPAMERI', 2023, 1): 3.914200720212933,
#  ('IPAMERI', 2023, 2): 7.828401440425865,
#  ('IPAMERI', 2024, 1): 7.828401440425865,
#  ('IPAMERI', 2024, 2): 0.0,
#  ('IPAMERI', 2025, 1): 3.914200720212933,
#  ('IPAMERI', 2025, 2): 0.0,
#  ('LUZIÂNIA', 2015, 1): 0.0,
#  ('LUZIÂNIA', 2015, 2): 0.0,
#  ('LUZIÂNIA', 2016, 1): 17.69242907487723,
#  ('LUZIÂNIA', 2016, 2): 39.210248219998185,
#  ('LUZIÂNIA', 2017, 1): 32.037641838291194,
#  ('LUZIÂNIA', 2017, 2): 22.95234042146235,
#  ('LUZIÂNIA', 2018, 1): 13.867039004633504,
#  ('LUZIÂNIA', 2018, 2): 17.21425531609676,
#  ('LUZIÂNIA', 2019, 1): 16.736081557316297,
#  ('LUZIÂNIA', 2019, 2): 10.519822693170244,
#  ('LUZIÂNIA', 2020, 1): 13.388865245853038,
#  ('LUZIÂNIA', 2020, 2): 14.823386522194436,
#  ('LUZIÂNIA', 2021, 1): 11.95434396951164,
#  ('LUZIÂNIA', 2021, 2): 9.085301416828846,
#  ('LUZIÂNIA', 2022, 1): 14.345212763413969,
#  ('LUZIÂNIA', 2022, 2): 9.085301416828846,
#  ('LUZIÂNIA', 2023, 1): 8.60712765804838,
#  ('LUZIÂNIA', 2023, 2): 11.476170210731174,
#  ('LUZIÂNIA', 2024, 1): 10.041648934389778,
#  ('LUZIÂNIA', 2024, 2): 9.563475175609312,
#  ('LUZIÂNIA', 2025, 1): 10.519822693170244,
#  ('LUZIÂNIA', 2025, 2): 5.259911346585122,
#  ('PALMINÓPOLIS', 2015, 1): 0.0,
#  ('PALMINÓPOLIS', 2015, 2): 0.0,
#  ('PALMINÓPOLIS', 2016, 1): 0.0,
#  ('PALMINÓPOLIS', 2016, 2): 0.0,
#  ('PALMINÓPOLIS', 2017, 1): 0.0,
#  ('PALMINÓPOLIS', 2017, 2): 0.0,
#  ('PALMINÓPOLIS', 2018, 1): 0.0,
#  ('PALMINÓPOLIS', 2018, 2): 25.967281225655675,
#  ('PALMINÓPOLIS', 2019, 1): 0.0,
#  ('PALMINÓPOLIS', 2019, 2): 0.0,
#  ('PALMINÓPOLIS', 2020, 1): 0.0,
#  ('PALMINÓPOLIS', 2020, 2): 0.0,
#  ('PALMINÓPOLIS', 2021, 1): 0.0,
#  ('PALMINÓPOLIS', 2021, 2): 0.0,
#  ('PALMINÓPOLIS', 2022, 1): 25.967281225655675,
#  ('PALMINÓPOLIS', 2022, 2): 0.0,
#  ('PALMINÓPOLIS', 2023, 1): 25.967281225655675,
#  ('PALMINÓPOLIS', 2023, 2): 0.0,
#  ('PALMINÓPOLIS', 2024, 1): 0.0,
#  ('PALMINÓPOLIS', 2024, 2): 0.0,
#  ('PALMINÓPOLIS', 2025, 1): 0.0,
#  ('PALMINÓPOLIS', 2025, 2): 0.0,
#  ('PARANAIGUARA', 2015, 1): 0.0,
#  ('PARANAIGUARA', 2015, 2): 0.0,
#  ('PARANAIGUARA', 2016, 1): 0.0,
#  ('PARANAIGUARA', 2016, 2): 39.43736032601551,
#  ('PARANAIGUARA', 2017, 1): 39.43736032601551,
#  ('PARANAIGUARA', 2017, 2): 13.145786775338504,
#  ('PARANAIGUARA', 2018, 1): 0.0,
#  ('PARANAIGUARA', 2018, 2): 13.145786775338504,
#  ('PARANAIGUARA', 2019, 1): 0.0,
#  ('PARANAIGUARA', 2019, 2): 13.145786775338504,
#  ('PARANAIGUARA', 2020, 1): 26.291573550677008,
#  ('PARANAIGUARA', 2020, 2): 26.291573550677008,
#  ('PARANAIGUARA', 2021, 1): 26.291573550677008,
#  ('PARANAIGUARA', 2021, 2): 13.145786775338504,
#  ('PARANAIGUARA', 2022, 1): 39.43736032601551,
#  ('PARANAIGUARA', 2022, 2): 0.0,
#  ('PARANAIGUARA', 2023, 1): 13.145786775338504,
#  ('PARANAIGUARA', 2023, 2): 0.0,
#  ('PARANAIGUARA', 2024, 1): 0.0,
#  ('PARANAIGUARA', 2024, 2): 0.0,
#  ('PARANAIGUARA', 2025, 1): 0.0,
#  ('PARANAIGUARA', 2025, 2): 0.0,
#  ('PIRENÓPOLIS', 2015, 1): 0.0,
#  ('PIRENÓPOLIS', 2015, 2): 0.0,
#  ('PIRENÓPOLIS', 2016, 1): 7.493443237167479,
#  ('PIRENÓPOLIS', 2016, 2): 11.240164855751216,
#  ('PIRENÓPOLIS', 2017, 1): 11.240164855751216,
#  ('PIRENÓPOLIS', 2017, 2): 7.493443237167479,
#  ('PIRENÓPOLIS', 2018, 1): 11.240164855751216,
#  ('PIRENÓPOLIS', 2018, 2): 3.7467216185837393,
#  ('PIRENÓPOLIS', 2019, 1): 22.480329711502435,
#  ('PIRENÓPOLIS', 2019, 2): 7.493443237167479,
#  ('PIRENÓPOLIS', 2020, 1): 11.240164855751216,
#  ('PIRENÓPOLIS', 2020, 2): 3.7467216185837393,
#  ('PIRENÓPOLIS', 2021, 1): 18.733608092918697,
#  ('PIRENÓPOLIS', 2021, 2): 18.733608092918697,
#  ('PIRENÓPOLIS', 2022, 1): 3.7467216185837393,
#  ('PIRENÓPOLIS', 2022, 2): 18.733608092918697,
#  ('PIRENÓPOLIS', 2023, 1): 7.493443237167479,
#  ('PIRENÓPOLIS', 2023, 2): 7.493443237167479,
#  ('PIRENÓPOLIS', 2024, 1): 14.986886474334955,
#  ('PIRENÓPOLIS', 2024, 2): 7.493443237167479,
#  ('PIRENÓPOLIS', 2025, 1): 3.7467216185837393,
#  ('PIRENÓPOLIS', 2025, 2): 3.7467216185837393,
#  ('PIRES DO RIO', 2015, 1): 0.0,
#  ('PIRES DO RIO', 2015, 2): 0.0,
#  ('PIRES DO RIO', 2016, 1): 3.0889939146819883,
#  ('PIRES DO RIO', 2016, 2): 3.0889939146819883,
#  ('PIRES DO RIO', 2017, 1): 3.0889939146819883,
#  ('PIRES DO RIO', 2017, 2): 9.266981744045964,
#  ('PIRES DO RIO', 2018, 1): 21.62295740277392,
#  ('PIRES DO RIO', 2018, 2): 9.266981744045964,
#  ('PIRES DO RIO', 2019, 1): 9.266981744045964,
#  ('PIRES DO RIO', 2019, 2): 9.266981744045964,
#  ('PIRES DO RIO', 2020, 1): 6.1779878293639765,
#  ('PIRES DO RIO', 2020, 2): 6.1779878293639765,
#  ('PIRES DO RIO', 2021, 1): 0.0,
#  ('PIRES DO RIO', 2021, 2): 6.1779878293639765,
#  ('PIRES DO RIO', 2022, 1): 6.1779878293639765,
#  ('PIRES DO RIO', 2022, 2): 24.711951317455902,
#  ('PIRES DO RIO', 2023, 1): 15.44496957340994,
#  ('PIRES DO RIO', 2023, 2): 9.266981744045964,
#  ('PIRES DO RIO', 2024, 1): 9.266981744045964,
#  ('PIRES DO RIO', 2024, 2): 9.266981744045964,
#  ('PIRES DO RIO', 2025, 1): 9.266981744045964,
#  ('PIRES DO RIO', 2025, 2): 3.0889939146819883,
#  ('PONTALINA', 2015, 1): 0.0,
#  ('PONTALINA', 2015, 2): 0.0,
#  ('PONTALINA', 2016, 1): 16.385384237260364,
#  ('PONTALINA', 2016, 2): 98.3123054235622,
#  ('PONTALINA', 2017, 1): 5.461794745753454,
#  ('PONTALINA', 2017, 2): 5.461794745753454,
#  ('PONTALINA', 2018, 1): 5.461794745753454,
#  ('PONTALINA', 2018, 2): 0.0,
#  ('PONTALINA', 2019, 1): 5.461794745753454,
#  ('PONTALINA', 2019, 2): 0.0,
#  ('PONTALINA', 2020, 1): 5.461794745753454,
#  ('PONTALINA', 2020, 2): 5.461794745753454,
#  ('PONTALINA', 2021, 1): 0.0,
#  ('PONTALINA', 2021, 2): 21.847178983013816,
#  ('PONTALINA', 2022, 1): 0.0,
#  ('PONTALINA', 2022, 2): 21.847178983013816,
#  ('PONTALINA', 2023, 1): 5.461794745753454,
#  ('PONTALINA', 2023, 2): 0.0,
#  ('PONTALINA', 2024, 1): 0.0,
#  ('PONTALINA', 2024, 2): 5.461794745753454,
#  ('PONTALINA', 2025, 1): 0.0,
#  ('PONTALINA', 2025, 2): 0.0,
#  ('PORANGATU', 2015, 1): 0.0,
#  ('PORANGATU', 2015, 2): 0.0,
#  ('PORANGATU', 2016, 1): 4.512940857910057,
#  ('PORANGATU', 2016, 2): 9.025881715820114,
#  ('PORANGATU', 2017, 1): 4.512940857910057,
#  ('PORANGATU', 2017, 2): 6.769411286865086,
#  ('PORANGATU', 2018, 1): 6.769411286865086,
#  ('PORANGATU', 2018, 2): 6.769411286865086,
#  ('PORANGATU', 2019, 1): 2.2564704289550286,
#  ('PORANGATU', 2019, 2): 11.282352144775144,
#  ('PORANGATU', 2020, 1): 6.769411286865086,
#  ('PORANGATU', 2020, 2): 9.025881715820114,
#  ('PORANGATU', 2021, 1): 9.025881715820114,
#  ('PORANGATU', 2021, 2): 6.769411286865086,
#  ('PORANGATU', 2022, 1): 11.282352144775144,
#  ('PORANGATU', 2022, 2): 2.2564704289550286,
#  ('PORANGATU', 2023, 1): 15.7952930026852,
#  ('PORANGATU', 2023, 2): 4.512940857910057,
#  ('PORANGATU', 2024, 1): 4.512940857910057,
#  ('PORANGATU', 2024, 2): 4.512940857910057,
#  ('PORANGATU', 2025, 1): 4.512940857910057,
#  ('PORANGATU', 2025, 2): 0.0,
#  ('QUIRINÓPOLIS', 2015, 1): 0.0,
#  ('QUIRINÓPOLIS', 2015, 2): 0.0,
#  ('QUIRINÓPOLIS', 2016, 1): 0.0,
#  ('QUIRINÓPOLIS', 2016, 2): 2.064111296881128,
#  ('QUIRINÓPOLIS', 2017, 1): 10.32055648440564,
#  ('QUIRINÓPOLIS', 2017, 2): 22.705224265692408,
#  ('QUIRINÓPOLIS', 2018, 1): 20.64111296881128,
#  ('QUIRINÓPOLIS', 2018, 2): 16.51289037504902,
#  ('QUIRINÓPOLIS', 2019, 1): 8.25644518752451,
#  ('QUIRINÓPOLIS', 2019, 2): 10.32055648440564,
#  ('QUIRINÓPOLIS', 2020, 1): 6.192333890643384,
#  ('QUIRINÓPOLIS', 2020, 2): 8.25644518752451,
#  ('QUIRINÓPOLIS', 2021, 1): 10.32055648440564,
#  ('QUIRINÓPOLIS', 2021, 2): 6.192333890643384,
#  ('QUIRINÓPOLIS', 2022, 1): 12.384667781286767,
#  ('QUIRINÓPOLIS', 2022, 2): 16.51289037504902,
#  ('QUIRINÓPOLIS', 2023, 1): 22.705224265692408,
#  ('QUIRINÓPOLIS', 2023, 2): 14.448779078167894,
#  ('QUIRINÓPOLIS', 2024, 1): 6.192333890643384,
#  ('QUIRINÓPOLIS', 2024, 2): 10.32055648440564,
#  ('QUIRINÓPOLIS', 2025, 1): 10.32055648440564,
#  ('QUIRINÓPOLIS', 2025, 2): 4.128222593762255,
#  ('SÃO MIGUEL DO ARAGUAIA', 2015, 1): 0.0,
#  ('SÃO MIGUEL DO ARAGUAIA', 2015, 2): 0.0,
#  ('SÃO MIGUEL DO ARAGUAIA', 2016, 1): 0.0,
#  ('SÃO MIGUEL DO ARAGUAIA', 2016, 2): 9.1324200913242,
#  ('SÃO MIGUEL DO ARAGUAIA', 2017, 1): 0.0,
#  ('SÃO MIGUEL DO ARAGUAIA', 2017, 2): 0.0,
#  ('SÃO MIGUEL DO ARAGUAIA', 2018, 1): 0.0,
#  ('SÃO MIGUEL DO ARAGUAIA', 2018, 2): 9.1324200913242,
#  ('SÃO MIGUEL DO ARAGUAIA', 2019, 1): 13.6986301369863,
#  ('SÃO MIGUEL DO ARAGUAIA', 2019, 2): 9.1324200913242,
#  ('SÃO MIGUEL DO ARAGUAIA', 2020, 1): 0.0,
#  ('SÃO MIGUEL DO ARAGUAIA', 2020, 2): 4.566210045662101,
#  ('SÃO MIGUEL DO ARAGUAIA', 2021, 1): 0.0,
#  ('SÃO MIGUEL DO ARAGUAIA', 2021, 2): 18.264840182648403,
#  ('SÃO MIGUEL DO ARAGUAIA', 2022, 1): 4.566210045662101,
#  ('SÃO MIGUEL DO ARAGUAIA', 2022, 2): 0.0,
#  ('SÃO MIGUEL DO ARAGUAIA', 2023, 1): 9.1324200913242,
#  ('SÃO MIGUEL DO ARAGUAIA', 2023, 2): 9.1324200913242,
#  ('SÃO MIGUEL DO ARAGUAIA', 2024, 1): 22.831050228310502,
#  ('SÃO MIGUEL DO ARAGUAIA', 2024, 2): 18.264840182648403,
#  ('SÃO MIGUEL DO ARAGUAIA', 2025, 1): 0.0,
#  ('SÃO MIGUEL DO ARAGUAIA', 2025, 2): 0.0,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2015, 1): 0.0,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2015, 2): 0.0,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2016, 1): 0.0,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2016, 2): 112.00716845878136,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2017, 1): 44.80286738351254,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2017, 2): 22.40143369175627,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2018, 1): 22.40143369175627,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2018, 2): 22.40143369175627,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2019, 1): 44.80286738351254,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2019, 2): 22.40143369175627,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2020, 1): 112.00716845878136,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2020, 2): 44.80286738351254,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2021, 1): 22.40143369175627,
#  ('SÃO MIGUEL DO PASSA QUATRO', 2021, 2): 0.0,
#  ...}

# %%
from datetime import datetime

def encode_date(date_str: str):
    date = datetime.strptime(date_str, "%Y-%m-%d")
    year = date.year
    semester = 1 if date.month <= 6 else 2
    return year, semester

# %%
filter = []

for name, date, action in results:
  year, semester = encode_date(date)
  key = (name.upper(), year, semester)

  if semester == 1:
    next_key = (name.upper(), year, 2)
  else:
    next_key = (name.upper(), year + 1, 1)

  if next_key not in uf2score:
    continue

  if key in uf2score:
    delta = uf2score[next_key] - uf2score[key]
    filter.append((name, action, delta))

# %%
import unicodedata
import re
from statistics import mean, stdev
from typing import List, Tuple, Dict, Any, Optional


# ---------- 1. Pré-processamento de texto ----------

STOPWORDS = {
    "a", "as", "o", "os", "um", "uma", "uns", "umas",
    "de", "do", "da", "dos", "das",
    "em", "no", "na", "nos", "nas",
    "para", "pra", "pro", "por",
    "ao", "aos", "à", "às",
    "e"
}


def normalize_and_tokenize(text: str) -> List[str]:
    """
    Normaliza o texto e retorna tokens de conteúdo:
    - minúsculas
    - remove acentos
    - remove pontuação
    - quebra em tokens
    - remove stopwords
    """
    text = text.lower()

    # remove acentos
    text = unicodedata.normalize("NFD", text)
    text = "".join(ch for ch in text if not unicodedata.combining(ch))

    # remove pontuação
    text = re.sub(r"[^\w\s]", " ", text)

    # colapsa espaços
    text = re.sub(r"\s+", " ", text).strip()

    tokens = text.split()
    tokens = [t for t in tokens if t not in STOPWORDS]

    return tokens


# ---------- 2. Similaridade e agrupamento ----------

def jaccard_similarity(tokens_a: List[str], tokens_b: List[str]) -> float:
    """
    Similaridade de Jaccard entre conjuntos de tokens.
    """
    set_a = set(tokens_a)
    set_b = set(tokens_b)
    if not set_a and not set_b:
        return 1.0
    inter = len(set_a & set_b)
    uni = len(set_a | set_b)
    return inter / uni


def group_bills_by_structure(
    bills: List[Tuple[str, str, float]],
    threshold: float = 0.75,
) -> List[Dict[str, Any]]:
    """
    Agrupa projetos de lei (municipio, frase, score) em grupos
    estruturalmente similares, usando Jaccard sobre tokens normalizados.

    Retorna uma lista de grupos, cada grupo é um dict com:
      - "rep_tokens": tokens do representante
      - "rep_phrase": frase representante (primeira do grupo)
      - "members": lista de (municipio, frase, score, similarity)
    """
    if not bills:
        return []

    groups: List[Dict[str, Any]] = []

    for municipio, frase, score in bills:
        tokens = normalize_and_tokenize(frase)

        if not groups:
            groups.append({
                "rep_tokens": tokens,
                "rep_phrase": frase,
                "members": [(municipio, frase, score, 1.0)],
            })
            continue

        best_idx: Optional[int] = None
        best_sim = 0.0

        for i, g in enumerate(groups):
            sim = jaccard_similarity(tokens, g["rep_tokens"])
            if sim > best_sim:
                best_sim = sim
                best_idx = i

        if best_idx is not None and best_sim >= threshold:
            groups[best_idx]["members"].append(
                (municipio, frase, score, best_sim)
            )
        else:
            groups.append({
                "rep_tokens": tokens,
                "rep_phrase": frase,
                "members": [(municipio, frase, score, 1.0)],
            })

    return groups


# ---------- 3. Estatística básica ----------

def compute_mean_and_std(values: List[float]) -> Tuple[float, float]:
    """
    Calcula média e desvio padrão amostral.
    Se houver apenas um valor, desvio padrão = 0.0.
    """
    if not values:
        return 0.0, 0.0
    if len(values) == 1:
        return values[0], 0.0
    return mean(values), stdev(values)


# ---------- 4. Teste não paramétrico (Wilcoxon) ----------

def wilcoxon_less_than_zero(values: List[float], alpha: float = 0.05) -> Dict[str, Any]:
    """
    Aplica o teste de Wilcoxon signed-rank (não paramétrico)
    para verificar se a mediana dos valores é menor que zero.

    Retorna um dict:
      - "test": nome do teste
      - "p_value": p-valor (ou None se não foi possível calcular)
      - "reject_h0": True se rejeita H0 (mediana >= 0) em favor de mediana < 0
    """
    # Remove zeros (não contribuem para Wilcoxon)
    filtered = [v for v in values if v != 0.0]

    # Se poucos dados, o teste não faz muito sentido.
    if len(filtered) < 1:
        return {
            "test": "wilcoxon_signed_rank",
            "p_value": None,
            "reject_h0": False,
        }

    try:
        from scipy.stats import wilcoxon

        # H0: mediana = 0 ; H1: mediana < 0
        stat, p_value = wilcoxon(filtered, alternative="less", zero_method="wilcox")
        reject = (p_value is not None) and (p_value < alpha)
        return {
            "test": "wilcoxon_signed_rank",
            "p_value": float(p_value),
            "reject_h0": bool(reject),
        }
    except Exception:
        # Fallback simples: sem scipy, usa só o sinal da média
        m = mean(values)
        return {
            "test": "simple_mean_sign",
            "p_value": None,
            "reject_h0": bool(m < 0),
        }


# ---------- 5. Métrica de qualidade da política ----------

def compute_policy_quality(scores: List[float]) -> float:
    """
    Métrica de qualidade da política.

    Objetivo: políticas que reduzem o indicador (scores negativos)
    devem receber pontuação maior.

    A métrica considera:
      1) A proporção de municípios com score negativo (fraction_neg).
      2) A magnitude do efeito médio (mais negativa = melhor).

    Definição:
        fraction_neg = (# scores < 0) / n
        effect_mean  = mean(scores)

        quality = max(0, fraction_neg * (-effect_mean))

    Intuição:
      - Se poucos municípios melhoram (fraction_neg baixo), qualidade cai.
      - Se a média é pouco negativa (melhora fraca) ou positiva (piorou),
        a qualidade se aproxima de 0.
      - Positive outliers puxam a média pra cima e reduzem fraction_neg,
        penalizando políticas que causam piora em muitos lugares.
    """
    if not scores:
        return 0.0

    n = len(scores)
    neg_count = sum(1 for s in scores if s < 0)
    fraction_neg = neg_count / n if n > 0 else 0.0
    effect_mean = mean(scores)
    quality = fraction_neg * (-effect_mean)

    return max(0.0, quality)


# ---------- 6. Função principal: gerar políticas ----------

def generate_policies_from_bills(
    bills: List[Tuple[str, str, float]],
    similarity_threshold: float = 0.75,
    alpha: float = 0.05,
) -> List[Dict[str, Any]]:
    """
    Recebe uma lista de projetos de lei no formato:
      (municipio, descricao_PL, effect_score)

    Agrupa projetos estruturalmente similares e retorna uma lista de objetos:

      {
          "policy": Frase representativa do grupo,
          "actions": [(NomeMunicipio, Descricao, score), ...],
          "effect_mean": média dos scores,
          "effect_std": desvio padrão dos scores,
          "effective": resultado do teste não paramétrico
                       (dict com test, p_value, reject_h0),
          "quality_score": métrica que combina
                           (proporção de efeitos negativos) x
                           (magnitude média da melhoria)
      }
    """
    groups = group_bills_by_structure(bills, threshold=similarity_threshold)
    policies: List[Dict[str, Any]] = []

    for g in groups:
        members = g["members"]
        scores = [s for (_, _, s, _) in members]

        effect_mean, effect_std = compute_mean_and_std(scores)
        test_result = wilcoxon_less_than_zero(scores, alpha=alpha)
        quality_score = compute_policy_quality(scores)

        # agora actions inclui o score também
        actions = [(mun, frase, score) for (mun, frase, score, _) in members]

        policy_obj = {
            "policy": g["rep_phrase"],
            "actions": actions,
            "effect_mean": effect_mean,
            "effect_std": effect_std,
            "effective": test_result,
            "quality_score": quality_score,
        }
        policies.append(policy_obj)

    return policies

# %%
policies = generate_policies_from_bills(filter)
policies = sorted(policies, key=lambda x: x['quality_score'], reverse=True)

for p in policies:

    if len(p['actions']) <= 1:
      continue

    print("Policy:", p["policy"])
    print("  effect_mean:", p["effect_mean"])
    print("  effect_std:", p["effect_std"])
    print("  quality:", p["quality_score"])
    print("  effective:", p["effective"])
    print("  actions:")
    for mun, desc, score in p["actions"]:
        print(f"    - {mun}: {score:.3f} | {desc}")
    print()
# Out:
# Policy: Instituir o Prêmio “Advocacia Cidadã” no município.
#   effect_mean: -20.167865956757787
#   effect_std: 21.877958464530973
#   quality: 20.167865956757787
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.25, 'reject_h0': False}
#   actions:
#     - Primavera do Leste: -4.698 | Instituir o Prêmio “Advocacia Cidadã” no município.
#     - Dilermando de Aguiar: -35.638 | Instituir o Prêmio “Advocacia Cidadã” no município.
#
# Policy: Criar o programa “Doe um Bicicletário” no município.
#   effect_mean: -13.3505631006027
#   effect_std: 24.061643366348033
#   quality: 8.9003754004018
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.375, 'reject_h0': False}
#   actions:
#     - Cidreira: -41.005 | Criar o programa “Doe um Bicicletário” no município.
#     - Pelotas: -1.842 | Criar o programa “Doe um Bicicletário” no município.
#     - Itaqui: 2.796 | Criar o programa “Doe um Bicicletário” no município.
#
# Policy: Criar o programa municipal “Prefeito Mirim” no município.
#   effect_mean: -7.862871520679352
#   effect_std: 5.559889771870951
#   quality: 7.862871520679352
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.25, 'reject_h0': False}
#   actions:
#     - Três Passos: -3.931 | Criar o programa municipal “Prefeito Mirim” no município.
#     - Três Passos: -11.794 | Criar o programa municipal “Prefeito Mirim” no município.
#
# Policy: Implantar o programa “Bueiro Imobiliário” para prevenção de enchentes no município.
#   effect_mean: -6.869643142801056
#   effect_std: 10.254962950836642
#   quality: 6.869643142801056
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.0625, 'reject_h0': False}
#   actions:
#     - Campinas: -0.527 | Implantar o programa “Bueiro Imobiliário” para prevenção de enchentes no município.
#     - Cabo de Santo Agostinho: -22.120 | Implantar o programa “Bueiro Imobiliário” como forma de prevenção às enchentes no município.
#     - Rio Grande: -3.648 | Implantar o programa “Bueiro Imobiliário” como forma de prevenção às enchentes no município.
#     - Sant'Ana do Livramento: -1.185 | Implantar o programa “Bueiro Imobiliário” como forma de prevenção às enchentes no município.
#
# Policy: Criar o programa “Artes marciais nas escolas” no município.
#   effect_mean: -6.745020173805157
#   effect_std: 1.2516821177210677
#   quality: 6.745020173805157
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.25, 'reject_h0': False}
#   actions:
#     - Crixás: -5.860 | Criar o programa “Artes marciais nas escolas” no município.
#     - Igarapava: -7.630 | Criar o programa “Artes marciais nas escolas” no município.
#
# Policy: Criar o programa “Abrace Bem” no município.
#   effect_mean: -5.472041775130352
#   effect_std: 0.0
#   quality: 5.472041775130352
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.25, 'reject_h0': False}
#   actions:
#     - Votorantim: -5.472 | Criar o programa “Abrace Bem” no município.
#     - Votorantim: -5.472 | Criar o programa “Abrace Bem” no município.
#
# Policy: Criar programa de combate a pichações no município.
#   effect_mean: -6.389760328482053
#   effect_std: 8.835426642577172
#   quality: 5.324800273735044
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.078125, 'reject_h0': False}
#   actions:
#     - Tijucas do Sul: -11.350 | Criar programa de combate a pichações no município.
#     - Natal: 5.723 | Criar programa de combate a pichações no município.
#     - Esteio: -7.881 | Criar programa de combate a pichações no município.
#     - Armação dos Búzios: -19.997 | Criar programa de combate às pichações no município.
#     - Olinda: -2.572 | Criar programa de combate às pichações no município.
#     - Natal: -2.263 | Criar programa de combate a pichações e depredações no município.
#
# Policy: Criar o programa “Cuidando de Quem Cuida” no município.
#   effect_mean: -4.975224892855844
#   effect_std: 5.827973432849568
#   quality: 4.975224892855844
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.125, 'reject_h0': False}
#   actions:
#     - Campina Grande: -0.477 | Criar o programa “Cuidando de Quem Cuida” no município.
#     - Barra do Garças: -2.890 | Criar o programa “Cuidando de Quem Cuida” no município.
#     - Barra do Garças: -11.559 | Criar o programa “Cuidando de Quem Cuida” no município.
#
# Policy: Criar o programa “Câmara Vai À Escola” no município.
#   effect_mean: -4.940799997546849
#   effect_std: 6.964313877306142
#   quality: 4.940799997546849
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.125, 'reject_h0': False}
#   actions:
#     - Natal: -1.464 | Criar o programa “Câmara Vai À Escola” no município.
#     - Natal: -0.399 | Criar o programa “Câmara Vai À Escola” no município.
#     - Ribas do Rio Pardo: -12.959 | Criar o programa “Câmara Vai À Escola” no município.
#
# Policy: Criar câmara mirim no município.
#   effect_mean: -6.182621821930987
#   effect_std: 11.065336715814361
#   quality: 4.636966366448241
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.125, 'reject_h0': False}
#   actions:
#     - Itapoá: -22.764 | Criar câmara mirim no município.
#     - Votorantim: -0.782 | Criar câmara mirim no município.
#     - Heliodora: 0.000 | Criar câmara mirim no município.
#     - Sant'Ana do Livramento: -1.185 | Criar câmara mirim no município.
#
# Policy: Criar programa municipal creche noturna no município.
#   effect_mean: -8.748687696845476
#   effect_std: 12.372512793845509
#   quality: 4.374343848422738
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Carlos Barbosa: 0.000 | Criar programa municipal creche noturna no município.
#     - Armação dos Búzios: -17.497 | Criar programa creche noturna no município.
#
# Policy: Instituir o mês “Junho Violento” para conscientização e prevenção da violência contra pessoas idosas no município.
#   effect_mean: -4.155606668455498
#   effect_std: 5.194116178333493
#   quality: 4.155606668455498
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.25, 'reject_h0': False}
#   actions:
#     - Montes Claros: -0.483 | Instituir o mês “Junho Violento” para conscientização e prevenção da violência contra pessoas idosas no município.
#     - Ipameri: -7.828 | Instituir o mês “Junho Violento” como mês de conscientização, prevenção e combate à violência contra pessoas idosas no município.
#
# Policy: Criar o programa municipal “Auxílio Reforma à Moradia” no município.
#   effect_mean: -4.128222593762257
#   effect_std: 0.0
#   quality: 4.128222593762257
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.25, 'reject_h0': False}
#   actions:
#     - Quirinópolis: -4.128 | Criar o programa municipal “Auxílio Reforma à Moradia” no município.
#     - Quirinópolis: -4.128 | Criar o programa municipal “Auxílio Reforma à Moradia” no município.
#
# Policy: Criar o programa “Porteira adentro” no município.
#   effect_mean: -7.788161993769471
#   effect_std: 16.284192513352128
#   quality: 3.8940809968847354
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.375, 'reject_h0': False}
#   actions:
#     - Ponte Alta do Norte: -31.153 | Criar o programa “Porteira adentro” no município.
#     - São Francisco de Assis: 0.000 | Criar o programa “Porteira adentro” no município.
#     - Alto Araguaia: -5.816 | Criar o programa municipal “Porteira adentro” no município.
#     - Alto Araguaia: 5.816 | Criar o programa municipal “Porteira adentro” no município.
#
# Policy: Criar o programa “Meu Bairro Bem Cuidado” no município.
#   effect_mean: -4.736822078993583
#   effect_std: 7.848720494543193
#   quality: 3.157881385995722
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.109375, 'reject_h0': False}
#   actions:
#     - Natal: 2.263 | Criar o programa “Meu Bairro Bem Cuidado” no município.
#     - Campina Grande: 1.431 | Criar o programa “Meu Bairro Bem Cuidado” no município.
#     - Caruaru: -7.406 | Criar o programa “Meu Bairro Bem Cuidado” no município.
#     - Anápolis: -4.262 | Criar o programa “Meu Bairro Bem Cuido” no município.
#     - Natal: -1.464 | Criar o programa “Meu Bairro Bem Cuido” no município.
#     - Formosa: -18.982 | Criar o programa “Meu Bairro Bem Cuido” no município.
#
# Policy: Instituir a campanha “Janeiro Branco” no município.
#   effect_mean: -3.017453082591806
#   effect_std: 3.118814773809316
#   quality: 3.017453082591806
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.125, 'reject_h0': False}
#   actions:
#     - Carlos Barbosa: -6.575 | Instituir a campanha “Janeiro Branco” no município.
#     - Anápolis: -0.752 | Instituir a campanha “Janeiro Branco” no município.
#     - Formosa: -1.726 | Instituir a campanha “Janeiro Branco” no município.
#
# Policy: Criar o programa “Banco de Alimentos” no município.
#   effect_mean: -4.814636494944632
#   effect_std: 6.80892422904716
#   quality: 2.407318247472316
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Constantina: -9.629 | Criar o programa “Banco de Alimentos” no município.
#     - Capitólio: 0.000 | Criar o programa “Banco de Alimentos” no município.
#
# Policy: Instituir a campanha municipal de prevenção ao suicídio “Setembro Amarelo” no município.
#   effect_mean: -2.203843775491225
#   effect_std: 2.222971654612121
#   quality: 2.203843775491225
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.25, 'reject_h0': False}
#   actions:
#     - Barueri: -0.632 | Instituir a campanha municipal de prevenção ao suicídio “Setembro Amarelo” no município.
#     - Piedade: -3.776 | Instituir campanha municipal de prevenção ao suicídio “Setembro Amarelo” no município.
#
# Policy: Criar programa “Medicamento em Casa” no município.
#   effect_mean: -2.678013738107512
#   effect_std: 2.035088246195745
#   quality: 2.0085103035806338
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.125, 'reject_h0': False}
#   actions:
#     - Bom Retiro: 0.000 | Criar programa “Medicamento em Casa” no município.
#     - Diamantino: -4.558 | Criar o programa “Medicamento em Casa” no município.
#     - Parauapebas: -2.240 | Criar o programa “Medicamento em Casa” no município.
#     - Ipameri: -3.914 | Criar o programa “Medicamento em Casa” no município.
#
# Policy: Instituir a Campanha Dezembro “Verde” contra o abandono de animais no município.
#   effect_mean: -3.654436485893875
#   effect_std: 5.168153641182192
#   quality: 1.8272182429469375
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Quatis: -7.309 | Instituir a Campanha Dezembro “Verde” contra o abandono de animais no município.
#     - Guanhães: 0.000 | Instituir a Campanha Dezembro “Verde”- Não ao abandono de animais no município.
#
# Policy: Instituir a Semana de Conscientização “Não Jogue No Lixo” no município.
#   effect_mean: -2.5718611638027307
#   effect_std: 6.837165006052207
#   quality: 1.2859305819013653
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Caruaru: -7.406 | Instituir a Semana de Conscientização “Não Jogue No Lixo” no município.
#     - Natal: 2.263 | Instituir a Semana de Conscientização “Não Jogue No Lixo” no município.
#
# Policy: Criar o programa “Merenda nas Férias” no município.
#   effect_mean: -1.2644749101557298
#   effect_std: 0.2823533000878022
#   quality: 1.2644749101557298
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.25, 'reject_h0': False}
#   actions:
#     - Natal: -1.065 | Criar o programa “Merenda nas Férias” no município.
#     - Natal: -1.464 | Criar o programa “Merenda nas Férias” no município.
#
# Policy: Criar o programa “Rua Para Todos” no município.
#   effect_mean: -2.366642597373442
#   effect_std: 3.415906368096824
#   quality: 1.183321298686721
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.25, 'reject_h0': False}
#   actions:
#     - Natal: -2.662 | Criar o programa “Rua Para Todos” no município.
#     - Capitão Enéas: -7.088 | Criar o programa “Rua Para Todos” no município.
#     - Franca: 0.284 | Criar o programa “Rua Para Todos” no município.
#     - Rio Grande: 0.000 | Criar o programa “Rua Para Todos” no município.
#
# Policy: Criar o programa “Ponto Empoderado” no município.
#   effect_mean: -2.345160760770151
#   effect_std: 4.422077538435137
#   quality: 1.1725803803850754
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Votorantim: -5.472 | Criar o programa “Ponto Empoderado” no município.
#     - Votorantim: 0.782 | Criar o programa “Ponto Empoderado” no município.
#
# Policy: Instituir a ação cultural “O Jovem Poeta” no município.
#   effect_mean: -2.240155126144707
#   effect_std: 5.568936415248997
#   quality: 1.1200775630723534
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Araguari: 1.698 | Instituir a ação cultural “O Jovem Poeta” no município.
#     - Pires do Rio: -6.178 | Instituir a ação cultural “O Jovem Poeta” no município.
#
# Policy: Instituir o mês “Abril Laranja” como mês de prevenção da crueldade contra os animais no município.
#   effect_mean: -1.6280957554673559
#   effect_std: 3.868600472830447
#   quality: 1.0853971703115706
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.21875, 'reject_h0': False}
#   actions:
#     - Olinda: -2.572 | Instituir o mês “Abril Laranja” como mês de prevenção da crueldade contra os animais no município.
#     - Caruaru: 1.587 | Instituir o mês “Abril Laranja” como mês de prevenção da crueldade contra os animais no município.
#     - Ipameri: -7.828 | Instituir o mês “Abril Laranja” como mês de prevenção da crueldade contra os animais no município.
#     - São Mateus: -1.616 | Instituir o mês “Abril Laranja” como mês de prevenção da crueldade contra os animais no município.
#     - Esteio: -2.627 | Instituir o mês “Abril Laranja” para conscientização e prevenção da crueldade contra os animais no município.
#     - Carlos Barbosa: 3.287 | Instituir abril laranja, mês de prevenção da crueldade contra animais no município.
#
# Policy: Implantar o programa “Bueiro Imovel” como forma de prevenção às enchentes no município.
#   effect_mean: -2.084418968212611
#   effect_std: 2.9478135745140075
#   quality: 1.0422094841063054
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Rio Grande: -4.169 | Implantar o programa “Bueiro Imovel” como forma de prevenção às enchentes no município.
#     - Sant'Ana do Livramento: 0.000 | Implantar o programa “Bueiro Sustentável” como forma de prevenção às enchentes no município.
#
# Policy: Implantar dispositivo chamado “Boca de Lobo inteligente” no município.
#   effect_mean: -1.9338387791011211
#   effect_std: 2.6770786518489897
#   quality: 0.9669193895505606
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.25, 'reject_h0': False}
#   actions:
#     - Itaqui: 0.000 | Implantar dispositivo chamado “Boca de Lobo inteligente” no município.
#     - Erechim: -5.676 | Implantar dispositivo chamado “Boca de Lobo inteligente” no município.
#     - Nova Andradina: -2.059 | Implantar dispositivo chamado “Boca de Lobo inteligente” no município.
#     - Estância Velha: 0.000 | Implantar dispositivo chamado “Boca de Lobo inteligente” no município.
#
# Policy: Proibir blitz do IPVA no município.
#   effect_mean: -1.5535188069060684
#   effect_std: 7.333641074161443
#   quality: 0.932111284143641
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.40625, 'reject_h0': False}
#   actions:
#     - Anápolis: -5.014 | Proibir blitz do IPVA no município.
#     - Rio Grande: -3.648 | Proibir blitz do IPVA no município.
#     - Marabá: -9.380 | Proibir blitz do IPVA no município.
#     - Cáceres: 10.036 | Proibir blitz do IPVA no município.
#     - Campina Grande: 0.238 | Proibir blitz do IPVA no município.
#
# Policy: Criar o programa “Doe um Campo de Futebol” no município.
#   effect_mean: -1.8190611053272887
#   effect_std: 2.909756998899859
#   quality: 0.9095305526636444
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Tijucas: -3.877 | Criar o programa “Doe um Campo de Futebol” no município.
#     - Campina Grande: 0.238 | Criar o programa “Doe um Campo de Futebol” no município.
#
# Policy: Criar o programa de pagamento incentivado “Oportunidade Legal” no município.
#   effect_mean: -1.776809087786214
#   effect_std: 5.863170855955073
#   quality: 0.888404543893107
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Sant'Ana do Livramento: -5.923 | Criar o programa de pagamento incentivado “Oportunidade Legal” no município.
#     - Sant'Ana do Livramento: 2.369 | Criar o programa de pagamento incentivado “Oportunidade Legal” no município.
#
# Policy: Criar o programa “Doe uma Placa” no município.
#   effect_mean: -1.7063390495691495
#   effect_std: 2.413127825907508
#   quality: 0.8531695247845748
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Uruguaiana: -3.413 | Criar o programa “Doe uma Placa” no município.
#     - Capitão Enéas: 0.000 | Criar o programa “Doe uma Placa” no município.
#
# Policy: Criar o programa “Aluguel Social” no município.
#   effect_mean: -1.1845393918574763
#   effect_std: 1.6751916731300212
#   quality: 0.5922696959287381
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Sant'Ana do Livramento: -2.369 | Criar o programa “Aluguel Social” no município.
#     - Entre Rios de Minas: 0.000 | Criar o programa “Aluguel Social” no município.
#
# Policy: Realizar convênio de fomento com o Conselho Municipal de Segurança Pública para apoiar a realização do projeto “Transitolândia – Redução da Criminalidade e Violência e promoção da Defesa Social”.
#   effect_mean: -0.8953272868897229
#   effect_std: 1.2661839918821531
#   quality: 0.4476636434448614
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Araxá: 0.000 | Realizar convênio de fomento com o Conselho Municipal de Segurança Pública para apoiar a realização do projeto “Transitolândia – Redução da Criminalidade e Violência e promoção da Defesa Social”.
#     - Araxá: -1.791 | Realizar termo de fomento com o Conselho Municipal de Segurança Pública para apoiar o projeto “Transitolândia – Redução contínua da criminalidade e violência e promoção da defesa social.
#
# Policy: Criar o programa Cidade Limpa no município.
#   effect_mean: -0.8628053252344672
#   effect_std: 1.2201909926343126
#   quality: 0.4314026626172336
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Formosa: -1.726 | Criar o programa Cidade Limpa no município.
#     - São Carlos: 0.000 | Criar o programa Cidade Limpa no município.
#
# Policy: Criar o programa “sons e ruídos zero” para estabelecer medidas de proteção aos portadores do transtorno do espectro autista residentes no município.
#   effect_mean: -0.8345673006993672
#   effect_std: 3.203553073125837
#   quality: 0.4172836503496836
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Campina Grande: 1.431 | Criar o programa “sons e ruídos zero” para estabelecer medidas de proteção aos portadores do transtorno do espectro autista residentes no município.
#     - Campina Grande: -3.100 | Criar o programa “sons e ruídos zero” para estabelecer medidas de proteção aos portadores do transtorno do espectro autista residentes no município.
#
# Policy: Criar plano municipal de segurança pública no município.
#   effect_mean: -0.6175000611573185
#   effect_std: 2.0160573303585068
#   quality: 0.30875003057865924
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - São Mateus: 0.808 | Criar plano municipal de segurança pública no município.
#     - Canela: -2.043 | Criar plano municipal de segurança pública no município.
#
# Policy: Criar o programa de pagamento incentivado “Um Novo Tempo” no município.
#   effect_mean: -0.5922696959287381
#   effect_std: 0.8375958365650106
#   quality: 0.29613484796436906
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Sant'Ana do Livramento: 0.000 | Criar o programa de pagamento incentivado “Um Novo Tempo” no município.
#     - Sant'Ana do Livramento: -1.185 | Criar o programa de pagamento incentivado “Um Novo Tempo” no município.
#
# Policy: Criar o programa “Descarte Consciente” no município.
#   effect_mean: -0.5380648378499235
#   effect_std: 2.250829943146416
#   quality: 0.26903241892496177
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Natal: -2.130 | Criar o programa “Descarte Consciente” no município.
#     - Campinas: 1.054 | Criar o programa descarte consciente no município.
#
# Policy: Criar o programa “Farmácia Verde” no município.
#   effect_mean: -0.45482275445195164
#   effect_std: 1.992080959664295
#   quality: 0.22741137722597582
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Natal: -1.863 | Criar o programa “Farmácia Verde” no município.
#     - Campina Grande: 0.954 | Criar o programa “Farmácia Verde” no município.
#
# Policy: Alterar legislação municipal.
#   effect_mean: -0.39677501269679993
#   effect_std: 7.294619854165436
#   quality: 0.19838750634839997
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Caruaru: -5.555 | Alterar legislação municipal.
#     - Caruaru: 4.761 | Alterar legislação municipal e alterar legislação municipal.
#
# Policy: Criar o programa “Farmacia Solidária” no município.
#   effect_mean: -0.5150406454993268
#   effect_std: 3.1731452032655763
#   quality: 0.17168021516644227
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Paraíso do Sul: 0.000 | Criar o programa “Farmacia Solidária” no município.
#     - Sant'Ana do Livramento: 2.369 | Criar o programa “Farmácia Solidária” no município.
#     - Ipameri: -3.914 | Criar o programa “Farmácia Solidária” no município.
#
# Policy: Implantar o projeto “Doe uma Praça” no município.
#   effect_mean: -0.3987918442067597
#   effect_std: 1.5012584770103508
#   quality: 0.13293061473558657
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Santo Amaro da Imperatriz: 0.000 | Implantar o projeto “Doe uma Praça” no município.
#     - Formosa: 0.863 | Implantar o projeto “Doe uma Praça” no município.
#     - Nova Andradina: -2.059 | Implantar o projeto “Doe uma Praça” no município.
#
# Policy: Instituir a Semana de Combate aos Crimes Cibernéticos no município.
#   effect_mean: -0.15219748159502178
#   effect_std: 1.7395338276172678
#   quality: 0.10146498773001451
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.375, 'reject_h0': False}
#   actions:
#     - Natal: -0.399 | Instituir a Semana de Combate aos Crimes Cibernéticos no município.
#     - Anápolis: -1.755 | Instituir a Semana de Combate aos Crimes Cibernéticos no município.
#     - Araguari: 1.698 | Instituir a Semana de Combate aos Crimes Cibernéticos no município.
#
# Policy: Criar o programa municipal “Adote Uma Placa” no município.
#   effect_mean: -0.11922390009990957
#   effect_std: 0.16860805648030713
#   quality: 0.05961195004995479
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Carmo da Mata: 0.000 | Criar o programa municipal “Adote Uma Placa” no município.
#     - Campina Grande: -0.238 | Criar o programa “Adote Uma Placa” no município.
#
# Policy: Implantar ecopontos no município.
#   effect_mean: -0.11098307405884415
#   effect_std: 8.919344680123219
#   quality: 0.03699435801961472
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Luziânia: -9.085 | Implantar ecopontos no município.
#     - Pato Branco: 0.000 | Implantar ecopontos no município.
#     - Sarandi: 8.752 | Implantar ecopontos no município.
#
# Policy: Criar o programa “Sala de Acolhimento” no município.
#   effect_mean: -0.016721021069649566
#   effect_std: 2.0469437725371114
#   quality: 0.008360510534824783
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Natal: -1.464 | Criar o programa “Sala de Acolhimento” no município.
#     - Campina Grande: 1.431 | Criar o programa “Sala de Acolhimento” no município.
#
# Policy: Criar o programa “Agente Jovem do Meio Ambiente” no município.
#   effect_mean: -0.01672102106964868
#   effect_std: 2.04694377253711
#   quality: 0.00836051053482434
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Campina Grande: 1.431 | Criar o programa “Agente Jovem do Meio Ambiente” no município.
#     - Natal: -1.464 | Criar o programa “Agente Jovem do Meio Ambiente” no município.
#
# Policy: Realizar convênio de fomento com o Conselho Municipal de Segurança Pública para apoiar a realização do programa “De mãos dadas/Patronato – Redução da criminalidade e violência e promoção da defesa social.
#   effect_mean: -3.3306690738754696e-16
#   effect_std: 2.5323679837643054
#   quality: 1.6653345369377348e-16
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.5, 'reject_h0': False}
#   actions:
#     - Araxá: -1.791 | Realizar convênio de fomento com o Conselho Municipal de Segurança Pública para apoiar a realização do programa “De mãos dadas/Patronato – Redução da criminalidade e violência e promoção da defesa social.
#     - Araxá: 1.791 | Realizar convênio de fomento com o Conselho Municipal de Segurança Pública para apoiar a realização do programa “De mãos dadas/Patronato – Redução da criminalidade e violência e promoção da defesa social.
#
# Policy: Incluir a temática “Contra a Violência contra Mulheres e Meninas” no currículo das escolas do município.
#   effect_mean: 0.08046864941418834
#   effect_std: 0.9756305244127507
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.75, 'reject_h0': False}
#   actions:
#     - Montes Claros: 0.241 | Incluir a temática “Contra a Violência contra Mulheres e Meninas” no currículo das escolas do município.
#     - Montes Claros: 0.966 | Incluir a temática “Contra a Violência contra Mulheres e Meninas” no currículo das escolas do município.
#     - Montes Claros: -0.966 | Incluir a temática “Contra a Violência contra Mulheres e Meninas” no currículo das escolas do município.
#
# Policy: Criar fundo municipal para políticas penais no município.
#   effect_mean: 2.448706848611934
#   effect_std: 10.33250279053939
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.75, 'reject_h0': False}
#   actions:
#     - Marabá: 9.755 | Criar fundo municipal para políticas penais no município.
#     - Olinda: -4.857 | Criar fundo municipal para políticas penais no município.
#
# Policy: Criar o projeto “Cidade Limpa” no município.
#   effect_mean: 3.6140929153125136
#   effect_std: 7.995076968483511
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.8125, 'reject_h0': False}
#   actions:
#     - Canarana: 7.735 | Criar o projeto “Cidade Limpa” no município.
#     - Santana do Itararé: 18.136 | Criar o projeto “Cidade Limpa” no município.
#     - Porto Murtinho: 0.000 | Criar o projeto “Cidade Limpa” no município.
#     - Formosa: -2.588 | Criar o projeto “Cidade Limpa” no município.
#     - Carlos Barbosa: 0.000 | Criar o projeto “Cidade Limpa” no município.
#     - Natal: -1.597 | Criar o projeto “Cidade Limpa” no município.
#
# Policy: Instituir o mês “Maio Amarelo” para ações preventivas de conscientização para a redução de acidentes de trânsito no município.
#   effect_mean: 0.0
#   effect_std: 0.0
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': None, 'reject_h0': False}
#   actions:
#     - Pedra Preta: 0.000 | Instituir o mês “Maio Amarelo” para ações preventivas de conscientização para a redução de acidentes de trânsito no município.
#     - Toledo: 0.000 | Instituir o mês “Maio Amarelo” para promover ações preventivas e conscientização para a redução de acidentes de trânsito no município.
#
# Policy: Limpar terrenos no município.
#   effect_mean: 3.0716036486178138
#   effect_std: 8.001399369407162
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.90625, 'reject_h0': False}
#   actions:
#     - Ijaci: 14.280 | Limpar terrenos no município.
#     - Pedra Preta: 0.000 | Limpar terrenos urbanos no município.
#     - Butiá: -10.480 | Limpar terrenos baldios no município.
#     - Caruaru: 1.587 | Limpar terrenos baldios no município.
#     - Itapoá: 0.000 | Limpar terrenos baldios no município.
#     - Itapoá: 13.008 | Limpar terrenos baldios no município.
#     - Pires do Rio: 6.178 | Limpar terrenos baldios no município.
#     - Sant'Ana do Livramento: 0.000 | Limpar terrenos baldios no município.
#
# Policy: Proibir queimadas no município.
#   effect_mean: 1.4508880217662383
#   effect_std: 4.157994437432004
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.84375, 'reject_h0': False}
#   actions:
#     - Itabirito: -3.748 | Proibir queimadas no município.
#     - Barueri: -1.896 | Proibir queimadas no município.
#     - Formosa: 2.588 | Proibir queimadas no município.
#     - Guanhães: 6.203 | Proibir queimadas no município.
#     - Parauapebas: 4.107 | Proibir queimadas no município.
#
# Policy: Instituir o município como “pet friendly” no município.
#   effect_mean: 0.2645166751311976
#   effect_std: 0.0
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Caruaru: 0.265 | Instituir o município como “pet friendly” no município.
#     - Caruaru: 0.265 | Instituir o município como “pet friendly” no município.
#
# Policy: Instituir o Dia do Cac – Caça, Tiro e Coletor no município.
#   effect_mean: 3.825214284580092
#   effect_std: 0.4268865985075668
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Marabá: 4.127 | Instituir o Dia do Cac – Caça, Tiro e Coletor no município.
#     - Primavera do Leste: 3.523 | Instituir o Dia Municipal do Cac – Caça, Tiro e Coletor no calendário do município.
#
# Policy: Criar o programa “Doar um Espaço Público” no município.
#   effect_mean: 2.6583372100750995
#   effect_std: 3.759456535849261
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Canoinhas: 0.000 | Criar o programa “Doar um Espaço Público” no município.
#     - Toledo: 5.317 | Criar o programa “Doar um Espaço Público” no município.
#
# Policy: Criar o programa “Caçamba comunitária” no município.
#   effect_mean: 1.8970576900010274
#   effect_std: 7.0666541822916145
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.75, 'reject_h0': False}
#   actions:
#     - Campina Grande: -3.100 | Criar o programa “Caçamba comunitária” no município.
#     - Carmo do Paranaíba: 6.894 | Criar o programa “Caçamba comunitária” no município.
#
# Policy: Criar o programa “Doe Uma Lixeira” no município.
#   effect_mean: 2.566369222513255
#   effect_std: 5.911614887955042
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.875, 'reject_h0': False}
#   actions:
#     - Formiga: 0.000 | Criar o programa “Doe Uma Lixeira” no município.
#     - Natal: 5.723 | Criar o programa “Doe Uma Lixeira” no município.
#     - Araguari: 1.698 | Criar o programa “Doe Uma Lixeira” no município.
#     - Anápolis: 10.530 | Criar o programa “Doe Uma Lixeira” no município.
#     - Uruguaiana: -5.119 | Criar o programa “Doe Uma Lixeira” no município.
#
# Policy: Instituir o “Junho Violeta” no município.
#   effect_mean: 3.2754672675152947
#   effect_std: 8.55118233454059
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.625, 'reject_h0': False}
#   actions:
#     - Carlos Barbosa: 13.149 | Instituir o “Junho Violeta” no município.
#     - Formosa: -1.726 | Instituir o “Junho Violeta” no município.
#     - Natal: -1.597 | Instituir o “Junho Violeta” no município.
#
# Policy: Aumentar a quantidade de vagas de empregos do programa “Primeira Chance” no município.
#   effect_mean: 0.0
#   effect_std: 0.0
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': None, 'reject_h0': False}
#   actions:
#     - Franca: 0.000 | Aumentar a quantidade de vagas de empregos do programa “Primeira Chance” no município.
#     - Franca: 0.000 | Aumentar a quantidade de vagas de empregos do programa “Primeira Chance” no município.
#
# Policy: Criar o programa “Hora comunitária” no município.
#   effect_mean: 10.47998323202683
#   effect_std: 14.820934420174966
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Quilombo: 0.000 | Criar o programa “Hora comunitária” no município.
#     - Butiá: 20.960 | Criar o programa “Hora comunitária” no município.
#
# Policy: Criar o programa “Doe uma Praça” no município.
#   effect_mean: 4.977322749070303
#   effect_std: 5.043029999332411
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.984375, 'reject_h0': False}
#   actions:
#     - Dois Irmãos: -3.256 | Criar o programa “Doe uma Praça” no município.
#     - Careaçu: 0.000 | Criar o programa “Doe uma Praça” no município.
#     - Luiz Alves: 8.559 | Criar o programa “Doe uma Praça” no município.
#     - Quirinópolis: 6.192 | Criar o programa “Doe uma Praça” no município.
#     - Formosa: 6.902 | Criar o programa “Doe uma Praça” no município.
#     - Schroeder: 4.985 | Criar o programa “Doe uma Praça” no município.
#     - Juara: 11.459 | Criar o programa “Doe uma Praça” no município.
#
# Policy: Instituir o “Setembro Amarelo” no município.
#   effect_mean: 4.367671305324058
#   effect_std: 5.13605367139098
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.9375, 'reject_h0': False}
#   actions:
#     - Armação dos Búzios: 4.999 | Instituir o “Setembro Amarelo” no município.
#     - Diamantino: 9.115 | Instituir o “Setembro Amarelo” no município.
#     - Barra do Garças: -2.890 | Instituir o “Setembro Amarelo” no município.
#     - Bocaiúva: 6.246 | Instituir o “Setembro Amarelo” no município.
#
# Policy: Instituir a Campanha “Coração de Mulher” no município.
#   effect_mean: 1.122820307225544
#   effect_std: 2.6957056290116435
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.875, 'reject_h0': False}
#   actions:
#     - Natal: -2.130 | Instituir a Campanha “Coração de Mulher” no município.
#     - Quilombo: 0.000 | Instituir a Campanha “Coração de Mulher” no município.
#     - Marabá: 3.752 | Instituir a Campanha “Coração de Mulher” no município.
#     - Luziânia: 2.869 | Instituir a Campanha “Coração de Mulher” no município.
#
# Policy: Criar o projeto “Doe uma Placa” no município.
#   effect_mean: 0.0
#   effect_std: 0.0
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': None, 'reject_h0': False}
#   actions:
#     - São Francisco de Assis: 0.000 | Criar o projeto “Doe uma Placa” no município.
#     - Barra do Garças: 0.000 | Criar o projeto “Doe uma Placa” no município.
#
# Policy: Alterar o quadro do pessoal do município.
#   effect_mean: 0.0
#   effect_std: 0.0
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': None, 'reject_h0': False}
#   actions:
#     - Heliodora: 0.000 | Alterar o quadro do pessoal do município.
#     - Heliodora: 0.000 | Alterar o quadro de pessoal do município.
#
# Policy: Criar o programa “Doe um Ponto de ônibus” no município.
#   effect_mean: 0.3508381228391132
#   effect_std: 5.425432400126183
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.38043212890625, 'reject_h0': False}
#   actions:
#     - Itapoá: 13.008 | Criar o programa “Doe um Ponto de ônibus” no município.
#     - Natal: -0.399 | Criar o programa “Doe um Ponto de ônibus” no município.
#     - Anápolis: -3.510 | Criar o programa “Doe um Ponto de ônibus” no município.
#     - Quatis: -7.309 | Criar o programa “Doe um Ponto de ônibus” no município.
#     - Campinas: -0.088 | Criar o programa “Doe um Ponto de ônibus” no município.
#     - Sarandi: 4.376 | Criar o programa “Doe um Ponto de ônibus” no município.
#     - Campina Grande: -1.431 | Criar o programa “Doe um Ponto de ônibus” no município.
#     - Campina Grande: -4.292 | Criar o programa “Doe um Ponto de ônibus” no município.
#     - Anápolis: -2.006 | Criar o programa “Doe um Ponto de ônibus” no município.
#     - Xangri-lá: 6.074 | Criar o programa “Doe um Ponto de ônibus” no município.
#     - Francisco Beltrão: 7.241 | Criar o programa “Doe um Ponto de ônibus” no município.
#     - Natal: -1.863 | Criar o programa municipal “Doe um Ponto de ônibus” no município.
#     - Araxá: -1.791 | Criar o programa “Doe Um Ponto de ônibus” no município.
#     - Campina Grande: -3.100 | Criar o programa “Doe Um Ponto de ônibus” no município.
#
# Policy: Proibir a comercialização e utilização do cachimbo “Neguilé” no município.
#   effect_mean: 0.0
#   effect_std: 0.0
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': None, 'reject_h0': False}
#   actions:
#     - Pedra Preta: 0.000 | Proibir a comercialização e utilização do cachimbo “Neguilé” no município.
#     - Pedra Preta: 0.000 | Proibir a comercialização e utilização do cachimbo “Neguilé” no município.
#
# Policy: Criar o projeto “Doar uma Lixeira” no município.
#   effect_mean: 2.740186584137251
#   effect_std: 4.920435740613206
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Estância Velha: 0.000 | Criar o projeto “Doar uma Lixeira” no município.
#     - Pontal do Araguaia: 0.000 | Criar o projeto “Doar uma Lixeira” no município.
#     - São Francisco de Assis: 11.352 | Criar o projeto “Doar uma Lixeira” no município.
#     - São Francisco de Assis: 0.000 | Criar o projeto “Doar uma Lixeira” no município.
#     - Primavera do Leste: 2.349 | Criar o projeto “Doar uma Lixeira” no município.
#
# Policy: Criar programa municipal de redução gradativa do número de veículos de tração animal no município.
#   effect_mean: 1.476212882978155
#   effect_std: 3.9451392847111766
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.75, 'reject_h0': False}
#   actions:
#     - Uruguaiana: 4.266 | Criar programa municipal de redução gradativa do número de veículos de tração animal no município.
#     - Esteio: -1.313 | Criar programa de redução gradativa do número de veículos de tração animal no município.
#
# Policy: Criar pipódromos no município.
#   effect_mean: 1.541976291882169
#   effect_std: 2.553231956048315
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.875, 'reject_h0': False}
#   actions:
#     - Campina Grande: -0.954 | Criar pipódromos no município.
#     - Campina Grande: 1.431 | Criar pipódromos no município.
#     - Espera Feliz: 4.149 | Criar pipódromos no município.
#
# Policy: Criar o programa “Inclusão Digital da Terceira Idade” no município.
#   effect_mean: 1.142935515578212
#   effect_std: 1.3093971286476342
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Olinda: 0.857 | Criar o programa “Inclusão Digital da Terceira Idade” no município.
#     - Pato Branco: 0.000 | Criar o programa “Inclusão Digital da Terceira Idade” no município.
#     - Olinda: 2.572 | Criar o programa “Inclusão Digital da Terceira Idade” no município.
#
# Policy: Instalar dispositivo chamado “Boca de Lobo inteligente” nos logradouros do município.
#   effect_mean: 1.4326040387701564
#   effect_std: 0.002711383375541003
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Luziânia: 1.435 | Instalar dispositivo chamado “Boca de Lobo inteligente” nos logradouros do município.
#     - Campina Grande: 1.431 | Instalar dispositivo chamado “Boca de Lobo inteligente” nos logradouros do município.
#
# Policy: Fixar o salário mínimo no município.
#   effect_mean: 8.15128790348875
#   effect_std: 11.527661903921544
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Heliodora: 16.303 | Fixar o salário mínimo no município.
#     - Heliodora: 0.000 | Fixar o salário mínimo no município.
#
# Policy: Criar o projeto “Doar uma Área Pública” no município.
#   effect_mean: 1.849336993561025
#   effect_std: 2.9991972151916197
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.875, 'reject_h0': False}
#   actions:
#     - Marabá: 4.877 | Criar o projeto “Doar uma Área Pública” no município.
#     - Araxá: 1.791 | Criar o projeto “Doar uma Área Pública” no município.
#     - Parauapebas: -1.120 | Criar o projeto “Doar uma Área Pública” no município.
#
# Policy: Alterar o perímetro urbano do município.
#   effect_mean: 4.381928925112835
#   effect_std: 7.5897235334511075
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Ribas do Rio Pardo: 0.000 | Alterar o perímetro urbano do município.
#     - Porto dos Gaúchos: 0.000 | Alterar o perímetro urbano do município.
#     - Paranaiguara: 13.146 | Alterar o perímetro urbano do município.
#
# Policy: Criar o programa “Adote uma Praça” no município.
#   effect_mean: 1.4442910744922255
#   effect_std: 4.301362426263715
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 0.75, 'reject_h0': False}
#   actions:
#     - Natal: -1.597 | Criar o programa “Adote uma Praça” no município.
#     - Campo Verde: 4.486 | Criar o programa “Adote uma Praça” no município.
#
# Policy: Instituir a Campanha Segurança 60 + no município.
#   effect_mean: 6.366290914029607
#   effect_std: 6.6024162985977375
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Araguari: 11.035 | Instituir a Campanha Segurança 60 + no município.
#     - Araguari: 1.698 | Instituir a Campanha Segurança 60+ no município.
#
# Policy: Criar o programa “Planejando Vida” no município.
#   effect_mean: 1.790654573779445
#   effect_std: 0.0
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Araxá: 1.791 | Criar o programa “Planejando Vida” no município.
#     - Araxá: 1.791 | Criar o programa “Planejando Vida” no município.
#
# Policy: Criar o programa “Horas comunitárias e compostagem” no município.
#   effect_mean: 0.0
#   effect_std: 0.0
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': None, 'reject_h0': False}
#   actions:
#     - Lagoa da Prata: 0.000 | Criar o programa “Horas comunitárias e compostagem” no município.
#     - Lagoa da Prata: 0.000 | Criar o programa “Horas comunitárias e compostagem” no município.
#
# Policy: Criar o programa agente mirim no município.
#   effect_mean: 2.6583372100750995
#   effect_std: 3.759456535849261
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Toledo: 5.317 | Criar o programa agente mirim no município.
#     - Corbélia: 0.000 | Criar o programa agente mirim no município.
#
# Policy: Criar o programa “Bucando uma Nova oportunidade” no município.
#   effect_mean: 3.9241636611442616
#   effect_std: 1.8890324926589357
#   quality: 0.0
#   effective: {'test': 'wilcoxon_signed_rank', 'p_value': 1.0, 'reject_h0': False}
#   actions:
#     - Luziânia: 5.260 | Criar o programa “Bucando uma Nova oportunidade” no município.
#     - Formosa: 2.588 | Criar o programa “Bucando uma Nova oportunidade” no município.
