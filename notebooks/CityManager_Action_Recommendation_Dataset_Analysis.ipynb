# %%
# Download the Action Recommendation Dataset
# !gdown "1ECcRj3u6g04z-4ODNSHoJC3jRz6ba0nd"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ECcRj3u6g04z-4ODNSHoJC3jRz6ba0nd
# From (redirected): https://drive.google.com/uc?id=1ECcRj3u6g04z-4ODNSHoJC3jRz6ba0nd&confirm=t&uuid=2d562d54-f13d-4b7f-b177-11583e02b6ea
# To: /content/dataset.npy
# 100% 487M/487M [00:05<00:00, 82.1MB/s]

# %%
import numpy as np

with open("/content/dataset.npy", "rb") as f:
  dataset = np.load(f, allow_pickle=True)

len(dataset)
# Out:
# 220065

# %%
cities = list(set([row['municipio'] for row in dataset]))
len(cities)
# Out:
# 322

# %%
years = list(set([row['ano'] for row in dataset]))[2:]
print(f"{min(years)} até {max(years)}")
# Out:
# 1948 até 2026

# %%
embeddings = [row['embedding'] for row in dataset]
embeddings = np.concat([embeddings])

embeddings.shape
# Out:
# (220065, 768)

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# Carrega o modelo uma única vez (fora da função, para não recarregar toda hora)
model = SentenceTransformer("embaas/sentence-transformers-multilingual-e5-base")

def top_k_similares(texto: str,
                    embeddings: np.ndarray,
                    k: int = 5) -> np.ndarray:
    """
    Retorna os índices das k embeddings mais similares semanticamente ao `texto`.

    Parâmetros
    ----------
    texto : str
        Texto de entrada.
    embeddings : np.ndarray
        Matriz de embeddings com shape (N, 768), por exemplo (250000, 768).
        Idealmente pré-computadas com o mesmo modelo.
    k : int
        Número de vizinhos mais próximos a retornar.

    Retorno
    -------
    np.ndarray
        Array 1D com os índices das k embeddings mais similares.
    """

    # 1) Codificar o texto de entrada em um embedding
    # Para modelos E5, é comum prefixar com "query: "
    consulta = f"query: {texto}"
    embedding_texto = model.encode(
        consulta,
        normalize_embeddings=True  # já normaliza o vetor (norma L2 = 1)
    )  # shape (768,)

    # 2) Garantir que a matriz de embeddings também está normalizada
    #    (se você já salvou normalizada, pode pular esse passo)
    normas = np.linalg.norm(embeddings, axis=1, keepdims=True)
    # Evitar divisão por zero
    normas[normas == 0] = 1e-12
    embeddings_norm = embeddings / normas

    # 3) Similaridade por produto interno (equivale a cosseno se tudo está normalizado)
    #    resultado: vetor de similaridades shape (N,)
    scores = embeddings_norm @ embedding_texto

    # 4) Pegar os índices das k maiores similaridades
    # argpartition é mais eficiente que sort para top-k
    if k >= len(scores):
        # Se k >= N, só ordena tudo
        return np.argsort(-scores)

    idx_part = np.argpartition(-scores, k)[:k]  # k maiores (desordenados)
    # Ordenar esses k pelo score decrescente
    idx_ordenados = idx_part[np.argsort(-scores[idx_part])]

    return idx_ordenados
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/714 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
texto = "Como diminuir a criminalidade no município?"
k = 500

indices_top_k = top_k_similares(texto, embeddings, k)
print(indices_top_k)
# Out:
# [ 12479  48686   7426 213973  11019  94971 196688 210445 157034  37436
#  168764 203921  97511  33654  14725  10419 158341 174584 118846 196125
#  198567 197334 128310 213562 117036 108211 200695  56639 212763  46380
#  148841  63776  12887  29797 164197   1106 130135 197511  20958  77571
#  183625 150897 195491 130131 163983 144569 190195 148523 162955 117808
#  141156 206339  46866  94430  53949  57498  72786 136196 186662  24626
#   54428 138455 133062 214727   9560 134060   9979  13735 139995 175152
#  124248 194842  58907 178995   1564 116079  12976  73205   7214  11644
#  140249  69691   7278  32602 205807   7241 168737 165879  20921 173239
#  125104 166680 163726 170183  20503  29792  21789  46394 171582 131656
#  121916 127885  66888 109009  79770 201818  21753 179651  28725 152835
#    6942 141249 150195 154028 114198  53935  67145 204112 181844  11632
#   29769  38683 188439 148667 173212 191683  94575 176233  45878  34499
#    9362 144850 190963 117232 199607 174615   9343 214475 167971 136423
#   11228 184166 141494 202902 203700 126561 111513 131197  58983 205283
#   14122  29645  33982  12551  12511 135531  83568 180810 200321  20159
#    7319  32944 154485  37955  12182 154635 185873 154785 126503  40736
#  185612 163533  21848  21732 166767 182622  85358  11876  11885 164026
#  128930   7213  80928 102951  71527   1264 195361 199204 168763  90956
#   23491 131447 176745 136664 213043 161096 194828 127886 149055  89492
#   79720 165332 213473 153972  18646 197770 123222  60161  53994  30007
#   63780 142811 115867   2239 189479   6711 151275 195342 199412 145452
#   35306 135860 144289   6525  12105  36293  10647   9421 116120  28102
#  128292  21774 164182  13497 111524 148594 187585 159672  12221 193177
#   34406  70604  70888  52692 198600 159382   1606   9542 137557   7545
#  140480 137306  24541  78248 201106  22562 109794 153781 125596  75169
#   30154 148891   2556  31813  31775  31783 155932  55714 132901 175421
#   30243  37102  29938  60896  61914  59321 167944  99650  15960  46415
#   85355 109656 213805 218808  37678  83569 119419 200958 196604 196435
#   65561   7172 170787 138874  82153  27165 151309 168020 214349 157111
#  146694  28499 112074 202583 167458   7580 159833  51621 211381   9897
#  174644   9120 150202  81232  33085 116386  89975 111532 163004 144872
#   43814 214014  12365 188118 199265  16821 214300  10511  60885 159838
#   27577 149467 142272 101270 207432   6686  34936  84650   7168 168488
#   70607   7014  28945  30696  89264   9444 215931  12922 127497 213392
#  173737  90758  20266 151928  29082 131095 160323 169488  53913  24715
#   31402   6140 104896  59447 210239  66936 128938 111544 127838 112436
#    8614  89746 116144  28994  11308 206387 206405 121044  18530 165551
#   95160 197816  74759 106280 111631 203326  12539  14113 186325 106500
#   13108 126139   9273 142225   7987 123061  37188  31793  31791  87054
#  162314 112534  18522 118231 171099  57308   7339 181916 180848  75262
#  134580 146624 178783 197467   6684 121824  38157 166684  43745 205843
#  128577  33236 169643 110565  35534  38963  21705    664  22614 103479
#  144391  46658  37587    127  59867  82535 136306 155882 146690  30020
#   59304    307     90 130189  46361 213806   7129   4892  37625  63530
#   10487    960   6541  24640 191027 156024 136571 122281 217600 118536
#  141115  25981   7236 170832  75242 140817  73560 106333  43827 195517
#  138129 189796 189559  75035   8750  32983  98858 153829 121346  49511
#  140610 187239 165267 158661 178650  30170 181981  95922 132598 213815
#   55247   1518 165062 213871 212388 100113  12006  35305 140333   6843]

# %%
results = dataset[indices_top_k]
[(row['municipio'], row['acao']) for row in results]
# Out:
# [('Caruaru',
#   'Implementar programa de prevenção às drogas, denominado “Esporte Sim, Drogas Não”, no município.'),
#  ('Guarujá do Sul', 'Criar o programa “Juro Zero” no município.'),
#  ('Campina Grande',
#   'Criar o programa municipal “Dignidade em Foco” no município.'),
#  ('Natal', 'Criar o programa “Descarte Consciente” no município.'),
#  ('Caruaru', 'Criar o programa “Mulheres Sem Violência” no município.'),
#  ('Xangri-lá', 'Criar o programa “Deidentifique Nossas Ruas” no município.'),
#  ('Sarandi', 'Criar o projeto “Diga Não às Drogas” no município.'),
#  ('Pato Branco', 'Criar programa municipal antivandalismo no município.'),
#  ('Itaporanga', 'Criar o programa “Infância Sem Violência” no município.'),
#  ('Palmital', 'Criar o programa “Cidade Limpa” no município.'),
#  ('Votorantim', 'Criar o projeto “Recorte Legal” no município.'),
#  ('Natal',
#   'Criar programa de cooperação e o código “Sinal Vermelho” no município para combater e prevenir a violência doméstica e familiar.'),
#  ('Primavera do Leste', 'Criar o programa “Pichação Zero” no município.'),
#  ('Campinas',
#   'Criar política municipal de prevenção à corrupção no município.'),
#  ('Campina Grande',
#   'Implementar política municipal contra pichações no município.'),
#  ('Campina Grande',
#   'Instituir a campanha “A abuso sexual no ônibus é crime” no município.'),
#  ('Francisco Beltrão', 'Criar programa de combate à pichação no município.'),
#  ('Barueri', 'Criar programa de combate à pichação no município.'),
#  ('Tapurah',
#   'Reconhecer o risco da atividade de caçadores, atiradores esportivos e colecionadores de cac’s no município.'),
#  ('Montes Claros',
#   'Incluir a temática “Contra a Violência contra Mulheres e Meninas” no currículo das escolas do município.'),
#  ('Montes Claros',
#   'Incluir a temática “Contra a Violência contra Mulheres e Meninas” no currículo das escolas do município.'),
#  ('Montes Claros',
#   'Incluir a temática “Contra a Violência contra Mulheres e Meninas” no currículo das escolas do município.'),
#  ('Natal', 'Criar o programa “Desconecta” no município.'),
#  ('Montes Claros', 'Criar o projeto “Segurança Participativa” no município.'),
#  ('Araxá',
#   'Realizar convênio de fomento com o Conselho Municipal de Segurança Pública para apoiar a realização do projeto “Transitolândia – Redução da Criminalidade e Violência e promoção da Defesa Social”.'),
#  ('Luziânia',
#   'Incluir o Dia Municipal do Perito Criminal no calendário do município.'),
#  ('Barueri', 'Instituir o “Hino à Negritude” no município.'),
#  ('Tijucas do Sul', 'Criar programa de combate a pichações no município.'),
#  ('Natal', 'Criar programa de combate a pichações no município.'),
#  ('Esteio', 'Criar programa de combate a pichações no município.'),
#  ('Parauapebas',
#   'Instituir a campanha “Morte Zero no Trânsito” no município.'),
#  ('Santana do Itararé', 'Criar o programa “Hora Cidadã” no município.'),
#  ('Caruaru', 'Instituir o Dia “Sem Carro” no município.'),
#  ('Armação dos Búzios',
#   'Criar programa de combate às pichações no município.'),
#  ('Olinda', 'Criar programa de combate às pichações no município.'),
#  ('Marabá', 'Criar fundo municipal para políticas penais no município.'),
#  ('Olinda', 'Criar fundo municipal para políticas penais no município.'),
#  ('Natal',
#   'Instituir a Campanha Junho Violento – Violentos contra a Violência no município.'),
#  ('Formiga',
#   'Criar o projeto “Cidade Mais Limpa” para coletar e remover objetos e materiais inservíveis no município.'),
#  ('Toledo', 'Reestruturar o programa “Encipar” no município.'),
#  ('Araxá', 'Criar programa antidrogas no município.'),
#  ('Sarandi', 'Criar política municipal antipichação no município.'),
#  ('Barueri', 'Implantar programa de desarmamento no município.'),
#  ('Olinda',
#   'Implementar medidas de prevenção e penalização da prática de “surf em ônibus” no município.'),
#  ('Anápolis', 'Incentivar o valor honestidade no município.'),
#  ('Uruguaiana',
#   'Criar programa social denominado “João de barro” no município.'),
#  ('Pato Branco', 'Criar o programa “Cidade Contra a Dengue” no município.'),
#  ('Lagoa da Prata', 'Criar o projeto “Cidade Limpa” no município.'),
#  ('Formosa', 'Criar o projeto “Cidade Limpa” no município.'),
#  ('Canarana', 'Criar o projeto “Cidade Limpa” no município.'),
#  ('Lagoa da Prata', 'Criar o projeto “Cidade Limpa” no município.'),
#  ('Natal', 'Criar o projeto “Cidade Limpa” no município.'),
#  ('Carlos Barbosa', 'Criar o projeto “Cidade Limpa” no município.'),
#  ('Porto Murtinho', 'Criar o projeto “Cidade Limpa” no município.'),
#  ("Sant'Ana do Livramento", 'Criar o projeto “Cidade Limpa” no município.'),
#  ('Santana do Itararé', 'Criar o projeto “Cidade Limpa” no município.'),
#  ('Frederico Westphalen', 'Criar o programa “Calçada Legal” no município.'),
#  ('Lagoa da Prata', 'Criar o programa “Praia Sem Drogas” no município.'),
#  ('Rio Grande', 'Implementar o dispositivo “Bueiro Coletor” no município.'),
#  ('Juazeiro', 'Criar o programa “Transito Cidadão” no município.'),
#  ('Guarujá do Sul', 'Implantar o programa “Recolhe” no município.'),
#  ('Paty do Alferes', 'Criar a Polícia Municipal no município.'),
#  ('Paty do Alferes', 'Criar a Polícia Municipal no município.'),
#  ('Natal',
#   'Criar programa de combate a pichações e depredações no município.'),
#  ('Campina Grande',
#   'Instituir a campanha “Pequeno silvestre não é Pet” no município.'),
#  ('Barueri', 'Implementar programa de desarmamento no município.'),
#  ('Campina Grande', 'Criar o programa “Liberdade Cidadã” no município.'),
#  ('Caruaru', 'Criar o projeto “Ver Direito” no município.'),
#  ('Barueri', 'Criar o programa “Esse Zero” no município.'),
#  ('Votorantim',
#   'Criar o programa “Minha Cidade Cada vez Mais Limpa” no município.'),
#  ('Esteio',
#   'Desafetar imóveis de propriedade do município da classe de “bem público” para a classe de “bem dominial”.'),
#  ('Pato Branco', 'Instituir a “Caminhada” no município.'),
#  ('Santo Antônio do Sudoeste',
#   'Criar e regulamentar o programa “Cuidar Cidadão” no município.'),
#  ('Anápolis', 'Instituir a campanha “Meio Ambiente Limpo” no município.'),
#  ('Marabá', 'Criar o projeto “Tudo Limpo” no município.'),
#  ('Parauapebas',
#   'Criar o programa “Portnes para Segurança e Fiscalização” no município.'),
#  ('Campina Grande',
#   'Instalar sinalização luminosa indicando a existência de radares e “pardais” nas vias do município.'),
#  ('Uruguaiana',
#   'Criar política municipal de prevenção e enfrentamento à “ciberpedofilia” no município.'),
#  ('Campina Grande', 'Criar o programa “Fiscal Cidadão” no município.'),
#  ('Campina Grande',
#   'Criar a campanha “Pare de dirigir teclando” no município.'),
#  ('Araxá',
#   'Assinar convênio com o Consep para implementar o programa “Redução da Criminalidade e Violência e promoção da defesa social, responsabilidade de todos”.'),
#  ('Estância Velha', 'Criar o projeto “Seja Legal, Grafite!” no município.'),
#  ('Campina Grande',
#   'Criar campanha municipal de combate à pichação no município.'),
#  ('Campinas',
#   'Criar o programa municipal de políticas sobre drogas “Recomeço de campinas: Só por Hoje” no município.'),
#  ('Natal', 'Instituir a “Hora do Esporte” no município.'),
#  ('Campina Grande', 'Criar programa de combate à pedofilia no município.'),
#  ('Votorantim', 'Criar o programa “Abrace Bem” no município.'),
#  ('Votorantim', 'Criar o programa “Abrace Bem” no município.'),
#  ('Guanhães', 'Criar o programa “Praça da Juventude no município”.'),
#  ('Natal',
#   'Proibir que condenados por crimes de racismo assumam cargos públicos no município.'),
#  ('Ipameri', 'Criar programa de combate ao vandalismo no município.'),
#  ('Formosa', 'Criar plano municipal de combate à pedofilia no município.'),
#  ("Sant'Ana do Livramento",
#   'Criar o programa de pagamento incentivado “Oportunidade Legal” no município.'),
#  ("Sant'Ana do Livramento",
#   'Criar o programa de pagamento incentivado “Oportunidade Legal” no município.'),
#  ('Itabirito', 'Criar o programa “Inegridade Cultural Escolar” no município.'),
#  ('Armação dos Búzios',
#   'Criar programa municipal de combate a acidentes de trânsito “Transito Mais Seguro” no município.'),
#  ('Guanhães', 'Instituir o “Benficar Social” no município.'),
#  ('Esteio', 'Criar o programa “Medicapet” no município.'),
#  ('Pedra Preta',
#   'Instituir o mês “Maio Amarelo” para ações preventivas de conscientização para a redução de acidentes de trânsito no município.'),
#  ('Querência', 'Criar o programa “Sorria Querência” no município.'),
#  ('Araxá',
#   'Realizar convênio de fomento com o Conselho Municipal de Segurança Pública para apoiar a realização do programa “De mãos dadas/Patronato – Redução da criminalidade e violência e promoção da defesa social.'),
#  ('Araxá',
#   'Realizar convênio de fomento com o Conselho Municipal de Segurança Pública para apoiar a realização do programa “De mãos dadas/Patronato – Redução da criminalidade e violência e promoção da defesa social.'),
#  ('Três Barras do Paraná',
#   'Criar o programa “Ajuda para Melhoria Habitacional” no município.'),
#  ('Uruguaiana',
#   'Criar o programa de cooperação “Sinal Vermelho” para discutir medidas de combate à violência contra a mulher no município.'),
#  ('Pelotas',
#   'Implementar o programa “Prevenção antes da repressão: pensando a cultura de paz” no município.'),
#  ('Montes Claros', 'Proibir jogar lixo no chão no município.'),
#  ('Itabirito', 'Criar o programa “Juventude Solidária” no município.'),
#  ('Diamantino', 'Criar o programa “Homem de Honra” no município.'),
#  ('Indianópolis', 'Criar política municipal antidrogas no município.'),
#  ('São Mateus',
#   'Criar programa municipal de combate às notícias falsas (“Fake News”'),
#  ('Campina Grande', 'Criar o programa “Roda da Cidadania” no município.'),
#  ('Natal',
#   'Implementar medidas de enfrentamento à cultura do crime organizado no município.'),
#  ('Luziânia', 'Instituir a campanha “Verdão Vermelho” no município.'),
#  ('Natal',
#   'Instituir a corrida cristã “Corr contra as Drogas” no calendário oficial do município.'),
#  ('Pires do Rio',
#   'Implantar o programa municipal “Te Vejo Melhor” no município.'),
#  ("Sant'Ana do Livramento",
#   'Criar o programa “Envelhecer com Dignidade” no município.'),
#  ('Agudo', 'Criar o programa “Concretizando” no município.'),
#  ('Sarandi',
#   'Doar área de terras destinadas à construção de um “Módulo Policial” no município.'),
#  ('Três Passos', 'Alterar o programa “025” da Lei Municipal no 3.787/03.'),
#  ('Campina Grande', 'Criar o programa “Guarda Maria da Penha” no município.'),
#  ('Armação dos Búzios',
#   'Criar programa municipal de combate a acidentes de trânsito denominado “Transito Mais Seguro” para implementar sinalização nas vias públicas do município.'),
#  ('Franca', 'Criar o programa “Casa Pet” no município.'),
#  ('Araxá', 'Criar o programa “Fiscal da Cidade” no município.'),
#  ('Toledo', 'Criar o “Projeto Grafite” no município.'),
#  ('Natal', 'Instituir a Campanha “Cordão Dourado” no município.'),
#  ('Pato Branco', 'Criar o programa “Asfalto 100%” no município.'),
#  ('Carlos Barbosa',
#   'Prevenção e punição de atos de pichação, vandalismo e depredação no município.'),
#  ('Formosa',
#   'Criar o programa “Jovem na Política” para incentivar a participação de jovens nas atividades políticas do município.'),
#  ('Estância Velha',
#   'Instituir campanha de conscientização, prevenção e enfrentamento à violência contra a pessoa idosa “Junho Violento” no município.'),
#  ('Campinas', 'Criar o programa “Escola sem Crítica” no município.'),
#  ('Campina Grande', 'Criar o programa “Bicicletar” no município.'),
#  ('Anápolis', 'Instituir a campanha pública “Tomada Premiada” no município.'),
#  ('Votorantim',
#   'Criar o programa “Cidade Solidária – Cidade Limpa” no município.'),
#  ('Ipameri', 'Instituir a Campanha “Destinação do Bem” no município.'),
#  ('Pato Branco',
#   'Instituir a Lei “Sargento Xavier Guerreiro de Combate à Pedofilia” no município.'),
#  ('Barueri', 'Implementar programa Criança Sem Violência no município.'),
#  ('Campina Grande', 'Instituir a Campanha “Pequenas de Valor” no município.'),
#  ('Natal',
#   'Instituir a campanha “Duncie descarte irregular de resíduos” no município.'),
#  ('Manhuaçu', 'Criar o programa “Tor Maria da Penha” no município.'),
#  ('Major Vieira', 'Proibir a prática de nepotismo no município.'),
#  ('Belo Jardim', 'Implementar lombadas no município.'),
#  ('Diamantino',
#   'Criar secretaria municipal de prevenção às drogas no município.'),
#  ('Toledo', 'Criar o programa “Engencipar” no município.'),
#  ('Rio Grande', 'Extingue a taxa de coleta de lixo no município.'),
#  ('Rio Grande', 'Extingue a taxa de coleta de lixo no município.'),
#  ('Cabo de Santo Agostinho',
#   'Criar o programa “Cabo por uma infância sem racismo” no município.'),
#  ('Ipameri', 'Instituir a campanha “Alerta dengue” no município.'),
#  ('Ipameri', 'Criar o programa “Melhor em Casa” no município.'),
#  ('Erechim',
#   'Regulamentar a atividade de diversão pública na modalidade “drive-in” no município.'),
#  ('Natal',
#   'Instituir a Semana de Conscientização “Não Jogue No Lixo” no município.'),
#  ('Caruaru',
#   'Instituir a Semana de Conscientização “Não Jogue No Lixo” no município.'),
#  ('Maracás', 'Instituir a política municipal “Ler Melhor” no município.'),
#  ('Campinas',
#   'Implantar o programa “Bueiro Imobiliário” para prevenção de enchentes no município.'),
#  ('Campina Grande', 'Criar o programa “Farmapet” no município.'),
#  ('Campina Grande',
#   'Criar o programa “Paz nas Escolas e Não Violência” para prevenção e controle da violência nas escolas do município.'),
#  ('Toledo',
#   'Instituir o mês “Maio Amarelo” para promover ações preventivas e conscientização para a redução de acidentes de trânsito no município.'),
#  ('Barra do Garças', 'Criar o selo anticorrupção no município.'),
#  ('Natal', 'Implantar o programa “Abrigo Amigo” no município.'),
#  ('Natal',
#   'Instituir a Campanha “Salve Uma Criança” como mecanismo de combate e prevenção à violência sexual praticada contra crianças e adolescentes no município.'),
#  ('Ijaci', 'Limpar terrenos no município.'),
#  ('Campina Grande',
#   'Criar o programa “Cassa Limpa” na zona rural do município.'),
#  ('Campinas', 'Criar o programa Criança Sem Violência no município.'),
#  ('Lagoa da Prata',
#   'Instituir o “Junho Violento” no município em alusão ao Dia Mundial de Conscientização da Violência contra Pessoa I'),
#  ('Paraguaçu Paulista',
#   'Criar o programa “De Olho no Trânsito” no município.'),
#  ('Campina Grande', 'Criar o programa “Muro Legal” no município.'),
#  ('Formosa',
#   'Instituir o mês “Abril Laranja” para prevenir a crueldade contra os animais no município.'),
#  ('Sarandi', 'Criar o programa “jardineiro da cidade” no município.'),
#  ('Luziânia', 'Instituir campanha de prevenção a golpes no município.'),
#  ('Cabo de Santo Agostinho',
#   'Criar o programa municipal de conscientização e educação ambiental “Cidade Limpa, Cidadão Consciente” no município.'),
#  ('Tijucas do Sul', 'Criar o programa “Vamos Reciclar” no município.'),
#  ('Votorantim', 'Proibir queimadas no município.'),
#  ('Barueri', 'Proibir queimadas no município.'),
#  ('Guanhães', 'Proibir queimadas no município.'),
#  ('Itabirito', 'Proibir queimadas no município.'),
#  ('Formosa', 'Proibir queimadas no município.'),
#  ('Parauapebas', 'Proibir queimadas no município.'),
#  ('Uruguaiana',
#   'Instituir a campanha “Maio Laranja” de enfrentamento à exploração e violência sexual contra crianças e adolescentes no município.'),
#  ('Caruaru', 'Instituir o município como “pet friendly” no município.'),
#  ('Caruaru', 'Instituir o município como “pet friendly” no município.'),
#  ('Anápolis',
#   'Criar o programa municipal de segurança comunitária “Projeto Lavra Solidária” no município.'),
#  ('Mostardas', 'Instituir a “Rota da Película” no município.'),
#  ('Campina Grande',
#   'Criar o programa “Buaco Zero” estabelecendo prazos para reparos em vias públicas no município.'),
#  ('Barão', 'Implementar lei anticorrupção no município.'),
#  ('Araxá',
#   'Instituir o mês “Junho Violento” no município para promover ações de combate à violência contra o idoso.'),
#  ('São José do Ouro', 'Criar o programa “Morar Melhor” no município.'),
#  ('Marabá', 'Instituir o Dia do Cac – Caça, Tiro e Coletor no município.'),
#  ('Natal', 'Criar a política “chave por chave” no município.'),
#  ('Araxá', 'Alterar a Lei Municipal no município.'),
#  ('Votorantim', 'Criar câmara mirim no município.'),
#  ('Itapoá', 'Criar câmara mirim no município.'),
#  ('Heliodora', 'Criar câmara mirim no município.'),
#  ("Sant'Ana do Livramento", 'Criar câmara mirim no município.'),
#  ('Sarandi', 'Criar o programa “Sarandi Melhor” no município.'),
#  ('Sarandi', 'Instituir a campanha “Sarandi Comprar Sarandi” no município.'),
#  ('Barueri',
#   'Alterar o art. 6o, VI, "a", do Código da Administração Direta do município.'),
#  ('Montes Claros',
#   'Instituir o mês “Junho Violento” para conscientização e prevenção da violência contra pessoas idosas no município.'),
#  ('Pato Branco',
#   'Instituir o evento “Marcha de Combate à Violência contra Pessoa Idosa” no calendário oficial do município.'),
#  ('Araxá',
#   'Realizar termo de fomento com o Conselho Municipal de Segurança Pública para apoiar o projeto “Transitolândia – Redução contínua da criminalidade e violência e promoção da defesa social.'),
#  ('Natal', 'Criar o programa “Investidor do Futuro” no município.'),
#  ('Carlos Barbosa', 'Criar programa municipal creche noturna no município.'),
#  ('Pelotas', 'Instituir o “Junho Verde” no município.'),
#  ('Pedra Preta',
#   'Instituir a Semana “Quebrando o Silêncio” no calendário do município.'),
#  ('Natal', 'Criar o programa “Tempo de Acordar” no município.'),
#  ('Natal',
#   'Instituir a campanha “Amar é dela, o silêncio mata” no município.'),
#  ('Entre Rios de Minas',
#   'Instituir o programa “Caminhos de São Francisco” no município.'),
#  ('Rio Grande',
#   'Implantar o programa “Bueiro Imobiliário” como forma de prevenção às enchentes no município.'),
#  ('Cabo de Santo Agostinho',
#   'Implantar o programa “Bueiro Imobiliário” como forma de prevenção às enchentes no município.'),
#  ("Sant'Ana do Livramento",
#   'Implantar o programa “Bueiro Imobiliário” como forma de prevenção às enchentes no município.'),
#  ("Sant'Ana do Livramento",
#   'Criar o programa “Smart Providência” no município.'),
#  ('Armação dos Búzios', 'Criar o programa “Parlamento Jovem” no município.'),
#  ('Santana do Itararé', 'Criar o projeto “Pequeno Retireiro” no município.'),
#  ('Três Passos', 'Criar o programa municipal “Prefeito Mirim” no município.'),
#  ('Três Passos', 'Criar o programa municipal “Prefeito Mirim” no município.'),
#  ('Marabá', 'Regulamentar o uso de “containers” no município.'),
#  ('Rio Grande', 'Criar o programa “Comunidade Colaborativa” no município.'),
#  ('Campina Grande',
#   'Instituir a campanha permanente “Universidade sem Violência” no município.'),
#  ('Catalão',
#   'Instituir a “Mealha de Honra ao Mérito do Mérito” no município.'),
#  ('Natal', 'Criar o programa “Merenda nas Férias” no município.'),
#  ('Natal', 'Criar o programa “Merenda nas Férias” no município.'),
#  ('Barueri', 'Criar o programa “Câmeras Barueri” no município.'),
#  ('Franca',
#   'Criar o programa “Jogo Limpo e respeito no esporte infantil” no município.'),
#  ('Butiá', 'Criar conselho municipal antidrogas no município.'),
#  ('Sarandi', 'Criar o programa “Rumos Verdes” no município.'),
#  ('Campina Grande', 'Criar o programa “Carrega Bagulho” no município.'),
#  ('Caruaru', 'Alterar legislação municipal.'),
#  ('Franca', 'Criar o programa municipal “Remédio em Casa” no município.'),
#  ('Cupira', 'Criar o programa “Pena na Escola” no município.'),
#  ('Campina Grande', 'Criar o projeto “Bem Fake-mais News” no município.'),
#  ('Parauapebas', 'Criar o programa municipal “Doe uma Parada” no município.'),
#  ('Cláudio', 'Criar o programa “Maio Amarelo” no município.'),
#  ('Natal', 'Criar a “Câmara Infantil” no município.'),
#  ('Itabirito',
#   'Criar o programa “Olhos da Comunidade” para reconhecer a participação cidadã na identificação e comunicação de irregularidades urbanas no município.'),
#  ('Olinda',
#   'Instituir o mês “Abril Laranja” como mês de prevenção da crueldade contra os animais no município.'),
#  ('Caruaru',
#   'Instituir o mês “Abril Laranja” como mês de prevenção da crueldade contra os animais no município.'),
#  ('Ipameri',
#   'Instituir o mês “Abril Laranja” como mês de prevenção da crueldade contra os animais no município.'),
#  ('São Mateus',
#   'Instituir o mês “Abril Laranja” como mês de prevenção da crueldade contra os animais no município.'),
#  ('Três Passos', 'Indenizar víitimas de interpérfluo no município.'),
#  ('Natal', 'Criar o programa “Caco da Juventude” no município.'),
#  ('Caruaru',
#   'Criar programa de jornada extra de prevencão à violência no município.'),
#  ('Barueri', 'Combater o vício do jogo de azar no município.'),
#  ('Campinas', 'Criar o programa “Taxi Amigo do Perito” no município.'),
#  ('São Mateus do Sul', 'Instituir o programa “Aluguel Social” no município.'),
#  ('Tijucas', 'Instituir campanha de prevenção ao avc no município.'),
#  ('Mostardas',
#   'Instituir e incluir no calendário oficial o “Caça de Sinuca” no município.'),
#  ('Rio Grande', 'Proibir blitz do IPVA no município.'),
#  ('Anápolis', 'Proibir blitz do IPVA no município.'),
#  ('Marabá', 'Proibir blitz do IPVA no município.'),
#  ('Campina Grande', 'Proibir blitz do IPVA no município.'),
#  ('Cáceres', 'Proibir blitz do IPVA no município.'),
#  ('Campina Grande', 'Criar o programa “Saúde do Catador” no município.'),
#  ('Votorantim',
#   'Vedar a atividade de guardadores autônomos de veículos automotores “Flanelinhas” nas vias e logradouros públicos do município.'),
#  ('Rio Grande', 'Criar o “Condominio horizontal de lotes” no município.'),
#  ('Capitão Enéas', 'Criar o programa “Doe uma Placa” no município.'),
#  ('Uruguaiana', 'Criar o programa “Doe uma Placa” no município.'),
#  ('Natal', 'Instituir a campanha “Acompanhante Legal” no município.'),
#  ('Itabirito', 'Criar o projeto “Pena na Faixa, Pé no Freio” no município.'),
#  ('Pedra Preta', 'Limpar terrenos urbanos no município.'),
#  ('Caçu', 'Criar o programa “Cartão Amigo” no município.'),
#  ('Primavera do Leste', 'Instituir o Prêmio “Advocacia Cidadã” no município.'),
#  ('Dilermando de Aguiar',
#   'Instituir o Prêmio “Advocacia Cidadã” no município.'),
#  ('Armação dos Búzios', 'Criar o programa “Rua da Brinquedo” no município.'),
#  ('Parauapebas',
#   'Criar o programa “Banco de Trabalho para a Juventude” no município.'),
#  ('Marabá', 'Regulamentar o poder de policia administrativa no município.'),
#  ('Campinas', 'Alterar o zoneamento urbano no município.'),
#  ('Campinas', 'Alterar o zoneamento urbano no município.'),
#  ('Campinas', 'Alterar o zoneamento urbano no município.'),
#  ('Pato Branco',
#   'Criar o programa “Torifa Zero a caminho do emprego” no município.'),
#  ('Itapoá',
#   'Implantar o projeto “Defesa pessoal e desenvolvimento social e profissional autônomo para mulheres” no município.'),
#  ('Uruguaiana', 'Regulamentar a violência contra a mulher no município.'),
#  ('Erechim', 'Criar programa municipal de combate à drogadição.'),
#  ('Armação dos Búzios', 'Criar programa creche noturna no município.'),
#  ('Franca', 'Implantar o conceito de “Smart Cities” no município.'),
#  ('Armação dos Búzios',
#   'Criar o programa municipal “Joque na Escola, Craque no Esporte” no município.'),
#  ('Canoinhas', 'Criar o programa “Doar um Espaço Público” no município.'),
#  ('Canela',
#   'Instituir e incluir no calendário oficial o “Marcha para Jesus” no município.'),
#  ('Toledo', 'Criar o programa “Doar um Espaço Público” no município.'),
#  ('Manhuaçu', 'Criar o “Condomínio fechado de lotes” no município.'),
#  ('Crixás', 'Criar programa Guarda Municipal Infantil no município.'),
#  ('Campina Grande', 'Implantar o programa “Remédio para Todos” no município.'),
#  ('Esteio',
#   'Implementar medidas de prevenção e punição a atos de pichação no município.'),
#  ('Uruguaiana', 'Instituir o diploma tiradentes no município.'),
#  ('São Francisco de Assis',
#   'Criar o programa “Escola Mais Seguro” no município.'),
#  ('Natal', 'Criar o projeto “Praia Limpa” no município.'),
#  ('Pato Branco', 'Alterar a malha viária do município.'),
#  ('Palmital', 'Criar a “Câmara Jovem” no município.'),
#  ('Barra do Garças',
#   'Estabelecer medidas de combate à corrupção e responsabilizar pessoas jurídicas no município.'),
#  ('Rio Grande',
#   'Criar o programa “Calcada Legal” para uniformizar a pavimentacao de passeios públicos do município.'),
#  ('Rio Grande',
#   'Implantar o programa “Bueiro Imovel” como forma de prevenção às enchentes no município.'),
#  ('Natal', 'Instalar motoboys “moto entregadores” no município.'),
#  ('Rio Grande',
#   'Criar o programa de mobilidade “Cidade para Pessoas” no município.'),
#  ('Toledo', 'Implementar termo de transação extrajudicial no município.'),
#  ('Campina Grande',
#   'Criar programa municipal de prevenção e enfrentamento à ludopatia no município.'),
#  ('Formosa',
#   'Criar o programa “A acessibilidade em estabelecimentos comerciais” no município.'),
#  ('Clevelândia', 'Criar o programa “km 0 - Produção Local” no município.'),
#  ('Três Barras do Paraná',
#   'Criar o programa “Transferência de atletas” no município.'),
#  ('Itaúna', 'Criar o programa “Criança nos Bairros” no município.'),
#  ('São Bento do Sul',
#   'Criar o programa municipal “Porteira Aberta” no município.'),
#  ('São Bento do Sul', 'Instituir o mês “Junho Branco” no município.'),
#  ('Montes Claros', 'Criar o projeto Mais Segurança no município.'),
#  ('Toledo', 'Criar programa municipal anti-pichação.'),
#  ('Toritama', 'Criar o programa “Empreenda Mulher” no município.'),
#  ('Itabirito',
#   'Criar a política “Diga Não à Violência nas Escolas” para prevenção e combate à violência escolar no município.'),
#  ('São Sebastião da Boa Vista',
#   'Criar normas sobre policia administrativa no município.'),
#  ('Pato Branco',
#   'Incluir o evento “Marcha de Combate à Violência contra Pessoa Idosa” no calendário oficial do município.'),
#  ('Natal',
#   'Criar o programa municipal “Mulheres guardiãs: lideranças na prevenção de riscos”.'),
#  ('Campina Grande',
#   'Criar o programa municipal “Mulheres guardiãs: lideranças na prevenção de riscos”.'),
#  ('Luziânia', 'Proibir blitzes do IPVA no município.'),
#  ('Três Barras do Paraná',
#   'Proponder o empreendimento denominado de loteamento “ Ouro Negro” no município.'),
#  ('Natal', 'Criar o programa “Farmácia Verde” no município.'),
#  ('Campina Grande', 'Criar o programa “Farmácia Verde” no município.'),
#  ('Barueri', 'Criar o projeto “Guarda Maria da Penha” no município.'),
#  ('Campina Grande', 'Criar o programa “Calo de Lata” no município.'),
#  ('Luziânia',
#   'Criar política municipal de prevenção à violência contra jovens no município.'),
#  ('Tijucas',
#   'Implantar o “Bueiro Imobiliário” como forma de prevenção às enchentes no município.'),
#  ('Campinas', 'Criar o programa descarte consciente no município.'),
#  ('Formosa', 'Criar a “Casa de Direitos” no município.'),
#  ('Canoinhas',
#   'Implementar termo de colaboração com a Polícia Militar do município para o repasse financeiro do projeto “Escolinha de Futebol”.'),
#  ('Ipameri',
#   'Instituir o mês “Junho Violento” para conscientizar e prevenir abandono e violência contra idosos no município.'),
#  ('Formosa', 'Instituir a campanha “Janeiro Branco” no município.'),
#  ('Anápolis', 'Instituir a campanha “Janeiro Branco” no município.'),
#  ('Carlos Barbosa', 'Instituir a campanha “Janeiro Branco” no município.'),
#  ('Natal', 'Instituir a “Frente Arborista” no município.'),
#  ('Campina Grande', 'Criar o programa “Casa Campinense” no município.'),
#  ('Rio Grande', 'Criar programa de combate à desinformação no município.'),
#  ('Rio Grande', 'Criar programa fossa limpa no município.'),
#  ('Caruaru',
#   'Criar o programa “Nota Fiscal Premiada” para estimular a cidadania fiscal no município.'),
#  ('Montes Claros', 'Criar o Programa Não à Violência Infância no município.'),
#  ('Campina Grande', 'Criar o projeto “ chute para o futuro” no município.'),
#  ('Canoinhas',
#   'Instituir política municipal de transparência e prevenção da corrupção.'),
#  ('Luziânia', 'Disponibilizar fake news no município.'),
#  ('Carmo da Mata',
#   'Criar o programa municipal “Adote Uma Placa” no município.'),
#  ('Olinda',
#   'Criar programa para reduzir gradativamente o número de veículos de tração animal no município.'),
#  ('Clevelândia',
#   'Criar o programa municipal “Cinelândia Premiada” no município.'),
#  ('Luiz Alves', 'Criar armas no município.'),
#  ('Rio Grande', 'Proibir jogar e queimar lixo na zona urbana do município.'),
#  ('Campina Grande', 'Criar o programa “bairro empreendedor” no município.'),
#  ('Franca', 'Criar o programa “obra transparente” no município.'),
#  ('Ribas do Rio Pardo', 'Criar o programa “Doar uma Praça” no município.'),
#  ('Campina Grande',
#   'Implementar o programa “Três Violentas” contra violência sexual em eventos culturais no município.'),
#  ('Natércia', 'Interditar o trânsito no município.'),
#  ('São Mateus do Sul',
#   'Instituir e incluir no calendário oficial festas e comemorações do município a Semana Municipal “Quebrando o Silêncio”.'),
#  ('Campina Grande', 'Criar o programa “Caçamba comunitária” no município.'),
#  ('Carmo do Paranaíba',
#   'Criar o programa “Caçamba comunitária” no município.'),
#  ('Campinas', 'Implantar o programa “Doe um Parcão” no município.'),
#  ('Araxá',
#   'Implementar termo de fomento com o Conselho Municipal de Segurança Pública para celebrar o projeto “Transito do Bem”.'),
#  ('Campina Grande',
#   'Implementar parceria público-privada com empresas de transporte por meio de aplicativos como Uber, 99, táxi, “Transferência da Solidariedade” no município.'),
#  ('Montes Claros',
#   'Alterar a Lei no 69/2003. Desafetar área de terreno de sua característica, transferir para o patrimônio disponível do município, autorizar doação ao Corpo de Bombeiros Militar.'),
#  ('Campina Grande',
#   'Estabelecer diretrizes para “Infância Sem Violência” no município.'),
#  ('Itaiçaba',
#   'Instituir o feriado municipal referente ao “Dia de Corpus Christi” no município.'),
#  ('Natal', 'Criar o programa “Doe Uma Lixeira” no município.'),
#  ('Anápolis', 'Criar o programa “Doe Uma Lixeira” no município.'),
#  ('Uruguaiana', 'Criar o programa “Doe Uma Lixeira” no município.'),
#  ('Formiga', 'Criar o programa “Doe Uma Lixeira” no município.'),
#  ('Araguari', 'Criar o programa “Doe Uma Lixeira” no município.'),
#  ('Ilhéus',
#   'Criar o programa “Bueiro Ecomático” no município como política pública ambiental e de prevenção a enchentes.'),
#  ('Primavera do Leste',
#   'Instituir o Dia Municipal do Cac – Caça, Tiro e Coletor no calendário do município.'),
#  ('Formosa', 'Criar o programa “O Partodelas” no município.'),
#  ('Pato Branco', 'Instituir o projeto “Café de Fralda Social” no município.'),
#  ("Sant'Ana do Livramento",
#   'Criar o programa “Calo de Lata” no município para reduzir gradativamente o número de veículos com tração animal e substituição por veículos de tração elétrica ou mecânica.'),
#  ('Maracás',
#   'Instituir o projeto “Regatando as Histórias do Município” no município.'),
#  ('Campinas', 'Criar “Parklets” no município.'),
#  ('Pedro Afonso', 'Criar o projeto “Esporte e Cidadania” no município.'),
#  ('Itapoá', 'Denominar “honório parra” no município.'),
#  ('Schroeder',
#   'Criar política municipal de transparência e prevenção da corrupção.'),
#  ('Erechim', 'Instituir o “Hino Nativista Brasileiro” no município.'),
#  ('Jaguari',
#   'Instituir a campanha “Maio Laranja” de combate ao abuso e à exploração sexual de crianças e adolescentes no município.'),
#  ('Mostardas',
#   'Criar o programa municipal “Adote Uma Passaela” no município.'),
#  ('Ipameri',
#   'Instituir o mês “Junho Violento” como mês de conscientização, prevenção e combate à violência contra pessoas idosas no município.'),
#  ('Lagoa Grande', 'Criar o programa “Campo Seguro” no município.'),
#  ('Canarana', 'Criar o programa “Cinema na Câmara” no município.'),
#  ('Campina Grande', 'Criar o programa “Cuidando de Quem Cuida” no município.'),
#  ('Barra do Garças',
#   'Criar o programa “Cuidando de Quem Cuida” no município.'),
#  ('Barra do Garças',
#   'Criar o programa “Cuidando de Quem Cuida” no município.'),
#  ('Carmo do Paranaíba',
#   'Criar o programa “Cuidando de Quem Cuida” no município.'),
#  ('Campina Grande', 'Criar o programa “Adote Uma Placa” no município.'),
#  ('Natal', 'Criar o programa “Medicamento no Lar” no município.'),
#  ('Natal', 'Criar o programa “Guincho Solidário” no município.'),
#  ('São Francisco de Assis', 'Criar o projeto “Rua do Trânsito” no município.'),
#  ('Goianá',
#   'Instituir a campanha permanente “Lixo no Lugar certo” no município.'),
#  ('Natércia', 'Criar cardo de faxineira no município.'),
#  ('Ribas do Rio Pardo',
#   'Incluir a campanha “Quebrando o Silêncio” no calendário de eventos oficiais do município.'),
#  ('Votorantim',
#   'Desafetar e permutar imóveis do loteamento “Jadim Maria José” do município.'),
#  ('Cáceres', 'Criar guarda municipal patrimonial no município.'),
#  ('Ipameri', 'Criar o programa “ela” no município.'),
#  ('Anápolis', 'Criar o programa “Viadutos Verde” no município.'),
#  ('Natal', 'Criar o programa “Meu Bairro Bem Cuidado” no município.'),
#  ('Campina Grande', 'Criar o programa “Meu Bairro Bem Cuidado” no município.'),
#  ('Caruaru', 'Criar o programa “Meu Bairro Bem Cuidado” no município.'),
#  ('Parauapebas', 'Criar o programa “Doar uma Área Pública” no município.'),
#  ('Canela', 'Criar programa menor aprendiz no município.'),
#  ('Caruaru', 'Alterar legislação municipal e alterar legislação municipal.'),
#  ('Serafina Corrêa',
#   'Instituir o programa “Alimentação Moradia” no município.'),
#  ('Campina Grande', 'Criar o programa “Criança Protegida” no município.'),
#  ('Cáceres',
#   'Proibir o uso em público do cachimbo conhecido como “narguilé” no município.'),
#  ('Campina Grande', 'Criar o evento “Quinta do Motociclista” no município.'),
#  ('Cáceres', 'Criar protocolo municipal antirracista no município.'),
#  ('Paraguaçu Paulista',
#   'Incluir o programa “0034 – Desenvolvimento Urbano e Habitacional” no orçamento do município.'),
#  ('Campinas', 'Alterar o zoneamento no município.'),
#  ('Campinas', 'Alterar o zoneamento no município.'),
#  ('Tijucas', 'Organizar política municipal de prevenção da corrupção.'),
#  ('São Mateus', 'Criar plano municipal de segurança pública no município.'),
#  ('Canela', 'Criar plano municipal de segurança pública no município.'),
#  ('Goianá', 'Criar o programa “Remédio em Casa” no município.'),
#  ('Tangará da Serra', 'Criar o programa “Remédio em Casa” no município.'),
#  ('Luziânia', 'Criar o programa “Remédio em Casa” no município.'),
#  ('São João do Ivaí', 'Criar o programa “Remédio em Casa” no município.'),
#  ('Campina Grande', 'Criar o programa “Remédio em Casa” no município.'),
#  ('Diamantino', 'Instituir o Dia de Combate à Violência Civis no município.'),
#  ('Natal',
#   'Implementar lei de prevenção e combate ao furto de fios e cabos no município.'),
#  ('Luiz Alves',
#   'Criar o programa “Camarrar é cuidar” para controle populacional de cães e gatos no município.'),
#  ('Natal', 'Criar o programa municipal “Check-Up da Criança” no município.'),
#  ('São Sebastião do Caí',
#   'Instituir o programa “Doe uma Praça” no município.'),
#  ('Formosa', 'Criar o programa “Guarda Imirim” no município.'),
#  ('Araxá', 'Criar o projeto “Ver-Viva” no município.'),
#  ('Campina Grande', 'Criar o programa “Banco de Livros Urbano” no município.'),
#  ('Anápolis',
#   'Instituir a Semana Municipal “Não Te Julgo, Te Ajudo” no município.'),
#  ('Paraguaçu Paulista',
#   'Criar campanha de erradicação do analfabetismo no município.'),
#  ('Formosa', 'Instituir o “Junho Violeta” no município.'),
#  ('Carlos Barbosa', 'Instituir o “Junho Violeta” no município.'),
#  ('Natal', 'Instituir o “Junho Violeta” no município.'),
#  ('Caçapava do Sul', 'Criar o programa “Aluno Cidadão” no município.'),
#  ('Campinas',
#   'Criar programa de cooperação e o código sinal vermelho no município para combater e prevenir a violência contra a mulher.'),
#  ('Catalão', 'Instituir normas sobre polícia administrativa no município.'),
#  ('Itapoá',
#   'Prevenção e punição de atos de pichação, vandalismo e depredação do patrimônio público no município.'),
#  ('Franca',
#   'Aumentar a quantidade de vagas de empregos do programa “Primeira Chance” no município.'),
#  ('Franca',
#   'Aumentar a quantidade de vagas de empregos do programa “Primeira Chance” no município.'),
#  ('Itabirito',
#   'Criar o programa municipal “Patrulha Maria da Penha” no município.'),
#  ('Marabá', 'Criar programa de segurança do paciente no município.'),
#  ('Itabirito',
#   'Criar o programa “Calçada Cidadã” voltado à padronização, acessibilidade e conservação das calçadas no município.'),
#  ('Primavera do Leste', 'Instalar “Ruas Acalmadas” no município.'),
#  ('Paty do Alferes', 'Alterar o critério de gabarito no município.'),
#  ('Nova Prata', 'Regulamentar a taxa de lixo no município.'),
#  ('Palmital',
#   'Reduzir a base de cálculo do itbi – imposto sobre transmissão inter vivos de bens imóveis no município.'),
#  ('Marabá', 'Criar o programa “Kit Maternidade” no município.'),
#  ('Quilombo', 'Criar o programa “Hora comunitária” no município.'),
#  ('Butiá', 'Criar o programa “Hora comunitária” no município.'),
#  ('Olinda', 'Criar programa de combate ao capacitismo no município.'),
#  ('Pato Branco', 'Criar a “Patrulha Mirim” no município.'),
#  ('Toritama', 'Criar o programa “Movimenta Mulhe” no município.'),
#  ('Armação dos Búzios', 'Criar o programa “Amigo do Turismo” no município.'),
#  ('Toledo', 'Criar o programa “Doe um Espaço Público” no município.'),
#  ('Marabá', 'Criar o programa “pró-meninas” no município.'),
#  ('Marabá',
#   'Criar o programa “Adote Uma Casinha em Ponto de Mototáxi” no município.'),
#  ('Olinda',
#   'Instituir a campanha “Turn Off” nas escolas públicas e privadas do município.'),
#  ('Esteio', 'Criar passe livre no município.'),
#  ('Natal',
#   'Alterar a Lei no6.536/2015 que institui o “Setembro Cidadão” no município.'),
#  ('Campina Grande', 'Criar o programa municipal “Lança+Jovem” no município.'),
#  ('Marabá', 'Dar o nome “Maria das Graças” ao município.'),
#  ('Paraguaçu Paulista',
#   'Criar o programa “Sou soldado do exército contra a dengue, vamos exterminá-la” no município.'),
#  ('São Francisco de Assis',
#   'Criar o programa “São Francisco Nota 10” no município.'),
#  ('Campina Grande',
#   'Instituir campanha permanente de prevenção e combate à automutilação e ao suicídio “Pare! Não faça mal a você!” no município.'),
#  ('Marabá',
#   'Criar o Dia Municipal do Projeto “Quebrando o Silêncio” no município.'),
#  ('Campina Grande', 'Criar o projeto “Banheiro Legal” no município.'),
#  ('Juazeiro', 'Criar o programa “ talentos da terra” no município.'),
#  ('Natal',
#   'Criar o programa “Comércio do Bem” no município para permitir a comercialização de produtos em espaços públicos municipais.'),
#  ('Barueri', 'Alterar o programa “Aluguel Social” do município.'),
#  ('Primavera do Leste', 'Criar o distrito industrial “IV” no município.'),
#  ('Parauapebas',
#   'Implantar o programa “Ponto Seguro do Trabalhador e da Trabalhadora” no município.'),
#  ('Pato Branco', 'Extingue a taxa de iluminação pública no município.'),
#  ('Quirinópolis', 'Criar o programa “Doe uma Praça” no município.'),
#  ('Lagoa da Prata', 'Criar o programa “Doe uma Praça” no município.'),
#  ('Careaçu', 'Criar o programa “Doe uma Praça” no município.'),
#  ('Campina Grande', 'Criar o programa “Doe uma Praça” no município.'),
#  ('Formosa', 'Criar o programa “Doe uma Praça” no município.'),
#  ('Luiz Alves', 'Criar o programa “Doe uma Praça” no município.'),
#  ('São Sebastião do Caí', 'Criar o programa “Doe uma Praça” no município.'),
#  ('Schroeder', 'Criar o programa “Doe uma Praça” no município.'),
#  ('Ipameri', 'Criar o programa “Doe uma Praça” no município.'),
#  ('Dois Irmãos', 'Criar o programa “Doe uma Praça” no município.'),
#  ('Barueri', 'Criar o programa “Doe uma Praça” no município.'),
#  ('Juara', 'Criar o programa “Doe uma Praça” no município.'),
#  ('Votorantim',
#   'Obrigar a fiscalização de tatuagens e a aplicação de “piercing” no município.'),
#  ('São Sebastião do Caí',
#   'Instituir a campanha “Compre em Caí” no município.'),
#  ('Santo Augusto', 'Implantar o projeto “Doe um Cantinho” no município.'),
#  ('Campina Grande', 'Criar o programa “Mulheres na Política” no município.'),
#  ('Campinas',
#   'Criar programa municipal de enfrentamento ao feminicídio no município.'),
#  ('Itapoá', 'Instituir oginásio de esporte “Virgonel” no município.'),
#  ('Caçu', 'Limpar lagos e rios no município.'),
#  ('Formosa', 'Criar o programa “Transito Para Todos” no município.'),
#  ('São Mateus do Sul',
#   'Instituir o programa “Caminhos da Produção no Campo” no município.'),
#  ('São Miguel do Araguaia',
#   'Promover a comercialização de comida e de bebidas por veículos denominados “Food Trucks” no município.'),
#  ('Butiá', 'Proibir o fumo em ambientes públicos no município.'),
#  ('Pedra Preta',
#   'Proibir práticas de violência, assédio e discriminação contra mulheres no município.'),
#  ('Caçu', 'Criar conselho municipal de políticas sobre drogas no município.'),
#  ('Natal', 'Criar o programa “Direito na Escola” no município.'),
#  ('Armação dos Búzios', 'Instituir o “Setembro Amarelo” no município.'),
#  ('Diamantino', 'Instituir o “Setembro Amarelo” no município.'),
#  ('Barra do Garças', 'Instituir o “Setembro Amarelo” no município.'),
#  ('Bocaiúva', 'Instituir o “Setembro Amarelo” no município.'),
#  ('Natal', 'Instituir a Campanha “Coração de Mulher” no município.'),
#  ('Quilombo', 'Instituir a Campanha “Coração de Mulher” no município.'),
#  ('Marabá', 'Instituir a Campanha “Coração de Mulher” no município.'),
#  ('Luziânia', 'Instituir a Campanha “Coração de Mulher” no município.'),
#  ('Montes Claros', 'Criar o programa “Incubadora de Empresas” no município.'),
#  ('Montes Claros', 'Criar o programa “Incubadora de Empresas” no município.'),
#  ('Porto Murtinho', 'Instituir o projeto “Dengue nas Escolas” no município.'),
#  ('Campina Grande', 'Criar o projeto “Amar é Legal” no município.'),
#  ('Franca', 'Criar o programa “Pontes da Vida” no município.'),
#  ('Natércia', 'Criar o programa “Adote um Equipamento Público” no município.'),
#  ('Campina Grande', 'Instituir a campanha “Pe na Sombra” no município.')]

# %%
import numpy as np

emb = np.concat([row['embedding'][None] for row in results])
emb.shape
# Out:
# (500, 768)

# %%
import umap

umodel = umap.UMAP(
    n_neighbors=3,        # aumenta => tópicos mais globais
    n_components=2,       # 10–25 geralmente é bom
    min_dist=0.0,
    metric="cosine",
    random_state=42,
    verbose=True
)

umodel
# Out:
# UMAP(metric='cosine', min_dist=0.0, n_neighbors=3, random_state=42, verbose=True)

# %%
embeddings_umap = umodel.fit_transform(emb)
embeddings_umap.shape
# Out:
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0.0, n_jobs=1, n_neighbors=3, random_state=42, verbose=True)
# Tue Nov 18 15:59:24 2025 Construct fuzzy simplicial set
# Tue Nov 18 15:59:25 2025 Finding Nearest Neighbors
# Tue Nov 18 15:59:25 2025 Finished Nearest Neighbor Search
# Tue Nov 18 15:59:25 2025 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Tue Nov 18 15:59:25 2025 Finished embedding
# (500, 2)

# %%
import pandas as pd
import altair as alt

df = pd.DataFrame({
    "x": embeddings_umap[:, 0],
    "y": embeddings_umap[:, 1],
    "label": [row['acao'] for row in results],
})

alt.Chart(df).mark_circle().encode(
    x=alt.X("x:Q", axis=alt.Axis(title="UMAP-1")),
    y=alt.Y("y:Q", axis=alt.Axis(title="UMAP-2")),
    tooltip=[alt.Tooltip("label:N", title="Ação")]
).interactive()
# Out:
# alt.Chart(...)
